# %% [markdown]
# ## TMDB Box Office Prediction

# %% [markdown]
# The objective of this competition is to predict the worldwide box office revenue of the movie using the data points provided like cast, crew, plot keywords, budget, posters, release dates, languages, production companies, and countries.

# %% [markdown]
# ### Acknowledgement

# %% [markdown]
# Most of the codes are inspired/reproduced from this awesome kernel - https://www.kaggle.com/artgor/eda-feature-engineering-and-model-interpretation

# %% [markdown]
# ### Loading the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
import ast
from tqdm import tqdm_notebook
from collections import Counter
warnings.filterwarnings('ignore')

# %%
kaggle=0
if kaggle==0:
    train=pd.read_csv("train.csv")
    test=pd.read_csv("test.csv")
    sub=pd.read_csv("sample_submission.csv")
else:
    train=pd.read_csv("../input/train.csv")
    test=pd.read_csv("../input/test.csv")
    sub=pd.read_csv("../input/sample_submission.csv")

# %% [markdown]
# ### Data Cleaning

# %%
print(f'Shape of train is {train.shape} and shape of test is {test.shape}')
# Out:
# Shape of train is (3000, 23) and shape of test is (4398, 22)

# %% [markdown]
# The test set is greater than the train set .

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
# id                       3000 non-null int64
# belongs_to_collection    604 non-null object
# budget                   3000 non-null int64
# genres                   2993 non-null object
# homepage                 946 non-null object
# imdb_id                  3000 non-null object
# original_language        3000 non-null object
# original_title           3000 non-null object
# overview                 2992 non-null object
# popularity               3000 non-null float64
# poster_path              2999 non-null object
# production_companies     2844 non-null object
# production_countries     2945 non-null object
# release_date             3000 non-null object
# runtime                  2998 non-null float64
# spoken_languages         2980 non-null object
# status                   3000 non-null object
# tagline                  2403 non-null object
# title                    3000 non-null object
# Keywords                 2724 non-null object
# cast                     2987 non-null object
# crew                     2984 non-null object
# revenue                  3000 non-null int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.1+ KB

# %%
train.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity    ...     \
# 0  When Lou, who has become the "father of the In...    6.575393    ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895    ...
# 2  Under the direction of a ruthless instructor, ...   64.299990    ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936    ...
# 4  Marine Boy is the story of a former national s...    1.148070    ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# From the overview of the data we find that the columns belongs_to_collection,genres,spoken_languages,Keywords,cast,crew,production_companies,production_countries are of JSON type . Lets convert the columns to pandas list.

# %%
# from this kernel: https://www.kaggle.com/gravix/gradient-in-a-box & https://www.kaggle.com/artgor/eda-feature-engineering-and-model-interpretation
dict_columns = ['belongs_to_collection', 'genres', 'production_companies',
                'production_countries', 'spoken_languages', 'Keywords', 'cast', 'crew']

def text_to_dict(df):
    for column in dict_columns:
        df[column] = df[column].apply(lambda x: {} if pd.isna(x) else ast.literal_eval(x) )
    return df

train=text_to_dict(train)
test=text_to_dict(test)

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# ### Belongs to Collection

# %%
for i, e in enumerate(train['belongs_to_collection'][:5]):
    print(i, e)
# Out:
# 0 [{'id': 313576, 'name': 'Hot Tub Time Machine Collection', 'poster_path': '/iEhb00TGPucF0b4joM1ieyY026U.jpg', 'backdrop_path': '/noeTVcgpBiD48fDjFVic1Vz7ope.jpg'}]
# 1 [{'id': 107674, 'name': 'The Princess Diaries Collection', 'poster_path': '/wt5AMbxPTS4Kfjx7Fgm149qPfZl.jpg', 'backdrop_path': '/zSEtYD77pKRJlUPx34BJgUG9v1c.jpg'}]
# 2 {}
# 3 {}
# 4 {}

# %%
train['collection_name']=train['belongs_to_collection'].apply(lambda x:x[0]['name'] if x!= {} else 0)

# %%
test['collection_name']=test['belongs_to_collection'].apply(lambda x:x[0]['name'] if x!= {} else 0)

# %%
train=train.drop('belongs_to_collection',axis=1)
test=test.drop('belongs_to_collection',axis=1)

# %%
print(train['collection_name'].head(),test['collection_name'].head())
# Out:
# 0    Hot Tub Time Machine Collection
# 1    The Princess Diaries Collection
# 2                                  0
# 3                                  0
# 4                                  0
# Name: collection_name, dtype: object 0    Pokémon Collection
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# Name: collection_name, dtype: object

# %% [markdown]
# ### Genres

# %%
for i, e in enumerate(train['genres'][:5]):
    print(i, e)
# Out:
# 0 [{'id': 35, 'name': 'Comedy'}]
# 1 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]
# 2 [{'id': 18, 'name': 'Drama'}]
# 3 [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'name': 'Drama'}]
# 4 [{'id': 28, 'name': 'Action'}, {'id': 53, 'name': 'Thriller'}]

# %% [markdown]
# Each film consist of different geners . Lets take out most occuring geners for each film as the common genere.

# %%
genre_list=list(train['genres'].apply(lambda x: [i['name'] for i in x] if x != {} else []).values)

# %%
genre_list
# Out:
# [['Comedy'],
#  ['Comedy', 'Drama', 'Family', 'Romance'],
#  ['Drama'],
#  ['Thriller', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Horror', 'Thriller'],
#  ['Documentary'],
#  ['Action', 'Comedy', 'Music', 'Family', 'Adventure'],
#  ['Comedy', 'Music'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Comedy', 'Crime'],
#  ['Action', 'Thriller', 'Science Fiction', 'Mystery'],
#  ['Action', 'Crime', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Thriller', 'Crime'],
#  ['Adventure', 'Family', 'Science Fiction'],
#  ['Horror', 'Thriller'],
#  ['Thriller', 'Horror'],
#  ['Thriller', 'Mystery', 'Foreign'],
#  ['Horror', 'Comedy'],
#  ['Comedy', 'Horror', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Animation'],
#  ['Action', 'Adventure', 'Crime', 'Thriller'],
#  ['Drama', 'Comedy'],
#  ['Mystery', 'Drama', 'Thriller'],
#  ['Fantasy', 'Action', 'Adventure'],
#  ['Horror'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Drama', 'Science Fiction', 'Thriller'],
#  ['Thriller'],
#  ['War', 'Western'],
#  ['Action', 'Documentary'],
#  ['Crime', 'Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Mystery', 'Romance', 'Thriller'],
#  ['Animation', 'Family', 'Comedy', 'Adventure'],
#  ['Crime', 'Drama', 'Mystery', 'Western'],
#  ['Drama', 'Comedy'],
#  ['Science Fiction', 'Action', 'Adventure', 'Thriller'],
#  ['Romance', 'Drama', 'Comedy'],
#  ['Adventure', 'Comedy'],
#  ['Adventure', 'Family'],
#  ['Drama', 'Family', 'Romance'],
#  ['Action'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Crime', 'Fantasy'],
#  ['Music', 'Romance'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Adventure', 'Action', 'Thriller'],
#  ['Drama'],
#  ['Thriller', 'Fantasy', 'Crime', 'Drama'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Adventure'],
#  ['Action'],
#  ['Crime', 'Comedy'],
#  ['Drama'],
#  ['Crime', 'Drama'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller', 'Fantasy'],
#  ['Drama'],
#  ['Comedy', 'Music'],
#  ['Crime', 'Documentary'],
#  ['Crime', 'Drama'],
#  ['Horror', 'Comedy'],
#  ['Drama', 'Romance', 'Foreign'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Action', 'Thriller'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Horror', 'Mystery', 'Thriller'],
#  ['Thriller', 'Science Fiction'],
#  ['Horror', 'Mystery'],
#  ['Action', 'Adventure', 'Drama', 'Mystery', 'Science Fiction', 'Thriller'],
#  ['Drama'],
#  ['Crime', 'Action', 'Comedy', 'Thriller'],
#  ['Drama', 'History'],
#  ['Drama', 'Thriller', 'Mystery', 'Romance'],
#  ['Action', 'Crime'],
#  ['Drama'],
#  ['War', 'Adventure', 'Drama', 'Romance'],
#  ['Drama', 'History'],
#  ['Thriller', 'Drama', 'Mystery'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Thriller', 'Romance'],
#  ['Fantasy', 'Drama'],
#  ['Animation', 'Comedy', 'Adventure', 'Family'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Thriller', 'Science Fiction', 'Crime', 'Horror'],
#  ['Drama', 'Romance'],
#  ['Action', 'Comedy', 'Crime', 'Foreign'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Drama'],
#  ['Action', 'Drama', 'History', 'War'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Drama', 'Adventure', 'Romance'],
#  ['Action', 'Comedy', 'Crime', 'Romance'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Thriller', 'Drama', 'Adventure', 'Action', 'History'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Action', 'Comedy'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Action', 'Comedy'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Adventure', 'Animation', 'Drama', 'Family'],
#  ['Action', 'Comedy', 'Crime', 'Mystery', 'Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'War'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Horror', 'Drama', 'Thriller', 'Mystery'],
#  ['Horror', 'Thriller'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Documentary', 'History'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama'],
#  ['Drama', 'Family'],
#  ['Comedy'],
#  ['Thriller'],
#  ['Adventure', 'Action', 'Science Fiction', 'Thriller'],
#  ['Drama', 'Music', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Drama'],
#  ['Horror', 'Crime', 'Thriller'],
#  ['Drama', 'Mystery', 'Romance'],
#  ['Comedy', 'Crime'],
#  ['Action', 'Science Fiction', 'Drama'],
#  ['Comedy', 'Family'],
#  ['Thriller', 'Adventure', 'Drama'],
#  ['Adventure', 'Drama', 'Western'],
#  ['Documentary'],
#  ['Drama', 'Fantasy', 'Horror'],
#  ['Thriller'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Adventure', 'Fantasy', 'Animation', 'Family'],
#  ['Action'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Action', 'Drama', 'Thriller', 'Crime'],
#  ['Action', 'Western'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Comedy', 'Drama'],
#  ['Thriller', 'Horror'],
#  ['Fantasy', 'Action', 'Comedy', 'Science Fiction', 'Romance'],
#  ['Documentary', 'Music'],
#  ['Crime', 'Drama', 'Horror', 'Thriller'],
#  ['Mystery', 'Comedy', 'Crime'],
#  ['Adventure', 'Action', 'Thriller', 'Science Fiction'],
#  ['Comedy', 'Crime'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Drama', 'Thriller', 'Crime', 'Mystery'],
#  ['Adventure'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Horror', 'Science Fiction', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Thriller', 'War'],
#  ['Adventure', 'Action', 'Thriller'],
#  ['Thriller', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Adventure', 'Drama', 'Action'],
#  ['Comedy', 'Drama', 'Fantasy', 'Romance'],
#  ['Drama', 'Crime'],
#  ['Comedy'],
#  ['Drama', 'Mystery'],
#  ['Animation', 'Family'],
#  ['Drama', 'Comedy'],
#  ['Horror', 'Thriller', 'Science Fiction'],
#  ['Romance', 'Comedy', 'Drama'],
#  ['Comedy'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Horror'],
#  ['Action', 'Thriller', 'Crime'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Drama', 'Crime'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Music', 'Comedy', 'Drama', 'Romance', 'Science Fiction'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Animation', 'Comedy', 'Family'],
#  ['Horror', 'Comedy', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction', 'Family', 'Fantasy'],
#  ['Fantasy', 'Horror', 'Science Fiction'],
#  ['Western', 'Adventure'],
#  ['Horror', 'Comedy'],
#  ['Horror', 'Thriller', 'Adventure'],
#  ['Action', 'Comedy', 'Family'],
#  ['Action'],
#  ['Thriller', 'Crime', 'Drama'],
#  ['Comedy', 'Crime'],
#  ['Fantasy', 'Animation', 'Family'],
#  ['Action', 'Comedy'],
#  ['Comedy'],
#  ['Documentary'],
#  ['Drama', 'History', 'War'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Thriller', 'Mystery'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama', 'History'],
#  ['Fantasy', 'Thriller', 'Action', 'Crime'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Western'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Western', 'Documentary'],
#  ['Action', 'Adventure', 'Drama', 'History'],
#  ['Adventure', 'Family'],
#  ['Horror', 'Comedy'],
#  ['Comedy'],
#  ['Fantasy', 'Drama', 'Thriller', 'Mystery', 'Romance'],
#  ['Drama', 'Romance', 'Comedy', 'Music'],
#  ['Action', 'Drama'],
#  ['Animation', 'Music', 'Family'],
#  ['Animation'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Romance', 'Comedy', 'Horror'],
#  ['Comedy', 'Adventure', 'Romance'],
#  ['Romance', 'Comedy', 'Crime', 'Fantasy'],
#  ['Drama', 'History', 'War'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Mystery'],
#  ['Comedy'],
#  ['Action', 'Adventure'],
#  ['Comedy', 'Horror'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy'],
#  ['Adventure', 'Drama'],
#  ['Drama', 'Action', 'Western', 'Music', 'Romance'],
#  ['Action', 'Animation', 'Science Fiction'],
#  ['Drama'],
#  ['Drama', 'Family'],
#  ['Comedy'],
#  ['Drama', 'Romance'],
#  ['Science Fiction'],
#  ['Drama', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Adventure', 'Drama'],
#  ['Comedy'],
#  ['Adventure', 'Action', 'Family'],
#  ['Documentary', 'Foreign', 'Music'],
#  ['Family', 'Comedy'],
#  ['Comedy'],
#  ['Action', 'Thriller'],
#  ['Family', 'Comedy'],
#  ['Comedy', 'Romance'],
#  ['Documentary'],
#  ['Horror', 'Fantasy', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Crime', 'Thriller'],
#  ['Horror', 'Thriller'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Comedy', 'Science Fiction', 'Thriller', 'Adventure'],
#  ['Horror', 'Thriller'],
#  ['Thriller', 'Comedy', 'Crime', 'Romance'],
#  ['Action', 'Drama'],
#  ['Animation', 'Drama', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'War'],
#  ['Action', 'Drama', 'Foreign', 'History', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction'],
#  ['Action', 'Fantasy', 'Science Fiction'],
#  ['Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Fantasy', 'Action', 'Comedy', 'Science Fiction'],
#  ['Action', 'Horror'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Action', 'War'],
#  ['Drama', 'History', 'Crime'],
#  ['Family', 'Fantasy'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller', 'Mystery'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Comedy'],
#  ['Family', 'Comedy', 'Animation', 'Adventure'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Animation', 'Adventure', 'Family', 'Comedy'],
#  ['Science Fiction', 'Action', 'Drama', 'Thriller'],
#  ['Fantasy', 'Mystery', 'Thriller'],
#  ['Crime', 'Drama', 'Romance', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Adventure', 'Fantasy', 'Drama', 'Comedy', 'Science Fiction', 'Family'],
#  ['Western', 'Drama', 'Adventure', 'Thriller'],
#  ['Drama', 'Action', 'Thriller', 'Crime'],
#  ['Action', 'Comedy', 'Romance'],
#  ['Comedy', 'Family', 'Fantasy'],
#  ['Comedy'],
#  ['Action', 'Thriller', 'Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Comedy'],
#  ['Romance', 'Adventure'],
#  ['Drama', 'Action', 'History'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['War', 'Action', 'Drama'],
#  ['Action', 'Drama'],
#  ['Drama'],
#  ['Thriller', 'Crime'],
#  ['Mystery', 'Drama', 'Fantasy'],
#  ['Drama'],
#  ['Drama', 'History'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Thriller', 'Crime'],
#  ['Comedy', 'Romance'],
#  ['War', 'Drama', 'Action'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Fantasy', 'Drama', 'Comedy', 'Family', 'Adventure'],
#  ['Adventure', 'Animation', 'Fantasy'],
#  ['Documentary'],
#  ['Drama', 'Action'],
#  ['Adventure', 'Action', 'Thriller'],
#  ['Comedy'],
#  ['Action', 'Comedy'],
#  ['Action', 'Crime'],
#  ['Documentary'],
#  ['Action', 'Adventure', 'Comedy', 'Drama', 'Mystery'],
#  ['Family', 'Animation', 'Drama'],
#  ['Action', 'War', 'Science Fiction'],
#  ['Fantasy', 'Drama'],
#  ['Family', 'Documentary', 'Adventure'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'War'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Science Fiction', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Family', 'Adventure', 'Comedy', 'Fantasy'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Thriller', 'Horror'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Comedy', 'Romance', 'Foreign'],
#  ['Action', 'Drama', 'Thriller', 'War'],
#  ['Comedy', 'Thriller', 'Drama'],
#  ['Horror', 'Science Fiction'],
#  ['Science Fiction'],
#  ['Animation', 'Family'],
#  ['Drama', 'Thriller', 'Crime'],
#  ['Animation', 'Family', 'Adventure'],
#  ['Drama', 'Music'],
#  ['Drama', 'Thriller', 'Action'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Family', 'Comedy'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Adventure', 'Drama', 'History'],
#  ['Drama'],
#  ['Family', 'Comedy'],
#  ['Comedy'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Documentary'],
#  ['Drama', 'Horror', 'Science Fiction', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'History', 'Romance', 'War'],
#  ['Comedy', 'Crime', 'Horror', 'Thriller'],
#  ['Romance', 'Comedy'],
#  ['Drama', 'History'],
#  ['Drama'],
#  ['Action'],
#  ['Action', 'Horror', 'Thriller', 'Science Fiction'],
#  ['Horror', 'Thriller', 'Mystery'],
#  ['Animation', 'Comedy', 'Fantasy'],
#  ['Thriller'],
#  ['Adventure', 'Comedy', 'Science Fiction'],
#  ['Drama'],
#  ['Horror', 'Action', 'Thriller', 'Science Fiction'],
#  ['Drama', 'History'],
#  ['Romance'],
#  ['Comedy', 'Romance'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Adventure', 'Horror', 'Thriller'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Foreign'],
#  ['Fantasy', 'Comedy', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Comedy'],
#  ['Crime', 'Thriller', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Fantasy'],
#  ['Comedy', 'Family'],
#  ['Comedy'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Comedy'],
#  ['Science Fiction', 'Thriller'],
#  ['Crime', 'Drama', 'Mystery'],
#  ['Action', 'Comedy', 'Crime', 'Romance'],
#  ['Adventure', 'Comedy', 'Drama', 'Science Fiction'],
#  ['Family', 'Adventure', 'Drama'],
#  ['Drama', 'History'],
#  ['Adventure', 'Action', 'Comedy'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Action', 'War'],
#  ['Drama', 'Thriller'],
#  ['Documentary'],
#  ['Mystery', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Adventure', 'Action', 'Science Fiction', 'Thriller'],
#  ['Fantasy', 'Drama', 'Comedy', 'Family'],
#  ['Action', 'Thriller'],
#  ['Thriller', 'Science Fiction', 'Adventure', 'Action'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Crime', 'Thriller'],
#  ['Music', 'Romance', 'Drama'],
#  ['Horror', 'Thriller', 'War'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror'],
#  ['Drama', 'Mystery'],
#  ['Drama'],
#  ['Romance', 'Comedy', 'Family'],
#  ['Thriller', 'Action', 'Crime'],
#  ['History', 'Drama'],
#  ['Comedy', 'Family'],
#  ['Drama', 'Science Fiction', 'Mystery'],
#  ['Comedy', 'Drama', 'Family'],
#  ['Comedy', 'Family', 'Science Fiction'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama'],
#  ['Adventure', 'Drama', 'Action', 'Romance', 'Family'],
#  [],
#  ['Comedy'],
#  ['Drama', 'Crime', 'Thriller'],
#  ['Action', 'Comedy', 'Drama', 'History'],
#  ['Family', 'Animation'],
#  ['Horror'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Fantasy', 'Drama', 'Comedy', 'Science Fiction', 'Romance'],
#  ['Western'],
#  ['Action', 'Adventure', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Crime', 'Drama', 'History'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Animation', 'Comedy', 'Drama', 'Fantasy'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'Horror', 'Science Fiction'],
#  ['Animation', 'Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Drama', 'History'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Action', 'Thriller'],
#  ['Horror', 'Mystery', 'Science Fiction'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Documentary'],
#  ['Animation', 'Comedy', 'Family'],
#  ['War', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Mystery', 'Crime', 'Drama'],
#  ['Western'],
#  ['Action', 'Drama', 'War'],
#  ['Comedy', 'Drama'],
#  ['Thriller', 'Crime', 'Action'],
#  ['Mystery', 'Drama', 'Thriller'],
#  ['Horror'],
#  ['Crime', 'Drama'],
#  ['Comedy', 'Drama', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Thriller', 'Science Fiction', 'Action', 'Crime'],
#  ['Drama', 'Music', 'Romance'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Romance', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama'],
#  ['Action', 'Crime', 'Drama'],
#  ['Documentary', 'Music'],
#  ['Drama'],
#  ['Drama', 'History'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Adventure', 'Action', 'Thriller', 'Crime'],
#  ['Adventure', 'Comedy', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Romance', 'Comedy', 'Crime'],
#  ['Comedy', 'Drama', 'Family', 'Fantasy', 'Romance'],
#  ['Drama'],
#  ['Documentary', 'Music'],
#  ['Family', 'Adventure'],
#  ['Action', 'Science Fiction', 'Adventure', 'Thriller'],
#  ['Drama', 'Romance'],
#  ['Drama', 'War'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Adventure', 'Action'],
#  ['Comedy', 'Documentary'],
#  ['Adventure', 'Family', 'Fantasy'],
#  ['Comedy', 'Drama'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Adventure', 'Fantasy', 'Action'],
#  ['Comedy', 'Drama', 'Music', 'Romance'],
#  ['Action', 'Adventure', 'Drama'],
#  ['Drama', 'Comedy'],
#  ['Thriller', 'Comedy', 'Fantasy', 'Horror'],
#  ['Horror', 'Thriller'],
#  ['Documentary'],
#  ['Thriller', 'Drama'],
#  ['Crime', 'Action', 'Science Fiction'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Crime', 'Romance', 'Drama'],
#  ['Animation', 'Science Fiction'],
#  ['Action', 'Adventure', 'Crime', 'Drama', 'Thriller'],
#  ['Adventure', 'Drama'],
#  ['Comedy'],
#  ['Comedy', 'Drama', 'History'],
#  ['Adventure', 'Family'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Drama', 'History', 'Western'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'Thriller'],
#  ['Science Fiction', 'Thriller'],
#  ['Horror', 'Thriller', 'Science Fiction'],
#  ['Horror'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Drama', 'History'],
#  ['Action', 'Science Fiction', 'Crime'],
#  ['Adventure', 'Animation', 'Comedy', 'Family'],
#  ['Drama'],
#  ['Action', 'Western', 'Drama'],
#  ['Comedy', 'Horror', 'Music'],
#  ['Drama', 'Comedy'],
#  ['Drama', 'Music'],
#  ['Horror', 'Action', 'Thriller', 'Crime'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Music'],
#  ['Action', 'Horror', 'Science Fiction'],
#  ['Horror', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Romance', 'Drama'],
#  ['Comedy'],
#  ['Romance', 'Comedy'],
#  ['Horror', 'Comedy', 'Fantasy'],
#  ['Comedy', 'Drama'],
#  ['Drama'],
#  ['Thriller', 'Drama'],
#  ['Action', 'Romance', 'War'],
#  ['Drama', 'Thriller'],
#  ['Adventure', 'Drama', 'Romance', 'Action'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Drama', 'Action', 'Crime', 'Thriller'],
#  ['Drama', 'History', 'War'],
#  ['Thriller', 'War', 'Adventure'],
#  ['Documentary'],
#  ['Drama'],
#  ['Fantasy', 'Animation', 'Romance', 'Family'],
#  ['Horror', 'Comedy', 'Action', 'Fantasy', 'Science Fiction'],
#  ['Thriller', 'Drama', 'Romance'],
#  ['Thriller', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Action', 'Adventure', 'Drama', 'War'],
#  ['Drama'],
#  ['Foreign', 'Drama'],
#  ['Family', 'Comedy'],
#  ['Comedy'],
#  ['Fantasy', 'Drama', 'Mystery'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama', 'War'],
#  ['Drama', 'History'],
#  ['Adventure', 'Fantasy', 'Action', 'Comedy', 'Family'],
#  ['Action', 'Comedy'],
#  ['Action', 'Adventure', 'Drama', 'History'],
#  ['Music', 'Drama'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy', 'Crime', 'Mystery', 'Romance', 'Thriller'],
#  ['Thriller', 'Action', 'Crime', 'Drama'],
#  ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#  ['Comedy'],
#  ['Drama', 'Family', 'Fantasy', 'Adventure'],
#  ['Adventure', 'Action', 'Comedy'],
#  ['Music', 'Drama', 'Romance'],
#  ['Adventure', 'Comedy'],
#  ['Drama', 'Romance'],
#  ['Drama'],
#  ['Romance', 'Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Thriller', 'Crime'],
#  ['Drama', 'Thriller'],
#  ['Science Fiction'],
#  ['Drama', 'Comedy', 'Music'],
#  ['Adventure', 'Animation', 'Comedy', 'Family'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama', 'Romance', 'Thriller', 'Western'],
#  ['Comedy', 'Drama'],
#  ['Crime', 'Horror', 'Mystery', 'Thriller'],
#  ['Science Fiction', 'Thriller'],
#  ['Romance', 'Drama', 'Comedy'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Fantasy', 'Drama'],
#  ['Action', 'Comedy', 'Science Fiction'],
#  ['Action', 'Thriller', 'Fantasy'],
#  ['Comedy', 'Romance'],
#  ['Drama'],
#  ['Horror', 'Thriller'],
#  ['Family'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Adventure', 'Fantasy'],
#  ['Drama', 'Music'],
#  ['Thriller'],
#  ['Comedy'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Music', 'Romance'],
#  ['Comedy', 'Drama', 'Crime'],
#  ['Action', 'Thriller'],
#  ['Action'],
#  ['Animation', 'Action', 'Family'],
#  ['Action', 'Adventure', 'Crime'],
#  ['Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Drama', 'Mystery', 'Romance', 'Thriller'],
#  ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Action', 'Adventure', 'Comedy', 'Fantasy'],
#  ['Drama', 'Crime'],
#  ['Action', 'Adventure', 'Comedy', 'Family'],
#  ['Family', 'Fantasy', 'Romance'],
#  ['Crime', 'Drama', 'Western'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy', 'Horror'],
#  ['Drama'],
#  ['Science Fiction', 'Adventure', 'Action'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Thriller', 'Crime', 'Drama', 'Mystery'],
#  ['Horror', 'Thriller', 'Romance'],
#  ['Romance', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Crime'],
#  ['Drama', 'War'],
#  ['Action', 'Comedy'],
#  ['Horror', 'Comedy', 'Music'],
#  ['Horror', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Documentary'],
#  ['Drama', 'Thriller', 'History'],
#  ['Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Adventure', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Adventure', 'Drama', 'Family'],
#  ['Action', 'History', 'War'],
#  ['Drama', 'Music', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Music', 'Comedy'],
#  ['Drama'],
#  ['Fantasy', 'Animation', 'Science Fiction', 'Family'],
#  ['Thriller', 'Horror'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Horror', 'Fantasy', 'Comedy'],
#  ['Drama', 'Action', 'Comedy', 'Thriller', 'Crime'],
#  ['Adventure', 'Fantasy', 'Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Adventure', 'Comedy', 'Crime', 'Mystery', 'Romance'],
#  ['Animation', 'Adventure', 'Comedy', 'Family'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Animation', 'Adventure', 'Family', 'Comedy'],
#  ['Adventure', 'Comedy', 'Family', 'Science Fiction'],
#  ['Drama', 'History', 'Romance'],
#  ['Drama'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Thriller', 'Crime'],
#  ['Action', 'Thriller'],
#  ['Family', 'Science Fiction'],
#  ['Comedy', 'Crime', 'Drama'],
#  ['Comedy'],
#  ['Thriller', 'Action', 'Comedy', 'Crime', 'Drama'],
#  ['Drama'],
#  ['Action', 'Thriller', 'Horror', 'Science Fiction'],
#  ['Drama', 'Music', 'Romance'],
#  ['Fantasy', 'Family'],
#  ['Romance', 'Comedy', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Thriller'],
#  ['Comedy', 'Documentary'],
#  ['Romance', 'Adventure', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Music'],
#  ['Thriller', 'Action', 'Crime', 'Drama'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Comedy'],
#  ['History', 'Drama', 'Thriller', 'Crime', 'Mystery'],
#  ['Comedy', 'Drama'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller'],
#  ['Drama', 'History', 'Romance'],
#  ['Action', 'Crime', 'Thriller'],
#  ['Adventure', 'Drama', 'Romance'],
#  ['Comedy'],
#  ['Drama'],
#  ['Action', 'History', 'War'],
#  ['War', 'Action', 'Drama', 'History', 'Thriller'],
#  ['Action', 'Crime', 'Drama'],
#  ['Drama', 'Romance'],
#  ['Documentary'],
#  ['Drama', 'Thriller'],
#  ['Documentary'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Romance'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Music'],
#  ['Adventure', 'Comedy', 'Family', 'Science Fiction'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Comedy', 'Crime'],
#  ['Drama', 'Romance'],
#  ['Comedy'],
#  ['Drama'],
#  ['Adventure', 'Documentary'],
#  ['Drama', 'History', 'War'],
#  ['Action', 'Thriller', 'Drama'],
#  ['Animation', 'Family'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Thriller', 'Horror', 'Action'],
#  ['War', 'Comedy', 'Drama', 'History'],
#  ['Drama', 'Romance', 'Comedy'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Thriller', 'Action', 'Adventure', 'Comedy', 'Crime'],
#  ['Thriller', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy'],
#  ['Animation', 'Family'],
#  ['Family', 'Animation', 'Adventure'],
#  ['Thriller'],
#  ['Comedy', 'Crime', 'Mystery'],
#  ['Drama', 'Crime'],
#  ['Drama', 'History', 'Thriller'],
#  ['Thriller'],
#  ['Romance', 'Comedy', 'Drama'],
#  ['Drama'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Drama', 'Thriller', 'Crime'],
#  ['Comedy'],
#  ['Mystery', 'Horror', 'Drama'],
#  ['Adventure', 'Animation', 'Comedy', 'Family'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Drama', 'Romance', 'Comedy'],
#  ['Drama', 'Mystery', 'Horror'],
#  ['Animation', 'Family'],
#  ['Drama', 'Romance'],
#  ['Action', 'Drama', 'History'],
#  ['Fantasy', 'Animation', 'Comedy'],
#  ['Drama'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Drama', 'Music', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Action', 'Crime', 'Drama'],
#  ['Action', 'Comedy'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Drama', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Action', 'Adventure', 'Science Fiction', 'Thriller'],
#  ['Drama', 'Thriller', 'Crime'],
#  ['Horror', 'Thriller'],
#  ['Drama'],
#  ['Comedy'],
#  ['Comedy', 'Romance'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Horror'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['Thriller', 'Adventure', 'Drama'],
#  ['Drama'],
#  ['Drama', 'Romance'],
#  ['Drama', 'Comedy'],
#  ['Drama'],
#  ['Comedy', 'Family'],
#  ['Drama'],
#  ['Comedy', 'Drama'],
#  ['Comedy', 'Romance'],
#  ['Documentary'],
#  ['Drama', 'Romance'],
#  ['Animation', 'Comedy', 'Family', 'Adventure'],
#  ['Drama', 'Thriller'],
#  ['Drama', 'Horror', 'Thriller'],
#  ['Comedy'],
#  ['Horror'],
#  ['Documentary'],
#  ['Documentary'],
#  ['Drama'],
#  ['Drama'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Drama', 'Romance'],
#  ['Romance', 'Drama', 'History'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Animation', 'Science Fiction'],
#  ['Comedy', 'Romance'],
#  ['Drama', 'Action', 'Thriller', 'Crime'],
#  ['Drama', 'History', 'Romance'],
#  ['Horror'],
#  ['Drama', 'Action', 'Thriller'],
#  ['Drama', 'Thriller'],
#  ['Drama', 'Thriller', 'Mystery'],
#  ['Comedy'],
#  ['Comedy'],
#  ['Drama', 'Thriller'],
#  ['Family', 'Fantasy', 'Adventure'],
#  ['Action', 'Fantasy', 'Thriller'],
#  ['Action', 'Drama', 'Thriller'],
#  ['Animation', 'Adventure', 'Family'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Drama', 'Foreign'],
#  ['History', 'Drama'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Horror', 'Thriller'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Comedy', 'Fantasy', 'Science Fiction'],
#  ['Documentary'],
#  ['Drama', 'Thriller'],
#  ['Thriller'],
#  ['Thriller', 'Adventure', 'History', 'Drama'],
#  ['Music', 'Drama', 'Romance', 'Crime'],
#  ['Adventure', 'Drama', 'Fantasy', 'Romance'],
#  ['Action', 'Adventure', 'Animation', 'Comedy', 'Drama', 'Family'],
#  ['Action', 'Comedy', 'Drama'],
#  ['Action', 'Thriller'],
#  ['Documentary'],
#  ['Adventure', 'Action'],
#  ['Action', 'Adventure', 'Comedy', 'Drama', 'Thriller'],
#  ['Comedy'],
#  ['Comedy', 'Romance', 'Drama'],
#  ['Action', 'Crime', 'Drama', 'Thriller'],
#  ['Drama'],
#  ['Drama'],
#  ['Horror', 'Science Fiction', 'Thriller'],
#  ['Drama'],
#  ['Drama', 'Adventure'],
#  ['Action', 'Drama'],
#  ['Crime', 'Drama', 'Thriller'],
#  ['History', 'Thriller', 'War'],
#  ['Action', 'Drama', 'History'],
#  ['Crime', 'Comedy', 'Thriller'],
#  ['Comedy'],
#  ['Drama', 'Family', 'Romance'],
#  ['Action', 'Drama', 'Romance'],
#  ['Horror'],
#  ['Horror', 'Thriller'],
#  ['Romance', 'Animation', 'Family', 'Comedy', 'Adventure'],
#  ['Drama'],
#  ['Comedy'],
#  ['Drama', 'Comedy'],
#  ['Thriller', 'Crime', 'Mystery'],
#  ['Action', 'Family', 'Fantasy'],
#  ['History', 'Action', 'Adventure'],
#  ['Family', 'Fantasy', 'Science Fiction', 'Adventure', 'Comedy'],
#  ['Action'],
#  ['Family', 'Animation', 'Adventure'],
#  ['Crime', 'Action', 'Science Fiction'],
#  ['Action', 'Science Fiction', 'Thriller', 'Western'],
#  ['Thriller', 'Action', 'Crime'],
#  ['Comedy'],
#  ['Crime', 'Drama', 'Family', 'Thriller'],
#  ['Action', 'Drama'],
#  ['Comedy', 'Drama'],
#  ['Drama', 'Action', 'Thriller', 'Romance'],
#  ['Drama'],
#  ['Fantasy', 'Adventure', 'Action', 'Family', 'Romance'],
#  ['Drama', 'Thriller'],
#  ['Adventure', 'Fantasy', 'Animation', 'Science Fiction', 'Family'],
#  ['Action', 'Adventure', 'Drama', 'Thriller'],
#  ['Comedy', 'Drama'],
#  ['Action', 'Thriller', 'Romance'],
#  ['Drama'],
#  ['Action', 'Adventure', 'Thriller', 'War'],
#  ['Comedy', 'Crime'],
#  ['Action'],
#  ['Adventure', 'Family'],
#  ['Romance', 'Comedy'],
#  ['Romance', 'Comedy'],
#  ['Crime', 'Drama', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Documentary'],
#  ['Horror', 'Mystery', 'Thriller'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Comedy', 'Family', 'Fantasy', 'Science Fiction'],
#  ['Comedy'],
#  ['Adventure', 'Fantasy', 'Family'],
#  ['Action', 'Comedy', 'Crime', 'Thriller'],
#  ['Thriller'],
#  ['Drama', 'War', 'History'],
#  ['Comedy'],
#  ['Romance', 'Drama'],
#  ['Drama', 'Comedy', 'Romance'],
#  ['Thriller', 'Science Fiction'],
#  ['Thriller', 'Adventure', 'Action'],
#  ['Romance', 'Action'],
#  ['Horror', 'Thriller'],
#  ['Drama', 'History', 'Mystery', 'Thriller'],
#  ['Drama'],
#  ['Science Fiction', 'Action', 'Adventure'],
#  ['Family', 'Animation'],
#  ['Fantasy', 'Drama'],
#  ['Comedy'],
#  ['Adventure', 'Drama', 'Action', 'History', 'War'],
#  ['Drama', 'Family'],
#  ['Horror', 'Thriller', 'Fantasy', 'Mystery'],
#  ['Comedy', 'Drama', 'Romance'],
#  ['Crime', 'Thriller'],
#  ['Drama', 'Horror', 'Science Fiction', 'Thriller'],
#  ['Action', 'Crime'],
#  ['Documentary', 'Crime'],
#  ['Drama', 'Comedy'],
#  ['Drama'],
#  ['Drama'],
#  ['Comedy'],
#  ['Documentary', 'Action', 'Adventure'],
#  ['Drama'],
#  ['Comedy', 'Music', 'Romance'],
#  ['Action', 'Adventure', 'Romance', 'Science Fiction'],
#  ['Action', 'Comedy', 'Crime'],
#  ['Drama', 'Horror', 'Science Fiction'],
#  ['Action', 'Adventure', 'Drama', 'Horror', 'Science Fiction'],
#  ['Horror', 'Mystery', 'Crime'],
#  ['Comedy', 'Family'],
#  ['Comedy', 'Drama'],
#  ...]

# %% [markdown]
# Lets print out most occuring genres,

# %%
Counter([i for j in genre_list for i in j]).most_common()
# Out:
# [('Drama', 1531),
#  ('Comedy', 1028),
#  ('Thriller', 789),
#  ('Action', 741),
#  ('Romance', 571),
#  ('Crime', 469),
#  ('Adventure', 439),
#  ('Horror', 301),
#  ('Science Fiction', 290),
#  ('Family', 260),
#  ('Fantasy', 232),
#  ('Mystery', 225),
#  ('Animation', 141),
#  ('History', 132),
#  ('Music', 100),
#  ('War', 100),
#  ('Documentary', 87),
#  ('Western', 43),
#  ('Foreign', 31),
#  ('TV Movie', 1)]

# %% [markdown]
# It is seen that Drama , comedy , thriller are most represented movies in the dataset.

# %%
train['num_genres'] = train['genres'].apply(lambda x: len(x) if x != {} else 0)
train['all_genres'] = train['genres'].apply(lambda x: ' '.join(sorted([i['name'] for i in x])) if x != {} else '')
top_genres = [m[0] for m in Counter([i for j in genre_list for i in j]).most_common(15)]
for g in top_genres:
    train['genre_' + g] = train['all_genres'].apply(lambda x: 1 if g in x else 0)
    
    
test['num_genres'] = test['genres'].apply(lambda x: len(x) if x != {} else 0)
test['all_genres'] = test['genres'].apply(lambda x: ' '.join(sorted([i['name'] for i in x])) if x != {} else '')
for g in top_genres:
    test['genre_' + g] = test['all_genres'].apply(lambda x: 1 if g in x else 0)

train = train.drop(['genres'], axis=1)
test = test.drop(['genres'], axis=1)

# %%
train[['all_genres','genre_Comedy','genre_Drama']].head()
# Out:
#                     all_genres  genre_Comedy  genre_Drama
# 0                       Comedy             1            0
# 1  Comedy Drama Family Romance             1            1
# 2                        Drama             0            1
# 3               Drama Thriller             0            1
# 4              Action Thriller             0            0

# %% [markdown]
# ### Production Companies

# %%
for i,e in enumerate(train['production_companies'].head()):
    print(i,e)
# Out:
# 0 [{'name': 'Paramount Pictures', 'id': 4}, {'name': 'United Artists', 'id': 60}, {'name': 'Metro-Goldwyn-Mayer (MGM)', 'id': 8411}]
# 1 [{'name': 'Walt Disney Pictures', 'id': 2}]
# 2 [{'name': 'Bold Films', 'id': 2266}, {'name': 'Blumhouse Productions', 'id': 3172}, {'name': 'Right of Way Films', 'id': 32157}]
# 3 {}
# 4 {}

# %% [markdown]
# Lets follow the same procedure as we did for genre.

# %%
prod_comp_list=list(train['production_companies'].apply(lambda x:[i['name'] for i in x] if x!={} else []).values)

# %%
prod_comp_list
# Out:
# [['Paramount Pictures', 'United Artists', 'Metro-Goldwyn-Mayer (MGM)'],
#  ['Walt Disney Pictures'],
#  ['Bold Films', 'Blumhouse Productions', 'Right of Way Films'],
#  [],
#  [],
#  [],
#  ['Ghost House Pictures', 'North Box Productions'],
#  [],
#  ['Walt Disney Pictures', 'Jim Henson Productions', 'Jim Henson Company, The'],
#  ['Castle Rock Entertainment'],
#  ['United Artists'],
#  ['Twentieth Century Fox Film Corporation',
#   'Amercent Films',
#   'American Entertainment Partners L.P.',
#   'Interscope Communications'],
#  ['DreamWorks SKG', 'Jinks/Cohen Company'],
#  ['Double Feature Films',
#   'Jersey Films',
#   'Nina Saxon Film Design',
#   'Metro-Goldwyn-Mayer (MGM)'],
#  ['DreamWorks SKG',
#   'Cruise/Wagner Productions',
#   'Amblin Entertainment',
#   'Twentieth Century Fox Film Corporation',
#   'Blue Tulip Productions',
#   'Ronald Shusett/Gary Goldman',
#   'Digital Image Associates'],
#  ['Hypnopolis'],
#  ['DreamWorks SKG', 'Craven-Maddalena Films', 'BenderSpink'],
#  ['BBC Films',
#   'Headline Pictures',
#   'Magnolia Mae Films',
#   'Taeoo Entertainment'],
#  ['UK Film Council', 'Prescience', 'Aegis Film Fund', 'Kaleidoscope Films'],
#  ['Twentieth Century Fox Film Corporation',
#   'Current Entertainment',
#   'TF1 Films Production',
#   'Canal+',
#   'TPS Star',
#   'EuropaCorp',
#   'Sea Side Films Florida Inc.'],
#  ['New Line Cinema',
#   'Irwin Allen Productions',
#   'Prelude Pictures',
#   'Saltire Entertainment'],
#  ['Paramount Pictures', 'Jason Productions'],
#  ['The Collective', 'Bloody Disgusting', '8383 Productions'],
#  ['\xa0Braeburn Entertainment', '\xa0Check Entertainment', 'G.C. Pix\xa0'],
#  ['New Zealand Film Commission', 'Live Stock Films'],
#  ['Universal Pictures',
#   'Dark Horse Entertainment',
#   'Largo Entertainment',
#   'JVC Entertainment Networks'],
#  ['Jean Doumanian Productions',
#   'Sweetland Films',
#   'Magnolia Films',
#   'Jasmine Productions Inc.'],
#  ['Fastnet Films', 'Caramel Film', 'No Trace Camping'],
#  ['De Laurentiis Entertainment Group (DEG)',
#   'Marvel Productions',
#   'Hasbro',
#   'Sunbow Productions'],
#  ['Paramount Pictures'],
#  ['Gaumont',
#   'TF1 Films Production',
#   'Canal+',
#   'CinéCinéma',
#   'Quad Productions',
#   'Chaocorp',
#   'Ten Films',
#   'TF1'],
#  ['Les Films du Losange',
#   'Wega Film',
#   'BIM Distribuzione',
#   'Centre National de la Cinématographie',
#   'Filmstiftung Nordrhein-Westfalen',
#   'France 3 Cinéma',
#   'Eurimages',
#   'Bavaria Film',
#   'Canal+',
#   'Studio Canal',
#   'Arte France Cinéma',
#   'Westdeutscher Rundfunk (WDR)',
#   'Filmfonds Wien',
#   'ORF Film/Fernseh-Abkommen',
#   'Österreichisches Filminstitut'],
#  ['Summit Entertainment',
#   'Atmosphere Entertainment MM',
#   'One Race Films',
#   'Goldmann Pictures',
#   'NeoReel',
#   'Aperture Entertainment',
#   'TIK Films'],
#  ['Magnet Releasing', 'Drafthouse Films', 'Timpson Films'],
#  ['New Line Cinema'],
#  ['Lawrence Bender Productions',
#   'IM Global',
#   'Automatik Entertainment',
#   'Trigger Street Productions',
#   '87Eleven'],
#  ['Bórd Scannán na hÉireann',
#   'British Broadcasting Corporation (BBC)',
#   'Venus Productions'],
#  ['Kopelson Entertainment',
#   'Punch Productions',
#   'Warner Bros.',
#   'Arnold Kopelson Productions'],
#  [],
#  ['Columbia Pictures Corporation', 'Jerry Bresler Productions'],
#  ['Rakontur'],
#  ['Warner Bros.', 'Jalem Productions'],
#  ['Paramount Pictures', 'Lakeshore Entertainment'],
#  ['Revelations Entertainment', 'Lascaux Films', 'Latitude Productions'],
#  ['26 Films', 'Gold Circle Films', 'Visionview Production'],
#  ['Indigo Film', 'Medusa Film'],
#  ['Blue Sky Studios', 'Twentieth Century Fox Animation'],
#  ['Double Feature Films', 'The Weinstein Company', 'FilmColony'],
#  ['Ad Hominem Enterprises'],
#  ['Paramount Pictures'],
#  [],
#  ['Warner Bros.'],
#  ['Walt Disney Productions'],
#  ['TriStar Pictures'],
#  ['Columbia Pictures',
#   'Affirm Films',
#   'LD Entertainment',
#   'Patrick Aiello Productions'],
#  ['Hollywood Pictures'],
#  ['Mon Voisin Productions'],
#  ['PolyGram Filmed Entertainment', 'Warner Bros.'],
#  ['Speak Productions'],
#  ['New Line Cinema'],
#  ['Eon Productions', 'Stillking Films', 'Babelsberg Film'],
#  ['Joanna Productions'],
#  ['Atlas Entertainment', 'Turner Pictures (I)'],
#  ['Paramount Pictures', 'Sean S. Cunningham Films', 'Horror Inc.'],
#  ['Paramount Vantage', 'Bona Fide Productions'],
#  ['Cannon Films'],
#  ['Company Films', 'Moving Pictures Film and Television'],
#  ['Office Kitano', 'Xstream Pictures', 'Shanghai Film Group'],
#  ['Universal Pictures'],
#  ['Universal Pictures'],
#  ['Section Eight',
#   'Mandalay Pictures',
#   'VIP 3 Medienfonds',
#   '2929 Productions',
#   'Rising Star',
#   'VIP 2 Medienfonds',
#   'Warner Independent Pictures (WIP)'],
#  ['Senator Film Produktion',
#   'Wildwood Enterprises',
#   'Sound for Film',
#   'Inca Films S.A.',
#   'Filmfour',
#   'BD Cine',
#   'Tu Vas Voir Productions',
#   'Sahara Films'],
#  ['Imagine Entertainment', 'Universal Pictures'],
#  [],
#  ['New World Pictures'],
#  ['Touchstone Pictures'],
#  [],
#  ['Orion Pictures', 'Warner Bros.'],
#  ['Warner Bros.', 'Deliverance Productions'],
#  ['Spectacle Entertainment Group',
#   'Windy Hill Pictures',
#   'Protagonist Pictures',
#   'Bow and Arrow Entertainment',
#   'PalmStar Media'],
#  ['United Artists',
#   'Intermedia Films',
#   'IM Filmproduktion',
#   'Cosmic Pictures',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Alphaville Films'],
#  ['Epsilon Motion Pictures',
#   'Hyde Park Films',
#   'Shopgirl',
#   'Touchstone Pictures'],
#  ['Universal Pictures',
#   'MFPV Film',
#   'Double Feature Films',
#   'ShadowCatcher Entertainment',
#   'Daniel Bobker Productions',
#   'Brick Dust Productions LLC'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Elle Driver', 'Tazora Films'],
#  ['Paramount Pictures', 'Kennedy/Marshall Company, The'],
#  ['Columbia Pictures'],
#  ['New Line Cinema', 'Golden Harvest Company'],
#  ['Scion Films', 'LD Entertainment', 'Czech Anglo Productions'],
#  ['Canal Plus', 'Regency Enterprises', 'Alcor Films'],
#  ['Miramax Films', 'A Band Apart', 'Super Cool ManChu'],
#  ['R%26C Produzioni', 'Les Films Balenciaga'],
#  ['France 2 Cinéma', 'Hachette Première', 'Canal+'],
#  ['Blast! Films'],
#  ['Asymmetrical Productions',
#   'Les Films Alain Sarde',
#   'Babbo Inc.',
#   'The Picture Factory',
#   'Canal+'],
#  ['Yellow, Black & White'],
#  ['Procirep',
#   'Canal+',
#   'Film Fund Luxembourg',
#   'Centre National de la Cinématographie (CNC)',
#   'Media Programme of the European Community',
#   'Ciné+'],
#  ['Ren Film'],
#  ['Studio Canal'],
#  ['Orion Pictures'],
#  ['Epic Productions',
#   'Vision International',
#   'Vision PDG',
#   'Trans World Entertainment (TWE)'],
#  ['Imagine Entertainment', 'DreamWorks SKG', 'Universal Pictures'],
#  ['Barunson Film Division',
#   'Film It Suda',
#   'Sio Film and Bravo Entertainment'],
#  ['Gran Via Productions', 'Walden Media', 'Lemodeln Model & Talent Agency'],
#  ['Çamaşırhane', 'Kinostar', 'Tiglon', 'Emrah Gamsızoğlu'],
#  ['Isle of Man Film',
#   'DJ Films',
#   'British Film Institute (BFI)',
#   'Pinewood Studios',
#   'Metrol Technology'],
#  ['Double Feature Films', 'CBS Films'],
#  ['Icon Entertainment International', 'The Ladd Company', 'B.H. Finance C.V.'],
#  ['Miramax Films', 'Pyramide Productions'],
#  ['The Mirisch Corporation'],
#  ['Cheyenne Enterprises',
#   'Epsilon Motion Pictures',
#   'Empire Pictures',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Hyde Park Entertainment',
#   'Baltimore Spring Creek Productions',
#   'Lotus Pictures'],
#  ['Revolution Studios', 'Blue Star Pictures'],
#  ['Imagine Entertainment',
#   'Spring Creek Productions',
#   'Warner Bros.',
#   'Roth Films',
#   'K. JAM Media',
#   'Cott Productions',
#   'Surf Film',
#   'Enelmar Productions, A.I.E.'],
#  ['Universal Pictures', 'Rastar Pictures'],
#  ['WingNut Films', 'New Line Cinema', 'The Saul Zaentz Company'],
#  ['Universal Pictures'],
#  ['Emperor Motion Pictures',
#   'Media Asia Films',
#   'Sil-Metropole Organisation Ltd.',
#   'Huayi Brothers Media',
#   'China Film Co.',
#   'Chongoing Film Group',
#   'Bon Voyage Film Studio',
#   'Shanghai Media Group',
#   'Zhejiang Films & TV(Group) Company Ltd.',
#   'Hunan Broadcasting System',
#   'Anhui Broadcasting Corp.',
#   'Beijing TV Station'],
#  ['Wild Hogs Productions', 'Touchstone Pictures'],
#  ['Mainline Pictures'],
#  ['Golden Harvest Company'],
#  ['New Line Cinema'],
#  ['Walt Disney Pictures'],
#  ['TriStar Pictures'],
#  ['Silver Pictures', 'Warner Bros.'],
#  ['Fox Searchlight Pictures', 'Watermark', 'Dune Entertainment III'],
#  ['Australian Film Finance Corporation',
#   'Zero Fiction Film',
#   'Ming Productions',
#   'Bluewater Pictures',
#   'Cheerland Entertainment Organization'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Lakeshore Entertainment', 'Alphaville Films'],
#  ['Revolution Studios', 'Debra Hill Productions'],
#  ['Columbia Pictures', '40 Acres & A Mule Filmworks'],
#  ['BBC Films',
#   'StudioCanal',
#   'Baby Cow Productions',
#   'British Film Institute (BFI)',
#   'Baby Cow Films'],
#  [],
#  ['Discovery Channel Pictures'],
#  ['Legendary Pictures', 'Green Hat Films', 'Warner Bros.'],
#  ['Entertainment Films', 'Material Entertainment', 'Beech Hill Films'],
#  ['Fandango',
#   'Vertigo Productions',
#   'SBS Independent',
#   'Adelaide Film Festival'],
#  [],
#  ['Paul Schiff Productions'],
#  ['ArieScope Pictures', 'A Bigger Boat'],
#  ['Twentieth Century Fox Film Corporation',
#   "Donners' Company",
#   'Bad Hat Harry Productions',
#   'Marvel Enterprises',
#   'XM2 Productions',
#   'XF2 Canada Productions'],
#  ['Twentieth Century Fox Film Corporation', 'Robert Wise Productions'],
#  ['Wild Bear Films', 'Archer Street Productions', 'Delux Productions'],
#  ['Duplass Brothers Productions'],
#  ['Senator Entertainment Co'],
#  ['Warner Bros.'],
#  ['Killer Films', 'Parts and Labor', 'FullDawa Films'],
#  ['Warner Bros.'],
#  ['CJ Entertainment',
#   'Opus Pictures',
#   'Stillking Films',
#   'SnowPiercer',
#   'Moho Film'],
#  ['Universal Pictures', 'Northern Lights Entertainment'],
#  ['Social Capital',
#   'Film Afrika Worldwide',
#   'Lipsync Productions',
#   'Procinvest Sas',
#   'Cinedigm',
#   'Magnet Media Productions',
#   'Magnet Media Group',
#   'Mirabelle Pictures',
#   'Alliance Cinema'],
#  ['Windwalker', 'Santa Fe International'],
#  ['Whitewater Films', 'Very Special Projects', 'WRA Productions'],
#  [],
#  ['Universal Pictures',
#   'Nuyorican Productions',
#   'Blumhouse Productions',
#   'Smart Entertainment'],
#  ['Magnum Motion Pictures Inc..'],
#  ['Walt Disney Pictures',
#   'Walt Disney Television Animation',
#   'Walt Disney Animation Australia',
#   'DisneyToon Studios',
#   'Walt Disney Animation Canada'],
#  [],
#  ['Global Pictures'],
#  ['Franchise Pictures',
#   'Warner Bros.',
#   'Morgan Creek Productions',
#   'The Canton Company'],
#  ['TriStar Pictures'],
#  ['Yari Film Group', 'Stratus Film Co.'],
#  ['Universal Pictures', 'Jascat'],
#  ['Ada Films'],
#  ['Touchstone Pictures'],
#  ['Village Roadshow Pictures',
#   'Dark Castle Entertainment',
#   'Warner Bros.',
#   'Eyetronics',
#   'Chime Films'],
#  [],
#  ['IRE Productions', 'Santa Fe Institute for Regional Education'],
#  ['Lakeshore Entertainment', 'Firm Films', 'Screen Gems'],
#  ['United Artists',
#   'Jewel Productions',
#   'Pimlico Films',
#   'Incorporated Television Company (ITC)'],
#  ['Kennedy Miller Productions'],
#  ['Warner Bros.', 'The Ladd Company'],
#  ['Filmhaus'],
#  ['Warner Bros.'],
#  ['Columbia Pictures Corporation', 'Price Entertainment'],
#  ['Parabolic Pictures',
#   'Stable Way Entertainment',
#   'Quickfire Films',
#   'Screen Australia',
#   'Screen NSW',
#   'Ingenious Broadcasting',
#   'Unthank Films',
#   'Story Bridge Films',
#   'Auburn Entertainment'],
#  ['Universal Pictures',
#   'Original Film',
#   'Ardustry Entertainment',
#   'Mediastream Film GmbH & Co. Productions KG'],
#  ['United Artists',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Hammerhead Productions',
#   'Screenland Pictures'],
#  ['Stand See'],
#  ['Orion Pictures'],
#  ['Eon Productions'],
#  ['New Line Cinema',
#   'Solaris Film',
#   'Avery Pix',
#   "O'Connor Brothers",
#   'Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG'],
#  ['Film Council', 'Scottish Screen', 'Bórd Scannán na hÉireann'],
#  ['Twentieth Century Fox Film Corporation', 'Hughes Entertainment'],
#  ['Toho Company', 'Sedic International'],
#  ['Original Film',
#   'Columbia Pictures Corporation',
#   'Revolution Studios',
#   'Happy Madison Productions'],
#  ['Steve White Entertainment'],
#  ['Alliance Films'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Walt Disney Pictures', 'Pixar Animation Studios', 'FortyFour Studios'],
#  ['Lionsgate', '34th Street Films'],
#  ['Miramax Films', 'Dimension Films', 'Trans Atlantic Entertainment'],
#  ['Alcon Entertainment',
#   'Lionsgate',
#   'Phoenix Pictures',
#   'What to Expect Productions'],
#  ['Fox Searchlight Pictures', 'British Film Company'],
#  ['Cannon Group', 'Cannon Films', 'Metro-Goldwyn-Mayer (MGM)'],
#  ['Werc Werk Works'],
#  ['Majid Majidi Film Production'],
#  ['Smart Egg Pictures'],
#  ['Twentieth Century Fox Film Corporation',
#   'Dune Entertainment',
#   'Major Studio Partners',
#   'Regency Enterprises',
#   'Epsilon Motion Pictures',
#   'New Regency Pictures',
#   'Sentinel Productions',
#   'Furthur Films'],
#  ['Bel Air Entertainment', 'Warner Bros.'],
#  ['Fox Searchlight Pictures', 'Chernin Entertainment'],
#  ['Paramount Pictures', 'Kerner Entertainment Company'],
#  ['De Laurentiis Entertainment Group (DEG)', 'Kestrel Films', 'Earth Girls'],
#  ['Reel FX Creative Studios', 'Relativity Media'],
#  ['Gracie Films', 'Twentieth Century Fox Film Corporation'],
#  ['Night Light Films'],
#  ['Itaca Films',
#   'BN Films',
#   'Brightside Entertainment',
#   '1019 Entertainment',
#   'Yoruba Saxon Productions'],
#  ['IRS Media'],
#  ['Twentieth Century Fox Film Corporation',
#   'Saban Entertainment',
#   'Toei Company'],
#  ['Admire Productions Ltd.', 'Coral Productions', 'Triumph Films'],
#  ['Casey Silver Productions', 'Touchstone Pictures', 'Dune Films'],
#  ['Hollywood Pictures', 'Cometstone Pictures'],
#  ['Universal Pictures', 'Zanuck/Brown Productions'],
#  ['Hollywood Pictures'],
#  ['SLB Films Pvt. Ltd.'],
#  ['Bleiberg Entertainment', 'Millennium Films'],
#  ['Stuber Productions', 'Aggregate Films', 'DumbDumb'],
#  ['Toho'],
#  ['Columbia Pictures Industries'],
#  ['Europa Film', 'Viking Films', 'Rifilm'],
#  [],
#  ['Media Asia Films',
#   'China Film Group Corporation (CFGC)',
#   'Stellar Megamedia',
#   'Jiangsu Broadcasting System',
#   'Chuan Production Film Studio'],
#  ['Twentieth Century Fox Film Corporation', 'Penta Pictures'],
#  [],
#  ['TriStar Pictures', 'Canal+', 'Carolco Pictures'],
#  ['Apostle', 'Type 55 Films'],
#  ['StudioCanal',
#   'The Australian Film Commission',
#   'Endymion Films',
#   'Australian Film Finance Corporation (AFFC)',
#   'Working Title Films',
#   'WTA',
#   'Woss Group Film Productions'],
#  ['Summit Entertainment',
#   'Saturn Films',
#   'Nu Image Films',
#   'Millennium Films',
#   'Michael De Luca Productions'],
#  ['BBC Films'],
#  ['Warner Brothers/Seven Arts'],
#  ['Merchant Ivory Productions', 'Touchstone Pictures'],
#  ['Studio Babelsberg',
#   'Walden Media',
#   'Babelsberg Film',
#   'Mostow/Lieberman Productions',
#   '80 Days Productions',
#   'Spanknyce Films',
#   'Fitzwilliam Productions'],
#  ['Ruby in Paradise', 'Full Crew/Say Yea'],
#  ['Le Bureau', 'Film4', 'Free Range Films'],
#  [],
#  ['Plan B Entertainment',
#   'Northern Ireland Screen',
#   'Sierra / Affinity',
#   'MICA Entertainment',
#   'MadRiver Pictures',
#   'Keep Your Head'],
#  ['New Line Cinema', 'Michael Phillips Productions'],
#  ['Universal Pictures',
#   'Tales From The Crypt Holdings',
#   'Universal City Studios'],
#  ['Impala', 'In-Cine Compania Industrial Cinematografica'],
#  ['Paramount Pictures'],
#  ['Fox 2000 Pictures'],
#  ['Orion Pictures', 'Kouf/Bigelow Productions'],
#  ['Prana Animation Studios', 'Summertime Entertainment'],
#  ['Madhouse', 'Warner Bros. Japan'],
#  ['Paramount Pictures', 'Egg Pictures', 'PolyGram Filmed Entertainment'],
#  ['Melvin Simon Productions', 'American International Pictures (AIP)'],
#  ['Summit Entertainment', 'Alloy Entertainment', 'Goldcrest Pictures'],
#  ['New Line Cinema', 'Dark Horse Entertainment'],
#  ['Degeto Film',
#   'EOS Entertainment',
#   'Rai Cinema',
#   'Österreichischer Rundfunk (ORF)',
#   'Constantin Film Produktion',
#   'Westdeutscher Rundfunk (WDR)',
#   'Norddeutscher Rundfunk (NDR)'],
#  ['Village Roadshow Pictures',
#   'NPV Entertainment',
#   'Silver Pictures',
#   'Warner Bros.',
#   'Jonathan Krane Group'],
#  ['EMI Films Ltd.', 'Mersham Productions'],
#  ['TPS Cinéma',
#   'TF1 Films Production',
#   'M6 Métropole Télévision',
#   'Télégraphe',
#   'Vertigo'],
#  ['Le Studio Canal+',
#   'Laurence Mark Productions',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Carolco Pictures'],
#  ['Fox Searchlight Pictures',
#   'Broken Lizard Industries',
#   'Coconut Pete Productions'],
#  [],
#  ['APT Entertainment', 'Star Cinema Productions', 'Cinemalaya Foundation'],
#  ['Darko Entertainment', 'Aggregate Film'],
#  ['Universal Pictures',
#   'Working Title Films',
#   'Walden Media',
#   'Cross Creek Pictures',
#   'Free State Pictures',
#   'RVK Studios'],
#  ['Twentieth Century Fox Film Corporation'],
#  ['Bandai Visual Company', 'Kodansha', 'Production I.G.'],
#  [],
#  ['Columbia Pictures Corporation'],
#  ['Columbia Pictures',
#   'Intermedia Films',
#   'Relativity Media',
#   'Red Wagon Entertainment',
#   'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG',
#   'RV Camping Productions Ltd.'],
#  ['Asmik Ace Entertainment',
#   'Fuji Television Network',
#   'WoWow',
#   'Dentsu',
#   'Kodansha',
#   'Sumitomo Corporation',
#   'Sankei Shimbun'],
#  ['Orion Pictures', 'ERP Productions'],
#  [],
#  ['40 Acres & A Mule Filmworks', 'Touchstone Pictures'],
#  ['Paramount Vantage',
#   'River Road Entertainment',
#   'Art Linson Productions',
#   'Into the Wild'],
#  ['Miramax Films', 'View Askew Productions'],
#  ['Isle of Man Film', 'Weinstein Company, The', 'Samuelson Productions'],
#  [],
#  ['Fox 2000 Pictures', 'Color Force'],
#  ['Columbia Pictures', 'Apatow Productions'],
#  ['Twentieth Century Fox Film Corporation',
#   'Steamroller Productions',
#   'Victor & Grais Productions'],
#  ['Twentieth Century Fox Film Corporation'],
#  ['Warner Bros.'],
#  ['Universal Pictures',
#   'Universal Pictures International (UPI)',
#   'Jigsaw',
#   'Global Produce'],
#  [],
#  ['Caravan Pictures',
#   'Roger Birnbaum Productions',
#   'Northern Lights Entertainment',
#   'Touchstone Pictures'],
#  ['Killer Films', 'Rabbit Bandini Films', 'Great Point Media'],
#  ['Paramount Pictures',
#   'DreamWorks SKG',
#   'Parkes/MacDonald Productions',
#   'Edge City'],
#  ['Destination Films'],
#  ['Lionsgate', 'Mutant Enemy Productions'],
#  ['New Line Cinema', 'Jersey Films'],
#  ['France 2 Cinéma',
#   'Canal+',
#   'Studio Canal',
#   'TPS Star',
#   'Ce Qui Me Meut Motion Pictures',
#   'StudioCanal Image',
#   'Uni Etoile 4'],
#  ['Emmett/Furla Films',
#   'Exclusive Media Group',
#   'Hedge Fund Film Partners',
#   'Crave Films',
#   'Knightsbridge Entertainment',
#   'Le Grisbi Productions',
#   '5150 Action'],
#  ['Goldcrest Films International',
#   'Peter Newman/Interal',
#   'Mary Breen-Farrelly Productions',
#   'Irish Film Industry',
#   'Pachyderm Production'],
#  ['Universal Pictures', 'Blumhouse Productions', 'Blinding Edge Pictures'],
#  ['Savoy Pictures'],
#  ['DreamWorks Pictures'],
#  ['Warner Bros.', 'Don Bluth Productions'],
#  ['Channel Four Films',
#   'PolyGram Filmed Entertainment',
#   'Working Title Films'],
#  ['Miramax Films', 'Spyglass Entertainment'],
#  ['Legendary Pictures', '3 Arts Entertainment', 'Jolie Pas'],
#  ['Miramax Films', 'Columbia TriStar'],
#  ['Studio Babelsberg', 'Lionsgate', 'Color Force'],
#  ['Art Pictures Studio'],
#  ['Universal Pictures',
#   'Spyglass Entertainment',
#   'Shady Acres Entertainment',
#   'Gran Via Productions',
#   'Kalima Productions GmbH & Co. KG',
#   'NDE Productions'],
#  ['Silver Pictures', 'Warner Bros.'],
#  ['Touchstone Pictures', 'Silver Screen Partners IV'],
#  ['Hemdale Film Corporation'],
#  ['Universal Pictures', 'No Frills Film Production'],
#  ['Paramount Pictures'],
#  ['United Artists'],
#  ['Hollywood Pictures'],
#  ['Golan-Globus Productions', 'The Cannon Group'],
#  ['Miramax Films',
#   'Initial Entertainment Group (IEG)',
#   'Alberto Grimaldi Productions'],
#  ['Village Roadshow Pictures',
#   'Legendary Pictures',
#   'Playtone',
#   'Wild Things Productions',
#   'Warner Bros.'],
#  ['Appian Way', 'Warner Bros.', 'Pearl Street Films'],
#  ['Touchstone Pictures'],
#  ['Walt Disney Pictures', 'Gunn Films', 'Casual Friday Productions'],
#  ['StudioCanal', 'Montecito Picture Company, The', 'Outpost Studios'],
#  ['MK2 Productions'],
#  ['Cookout Productions'],
#  [],
#  ['Walt Disney Pictures', 'Pixar Animation Studios'],
#  ['Imagine Entertainment', 'Malpaso Productions', 'Relativity Media'],
#  ['Columbia Pictures', 'Aardman Animations', 'Sony Pictures Animation'],
#  ['TriStar Pictures',
#   'Media Rights Capital',
#   'Sony Pictures Entertainment (SPE)',
#   'QED International',
#   'Alpha Core',
#   'Genre Films',
#   'Simon Kinberg Productions'],
#  ['Warner Bros.'],
#  ['Paramount Pictures'],
#  ['The Rank Organisation',
#   'Enigma Productions',
#   'National Film Finance Corporation (NFFC)'],
#  ['Relativity Media',
#   'Misher Films',
#   'Yucaipa Films',
#   'Goldmann Pictures',
#   'Rat Entertainment',
#   'Misha Films'],
#  ['Regency Enterprises',
#   'Appian Way',
#   'CatchPlay',
#   'Anonymous Content',
#   'New Regency Pictures',
#   'Hong Kong Alpha Motion Pictures Co.',
#   'RatPac Entertainment',
#   'M Productions',
#   'Monarchy Enterprises S.a.r.l.'],
#  ['Paramount Pictures', 'Icon Entertainment International'],
#  ['TriStar Pictures'],
#  ['Twentieth Century Fox Film Corporation',
#   'Joseph M. Singer Entertainment',
#   'Davis Entertainment'],
#  ['Scott Rudin Productions'],
#  ['TF1 Films Production',
#   'Canal+',
#   'CinéCinéma',
#   'Grive Productions',
#   'EuropaCorp',
#   'A.J.O.Z. Films'],
#  ['Maguire Entertainment', 'Screen Gems', 'Sony Pictures Home Entertainment'],
#  ['Kennedy Miller Productions', 'Animal Logic'],
#  ['AVCO Embassy Pictures',
#   'Guardian Trust Company',
#   'RSL Entertainment Corp.',
#   'Moviecorp VI'],
#  ['China Film Group Corporation'],
#  ['Greenestreet Films', 'Eclipse Catering'],
#  ['Twentieth Century Fox Film Corporation'],
#  [],
#  ['Walt Disney Pictures'],
#  ['Summit Entertainment',
#   'K/O Paper Products',
#   'SOIXAN7E QUIN5E',
#   'See Me Louisiana'],
#  [],
#  ['Touchstone Pictures',
#   'Milkshake Films',
#   'Hargitay & Hargitay Pictures in Motion'],
#  ['Paramount Pictures', 'Tamm Productions'],
#  ['BBC Films', 'Lionsgate'],
#  ['Paramount Pictures', 'Rysher Entertainment'],
#  ['Here Films'],
#  ['The Australian Film Commission',
#   'Central Motion Pictures',
#   'Fauna Productions'],
#  ['Paramount Pictures',
#   'Di Bonaventura Pictures',
#   'Mace Neufeld Productions',
#   'Skydance Productions',
#   'Etalon film',
#   'Buckaroo Entertainment'],
#  ['Warner Bros.'],
#  ['New Line Cinema',
#   'Village Roadshow Pictures',
#   'Likely Story',
#   'Anonymous Content',
#   'Overbrook Entertainment',
#   'PalmStar Media'],
#  ['Allied Filmmakers'],
#  ['Topcraft'],
#  ['HBO/Cinemax Documentary',
#   'thinkfilm',
#   'Creative Visions Productions',
#   'Red Light Films',
#   'Sundance Institute Documentary Fund'],
#  ['Di Bonaventura Pictures',
#   'Summit Entertainment',
#   'Participant Media',
#   'Closest to the Hole Productions',
#   'Leverage Entertainment',
#   'TIK Film'],
#  ['United Artists', 'Eon Productions', 'Danjaq'],
#  ['Universal Pictures'],
#  ['Lionsgate'],
#  ['Lionsgate',
#   'MHF Zweite Academy Film',
#   'Marvel Knights',
#   'Valhalla Motion Pictures',
#   'SGF Entertainment',
#   'Muse Entertainment'],
#  ['Meteor 17', 'Crew Neck Productions'],
#  ['Paramount Pictures',
#   'Bristol Bay Productions',
#   'Baldwin Entertainment Group',
#   'Desertlands Entertainment',
#   'Mace Neufeld Productions',
#   'Kanzaman',
#   'J.K. Livin Productions',
#   'Moguletta',
#   'Sahara Productions',
#   'Babelsberg Film'],
#  ['Walt Disney Pictures', 'Walt Disney Feature Animation'],
#  ['Impact Pictures',
#   'Jerry Weintraub Productions',
#   'Warner Bros.',
#   'Morgan Creek Productions'],
#  ['WingNut Films',
#   'DreamWorks SKG',
#   'Key Creatives',
#   'Film4',
#   'Goldcrest Pictures',
#   'New Zealand Large Budget Screen Production Grant'],
#  ['Kissaki Films', 'Stacey Reiss Productions'],
#  ['Reliance Big Pictures', 'Studio Green'],
#  ['Star Media', 'Интерфест', 'Реал-Дакота'],
#  ['France 2 Cinéma',
#   'Why Not Productions',
#   'Les Films Du Fleuve',
#   'Vlaams Audiovisueel fonds',
#   'Canal+',
#   'Radio Télévision Belge Francophone (RTBF)',
#   'Ciné+',
#   'Page 114',
#   'Lumière',
#   'Lunanime',
#   'France Télévisions',
#   "Centre du Cinéma et de l'Audiovisuel de la Fédération Wallonie-Bruxelles",
#   'VOO',
#   "Région Provence-Alpes-Côte d'Azur",
#   'Département des Alpes-Maritimes',
#   'Casa Kafka Pictures Movie Tax Shelter Empowered by Dexia'],
#  ['Spyglass Entertainment',
#   'Forward Pass',
#   'Kaitz Productions',
#   'Mann/Roth Productions',
#   'Touchstone Pictures'],
#  ['Thinkfilm'],
#  ['TriStar Pictures', 'Screen Gems', 'Roth Films'],
#  ['Cecchi Gori Group Tiger Cinematografica',
#   'AMLF',
#   'Canal+',
#   'Bavaria Entertainment'],
#  ['Round Films', 'Rachael Horovitz Productions'],
#  ['Lionsgate', 'Blumhouse Productions', 'Chapter One Films'],
#  [],
#  ['UTV Motion Pictures'],
#  ['Twentieth Century Fox Film Corporation', 'Davis Entertainment'],
#  ['Double Play', 'Geffen Company, The'],
#  ['Arachnid Productions Ltd.'],
#  ['The Ladd Company', 'Outland Productions'],
#  ['Paramount Pictures', 'Nickelodeon Movies', 'Klasky-Csupo'],
#  ['Twentieth Century Fox Film Corporation', 'Circle Films'],
#  ['Vanguard Films', 'Scanbox'],
#  ['New Real Films', 'Lumanity Production'],
#  ['Bedford Falls Productions',
#   'Lonely Film Productions GmbH & Co. KG.',
#   'Virtual Studios',
#   'Spring Creek Productions',
#   'Warner Bros.',
#   'Initial Entertainment Group (IEG)',
#   'Liberty Pictures'],
#  ['Pathé Renn Productions',
#   'TF1 Films Production',
#   'Canal+',
#   'Pathe',
#   'Two Brothers Productions'],
#  ['Propaganda Films', 'PolyGram Filmed Entertainment'],
#  ['Universal Pictures', 'Focus Features', 'Working Title Films'],
#  ["Donners' Company", 'Ixtlan', 'Warner Bros.'],
#  ['Tiger Aspect Productions', 'Working Title Films'],
#  [],
#  ['Universal Pictures', 'The Saul Zaentz Company'],
#  ['Grindstone Entertainment Group',
#   'Cheetah Vision',
#   'Paradox Entertainment',
#   'Gunny Entertainment',
#   'Emmett/Furla Films',
#   'Hedge Fund Film Partners'],
#  ['Columbia Pictures', 'Revolution Studios', 'Happy Madison Productions'],
#  ['Colorado Film Production'],
#  ['Bazelevs Production'],
#  ['Canal+',
#   'Ciné+',
#   'Tabo Tabo Films',
#   'Radio Télévision Suisse (RTS)',
#   'SRG SSR idée suisse',
#   'Office Fédéral de la Culture',
#   'Loterie Suisse Romande',
#   'Bande a Part Films',
#   'Sampek Productions',
#   'SofiTVCiné 3',
#   'Cofimage 27',
#   'Diligence Films',
#   'Cinéforom'],
#  ['Twentieth Century Fox Film Corporation', '1492 Pictures'],
#  ['Eurasia Investments'],
#  ['Bristol Bay Productions', 'Playtone'],
#  ['Hartbeat Productions'],
#  ['Allied Vision', 'The Picture Property Company', 'Pheasantry Films'],
#  ['Morgan Creek Productions'],
#  ['Savoy Pictures', 'Polar Entertainment'],
#  ['Team Todd', 'Warner Bros.', 'Ubu Productions'],
#  [],
#  ['Fuzzy Logic Pictures', 'Strongman', 'Wigwam Films'],
#  ['Pitchblack Pictures Inc.',
#   'Lighthouse Pictures',
#   'Caliber Media Company',
#   'Motion Picture Corporation of America (MPCA)'],
#  ['TriStar Pictures', 'Carolco Pictures'],
#  ['Columbia Pictures Corporation',
#   'Mandalay Entertainment',
#   'Summer Knowledge LLC'],
#  ['Paramount Pictures', 'Paramount Animation'],
#  ['Illusion Entertainment Group',
#   'Phoenix Pictures',
#   'Clyde Is Hungry Films',
#   'Canal+ Droits Audiovisuels'],
#  ['Orion Pictures'],
#  ['Warner Bros.', 'Knickerbocker Films'],
#  ['Twentieth Century Fox Film Corporation',
#   'SLM Production Group',
#   'Brandywine Productions'],
#  ['Universal Pictures',
#   'Spyglass Entertainment',
#   'The Kennedy/Marshall Company',
#   'DreamWorks Pictures',
#   'Touchstone Pictures'],
#  ['Temple Hill Productions', 'Relativity Media'],
#  ['Revolver Film', 'Waterland Film & TV', 'Max TV'],
#  ['Paramount Pictures'],
#  ['Paramount Pictures',
#   'MFP Munich Film Partners GmbH & Company I. Produktions KG',
#   'Krane Entertainment',
#   'Neufeld Rehme Productions'],
#  ['Tokyo Broadcasting System (TBS)',
#   'Amuse Soft Entertainment',
#   'Mainichi Broadcasting System (MBS)',
#   'Shochiku Company',
#   'Sedic',
#   'Dentsu',
#   'Shogakukan',
#   'Asahi Shimbun',
#   'TBS Radio & Communications'],
#  ['Racing Pictures'],
#  ['Fox Searchlight Pictures',
#   'Sound for Film',
#   'Working Title Films',
#   'Antidote Films (I)'],
#  ['Warner Bros.', 'Wide Frame Pictures', 'Panorama Studios'],
#  ['Gravier Productions',
#   'Televisió de Catalunya (TV3)',
#   'Versátil Cinema',
#   'Mediapro',
#   'Pontchartrain Productions'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Destination Films',
#   'Six Point Harness',
#   'Ars Nova',
#   'Goliath Entertainment'],
#  ['Relativity Media'],
#  [],
#  ['Pandora Filmproduktion', 'Canal+'],
#  ['Revolution Studios', 'TriStar Pictures'],
#  ['Telespan 2000',
#   'Antena 3 Films',
#   'Etb (Euskal Telebista)',
#   'Sayaka Producciones Audiovisuales',
#   'Canal+ España',
#   'Vertice 360'],
#  ['Australian Film Commission'],
#  ['Warner Bros.', 'Touchstone Pictures', 'Syncopy'],
#  ['Annapurna Pictures'],
#  ['New Line Cinema',
#   'FilmEngine',
#   'Katalyst Films',
#   'BenderSpink',
#   'Province of British Columbia Production Services Tax Credit'],
#  ['StudioCanal',
#   'Miracle Pictures',
#   'Palomar Pictures (II)',
#   'Manifest Film Company'],
#  ['DreamWorks SKG',
#   'Newmarket Capital Group',
#   'Lawrence Bender Productions',
#   'Pistolero Productions LLC'],
#  ['Polish Brothers Construction'],
#  ['Columbia Pictures Corporation', 'Polar Entertainment'],
#  ['Brothers K Productions'],
#  ['Universal Pictures', 'StudioCanal'],
#  ['Orion Pictures', 'The Mount Company'],
#  ['SBS Productions', 'Globo filmes', 'CinemaScópio Produções'],
#  ['Legendary Pictures',
#   'Hollywood Gang Productions',
#   'Atmosphere Entertainment MM',
#   'Warner Bros.',
#   'Nimar Studios',
#   'Cruel and Unusual Films'],
#  ['Serendipity Point Films', 'Egoli Tossell Film AG', 'A24'],
#  [],
#  ['David Foster Productions', 'Turman-Foster Company'],
#  ['Les Productions du Trésor', 'C-Films AG'],
#  ['Peter McCarthy / Front Films', 'Pacific Arts Video'],
#  ['Foresight Unlimited',
#   'Baumgarten Management and Productions (BMP)',
#   'Signature Entertainment',
#   'Unisol 3 Distribution'],
#  ['Universal Pictures', 'Kennedy Miller Productions'],
#  ['Columbia Pictures Corporation',
#   'Beacon Communications',
#   'Radiant Productions'],
#  ['Epsilon Motion Pictures',
#   'Franchise Pictures',
#   'Baldwin Entertainment Group',
#   'Dante Entertainment',
#   'Crusader Entertainment',
#   'ETIC Films',
#   'Forge',
#   'QI Quality International GmbH Co. KG',
#   'Signature Pictures',
#   'ApolloMedia Distribution',
#   'Coco',
#   'Film 111',
#   'Jericho Productions Ltd.',
#   'MFF (Sound of Thunder)',
#   'Matrix Film Finance',
#   'Scenario Lane Productions'],
#  ['Alcon Entertainment',
#   'ETIC Films',
#   'C.R.G. International',
#   'Trademark Films',
#   'Micro Fusion 2003-2'],
#  ['Emmett/Furla Films', 'PalmStar Media', 'Remark Films'],
#  ['City on a Hill Productions'],
#  ['Fifth Avenue Entertainment',
#   'Trans Atlantic Entertainment',
#   'Lakeshore International'],
#  ['TriStar Pictures'],
#  ['Nordisk Film',
#   'Ingenious Film Partners',
#   'Capitol Films',
#   'Potboiler Productions Ltd.',
#   'Bórd Scannán na hÉireann',
#   'Northern Ireland Film and Television Commission',
#   'Nepenthe Productions',
#   'Irish Film Board',
#   'Treasure Entertainment'],
#  ['Selznick International Pictures'],
#  [],
#  ['Universal Pictures', 'Playtone', 'HBO Films', 'Gold Circle Films'],
#  ['Columbia Pictures', 'Los Hooligans Productions'],
#  ['Fons Rademakers Produktie'],
#  ['Walt Disney Pictures', 'Mayhem Pictures', 'Monkey Dance Productions'],
#  ['Warner Bros.', 'South Side Amusement Company'],
#  ['Imagine Entertainment', 'Universal Pictures'],
#  ['Touchstone Pictures', 'Silver Screen Partners IV'],
#  ['TriStar Pictures'],
#  ['United Artists'],
#  ['Morgan Creek Productions',
#   'Clifford Werber Productions',
#   'SW7D Productions'],
#  ['Gaumont',
#   'Ciné@',
#   'Canal+',
#   'Screen Australia',
#   'Screen NSW',
#   'France Télévisions',
#   'France 2 Cinéma',
#   'Hopscotch Features',
#   'Mon Voisin Productions'],
#  ['Columbia Pictures Corporation', 'Delphi V Productions'],
#  [],
#  ['Legendary Pictures',
#   'Green Hat Films',
#   'Warner Bros.',
#   'IFP Westcoast Erste'],
#  ['Twentieth Century Fox Film Corporation'],
#  [],
#  ['CN Film'],
#  [],
#  ['Orion Pictures'],
#  [],
#  ['Twentieth Century Fox Film Corporation',
#   'Pacific Film and Television Commission',
#   'WWE Studios'],
#  ['Universal Pictures', 'Stampede Entertainment', 'Alphaville Films'],
#  ['Paramount Pictures'],
#  ['Warner Bros.'],
#  ['Columbia Pictures'],
#  ['Centropolis Entertainment', "Mel's Cite du Cinema"],
#  ['Touchstone Pictures'],
#  ['Wildwood Enterprises', 'American Film Company'],
#  ['Wildwood Enterprises', 'Touchstone Pictures'],
#  ['Melnitsa Animation Studio'],
#  ['Universal Pictures',
#   'Why Not Productions',
#   'Platinum Dunes',
#   'Blumhouse Productions',
#   '5150 Action'],
#  ['Poison L.P.'],
#  ['icon'],
#  ['Cruise/Wagner Productions',
#   'United Artists',
#   'Wildwood Enterprises',
#   'Andell Entertainment',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Brat Na Pont Productions'],
#  ['StudioCanal',
#   'Mutual Film Company',
#   '2929 Productions',
#   'Magnolia Pictures',
#   'Madhouse Entertainment'],
#  ['Columbia Pictures'],
#  ['Capitol Films',
#   'Boy in the Box',
#   '2 Bridges Productions',
#   'A2 Entertainment Group'],
#  ['New Line Cinema', 'Ivory Way Productions'],
#  ['Scott Free Productions', 'Cinelou Films'],
#  ['Warner Bros.'],
#  [],
#  ['Columbia Pictures', 'Sony Pictures Animation'],
#  ['Fono Roma', 'Les Films Corona', 'The Criterion Collection'],
#  ['Paramount Pictures',
#   'Cruise/Wagner Productions',
#   'Vinyl Films',
#   'KMP Film Invest'],
#  ['Voltage Pictures', 'Sobini Films', 'Dune Films'],
#  ['Universal Pictures', '40 Acres & A Mule Filmworks'],
#  ['Wallis-Hazen'],
#  ['StudioCanal',
#   'Canal+',
#   'TPS Star',
#   'Sofica Manon',
#   'Easy Company',
#   'A Plus Image 2'],
#  ['2929 Productions',
#   'Linson Entertainment',
#   'Art Linson Productions',
#   'Tribeca Productions'],
#  ['Kopelson Entertainment', 'Warner Bros.'],
#  ['Truth and Soul Pictures Inc',
#   'Protozoa Pictures',
#   'Harvest Filmworks',
#   'Plantain Films'],
#  ['Fox International Productions', 'Sahara Productions', 'Silvatar Media'],
#  ['Columbia Pictures', 'Horizon Pictures'],
#  ['Universal Pictures',
#   'Amblin Entertainment',
#   'Pariah Entertainment Group',
#   'Original Pictures',
#   'Reliance Entertainment',
#   'Walden Media',
#   'Pariah'],
#  ['Lewis Gilbert Productions', 'Lionsgate', 'Modern VideoFilm'],
#  ['Universal Pictures',
#   'Renaissance Pictures',
#   'Dark Horse Entertainment',
#   'Largo Entertainment',
#   'Signature Pictures',
#   'JVC Entertainment Networks'],
#  ['Castel Film Studio', 'Riviera Films', 'Sforzando Productions'],
#  ['Artisan Entertainment'],
#  ['Madras Talkies'],
#  ['Working Title Films'],
#  ['Dune Entertainment',
#   'Atlas Entertainment',
#   'Warner Bros.',
#   'DC Entertainment',
#   'Cruel & Unusual Films',
#   'TENCENT PICTURES',
#   'Wanda Pictures'],
#  ['Ghoulardi Film Company', 'The Weinstein Company', 'Annapurna Pictures'],
#  ['Industry Entertainment',
#   'Epsilon Motion Pictures',
#   'Hyde Park Films',
#   'Metro-Goldwyn-Mayer (MGM)'],
#  ['PCH Films'],
#  ['The Weinstein Company',
#   'Silverwood Films',
#   'Electric City Entertainment',
#   'Tim Burton Productions'],
#  ['Paramount Pictures', 'Motion Picture Associates'],
#  ['Aascar Films'],
#  ['Carnaby International', 'Molinare Studios', 'Eigerwand Pictures'],
#  ['Dune Entertainment',
#   'Regency Enterprises',
#   'Fox 2000 Pictures',
#   'DiNovi Pictures',
#   'Dune Entertainment III',
#   'Blossom Films'],
#  ['Paramount Pictures', 'Goldcrest Pictures', 'Internationale Filmproduktion'],
#  ['Universal Pictures',
#   'Laura Bickford Productions',
#   'Relativity Media',
#   'Medienproduktion Poseidon Filmgesellschaft'],
#  ['Regency Enterprises', 'Cheyenne Enterprises', 'New Regency Pictures'],
#  ['Twentieth Century Fox Film Corporation'],
#  ['A24',
#   'On The Corner Films',
#   'Nemperor',
#   'Lorton Entertainment',
#   'Mint Pictures'],
#  ['ABC Motion Pictures'],
#  ['Twentieth Century Fox Film Corporation',
#   'Davis Entertainment',
#   'Dune Entertainment III',
#   'Troublemaker Studios'],
#  ['Village Roadshow Pictures', 'Australian Film Finance Corporation'],
#  ['Rai Cinema',
#   '40 Acres & A Mule Filmworks',
#   'Touchstone Pictures',
#   'On My Own'],
#  [],
#  ['Hollywood Pictures', 'Don Simpson/Jerry Bruckheimer Films'],
#  ['Lucasfilm', 'Paramount Pictures'],
#  ['Snoot Entertainment'],
#  ['Warner Bros.',
#   'Moving Picture Company (MPC)',
#   'Berlanti Productions',
#   'RatPac-Dune Entertainment'],
#  ['Gramercy Pictures', 'Alphaville Productions', 'The Criterion Collection'],
#  ['Columbia Pictures', 'Mandalay Entertainment', 'Summer Knowledge LLC'],
#  ['WingNut Films', 'New Line Cinema', 'The Saul Zaentz Company'],
#  ['Universal Pictures'],
#  ['360 Pictures', 'Dribble Productions', 'Platinum Equity'],
#  ['New Line Cinema', 'Avery Pix'],
#  ['Paramount Pictures', 'Laurel Productions', 'Darkside Movie'],
#  ['Universal Pictures',
#   'Platinum Dunes',
#   'Hasbro',
#   'Blumhouse Productions',
#   'Allspark Pictures'],
#  [],
#  ['Fox 2000 Pictures'],
#  ['Columbia Pictures',
#   'Media Rights Capital',
#   'Sony Pictures Entertainment (SPE)',
#   'Alpha Core',
#   'Genre Films',
#   'Simon Kinberg Productions',
#   'LStar Capital',
#   'Ollin Studio'],
#  ['Columbia Pictures Corporation',
#   'Dark Castle Entertainment',
#   'Warner Bros.'],
#  ['Universal Pictures', 'Mad Dog Productions'],
#  ['Bandai Visual Company',
#   'Destination Films',
#   'Toho Company',
#   'DENTSU Music And Entertainment',
#   'Tezuka Production Company Ltd.',
#   'Madhouse',
#   'King Record Co.',
#   'Kadokawa Shoten Publishing Co.',
#   'Sony Pictures Television',
#   'Studio 4°C',
#   'Imagica Corp.',
#   'Metropolis Project'],
#  ['United Artists', 'The Caddo Company'],
#  ['See-Saw Films'],
#  ['Sneak Preview Productions'],
#  ['Studio Babelsberg',
#   'Twentieth Century Fox Film Corporation',
#   'Marv Films',
#   'Saville Productions'],
#  ['United Artists'],
#  ['Capture Film Internatrional', 'Meteor Film Productions'],
#  ['Traction Media', 'Animal Kingdom'],
#  ['Columbia Pictures Corporation',
#   'Happy Madison Productions',
#   'Anonymous Content',
#   'Flower Films (II)'],
#  ['Double Feature Films', 'PeaPie Films', '3 Arts Entertainment'],
#  ['Ópalo Films'],
#  [],
#  ['United Artists', 'Batjac Productions', 'The Alamo Company'],
#  ['Lakeshore Entertainment', 'Sidney Kimmel Entertainment'],
#  ['DiNovi Pictures'],
#  ['Gladden Entertainment'],
#  ['DNA Films', 'British Film Council'],
#  ['Lionsgate', 'Spectacle Entertainment Group'],
#  ['Icon Productions', 'BBC Films', 'GK Films', 'Warner Bros.'],
#  ['Fox Searchlight Pictures',
#   'Eden Wurmfeld Films',
#   'Cineric',
#   'Michael Alden Productions',
#   'Brad Zions Films'],
#  ['Universal Pictures',
#   'StudioCanal',
#   'Working Title Films',
#   'Perfect World Pictures',
#   'Miramax'],
#  ['Icon Productions',
#   'Nelson Entertainment',
#   'Icon Entertainment International',
#   'Canal+',
#   'Warner Bros.',
#   'Sovereign Pictures',
#   'Carolco Pictures',
#   'Marquis'],
#  ['Universal Pictures', 'Renaissance Pictures'],
#  ['StudioCanal',
#   'M6 Films',
#   'Mikros Image',
#   'Mandarin Films',
#   'Transfilm International',
#   "La Station d'Animation"],
#  ['DreamWorks SKG', 'Touchstone Pictures'],
#  ['RKO Radio Pictures'],
#  ['Orion Pictures'],
#  ['Paramount Pictures', 'Right of Way Films'],
#  ['Endgame Entertainment',
#   'Rising Star',
#   'Killer Films',
#   'John Wells Productions',
#   'Dreamachine',
#   'Film & Entertainment VIP Medienfonds 4 GmbH & Co. KG (I)',
#   'Grey Water Park Productions',
#   'John Goldwyn Productions',
#   'Wells Productions'],
#  ['A Band Apart', 'Dimension Films', 'Los Hooligans Productions', 'Miramax'],
#  ['Columbia Pictures Corporation'],
#  ['Walt Disney Pictures', 'Aamir Khan Productions'],
#  [],
#  ['Constantin Film', 'Impact Pictures', 'Screen Gems', 'Davis Films'],
#  ['William Castle Productions'],
#  ['Touchstone Pictures'],
#  ['Beacon Communications'],
#  ['Роскинопрокат', 'Флагман-Трейд'],
#  ['Saturn Films', 'Wild Bunch', 'Protozoa Pictures', 'Top Rope'],
#  ['Sony Pictures Classics',
#   'Castle Rock Entertainment',
#   'Detour Filmproduction',
#   'Faliro House Productions',
#   'Venture Forth'],
#  ['Paramount Pictures'],
#  ['EuropaCorp'],
#  ['Warner Bros.', 'Creepshow Films Inc.', 'Laurel Entertainment Inc.'],
#  ['Fox Searchlight Pictures', 'Bona Fide Productions', 'Big Beach Films'],
#  ['Killer Films',
#   'Longfellow Pictures',
#   'Warner Independent Pictures (WIP)',
#   'Jack and Henry Productions Inc.'],
#  ['Front Street Productions',
#   'Participant Media',
#   'Imagenation Abu Dhabi FZ',
#   'Exclusive Media Group',
#   'Spitfire Pictures'],
#  ['Paramount Pictures'],
#  ['Screen Gems'],
#  ['Columbia Pictures Corporation',
#   'Escape Artists',
#   'Black and Blu Entertainment',
#   'Finestkind'],
#  ['Mad Chance', 'Jaret Entertainment', 'Touchstone Pictures'],
#  ['Malpaso Productions', 'Warner Bros.'],
#  ['Epoch Film Co.'],
#  ['Huaxia Film Distribution Company',
#   'Bona Film Group',
#   'August 1st Film Studio'],
#  ['Participant Media', 'History Films'],
#  ['Téléfilm Canada', 'Shadow Shows', 'Corvid Pictures'],
#  [],
#  ['TriStar Pictures',
#   'Keith Barish Productions',
#   'TAFT Entertainment Pictures',
#   'Home Box Office (HBO)'],
#  ['CJ Entertainment', 'Moho Film', 'Yong Film'],
#  ['Filmax Entertainment',
#   'Castelao Producciones',
#   'Canal+ España',
#   'Instituto de la Cinematografía y de las Artes Audiovisuales (ICAA)',
#   'ICF'],
#  ['DreamWorks SKG'],
#  ['Columbia Pictures', 'Highroad Productions'],
#  ['Left Turn Films', 'Ugly Duckling Films'],
#  [],
#  ['Hughes Entertainment', 'Warner Bros. Family Entertainment', 'Warner Bros.'],
#  ['Universal Pictures', 'Refugee Films'],
#  ['Sveriges Television (SVT)',
#   'Cinematograph AB',
#   'Svenska Filminstitutet (SFI)',
#   'Tobis Filmkunst'],
#  ['Paramount Pictures'],
#  ['A Band Apart',
#   'Lawrence Bender Productions',
#   'Altavista Films',
#   'MUVI Films',
#   'Santo Domingo Films',
#   'Organización Santo Domingo'],
#  ['BBC Films',
#   'Participant Media',
#   'Krasnoff Foster Productions',
#   'Shoebox Films'],
#  ['Columbia Pictures Corporation', 'Oak Productions'],
#  ['Revolution Studios', 'Happy Madison Productions'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Hollywood Pictures', 'Touchwood Pacific Partners 1'],
#  ['Red Chillies Entertainment'],
#  ['Younger Than You',
#   'Sikelia Productions',
#   'Verdi Productions',
#   'Bruce Cohen Productions'],
#  ['Rhino Films', 'Warner Bros.'],
#  ['Fox Searchlight Pictures',
#   'Michael London Productions',
#   'Sideways Productions Inc.'],
#  ['United Artists', 'The Mirisch Production Company', 'Mirisch Films'],
#  ['Stone Group Pictures'],
#  ['Twentieth Century Fox Film Corporation',
#   '1492 Pictures',
#   'Constantin Film Produktion',
#   'Marvel Enterprises',
#   'Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 3 KG'],
#  ['Paramount Pictures'],
#  ['Producers Sales Organization',
#   'Bavaria Film',
#   'Dieter Geissler Filmproduktion',
#   'Warner Bros.',
#   'Westdeutscher Rundfunk (WDR)',
#   'Bavaria Studios'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Summit Entertainment', 'Offspring Entertainment', 'Touchstone Pictures'],
#  ['New Zealand Film Commission',
#   'A.M.A. Film',
#   'Pork Pie Productions',
#   'New Zealand United',
#   'New Zealand Railways',
#   'New Zealand Motor Corporation'],
#  ['Fred Berner Films', 'Zeke Productions'],
#  ['Universal Pictures', 'Beacon Communications', 'Azoff Entertainment'],
#  ['Twentieth Century Fox Film Corporation',
#   'Reel FX Creative Studios',
#   'Twentieth Century Fox Animation',
#   'Chatrone'],
#  ['Paramount Pictures', 'Eddie Murphy Productions'],
#  ['New Line Cinema', 'New Deal Productions', 'Gotham Entertainment Group'],
#  ['Toho Company'],
#  ['Porchlight Films'],
#  ['Section Eight',
#   'Warner Bros.',
#   'Participant Media',
#   'FilmWorks',
#   '4M',
#   'MID Foundation'],
#  ['Paramount Pictures',
#   'Dino de Laurentiis Cinematografica',
#   'Marianne Productions'],
#  ['Paramount Pictures'],
#  ['Aardman Animations', 'DreamWorks Animation'],
#  ['Columbia Pictures Corporation', 'Mirage Enterprises'],
#  ['1818', 'Lone Wolf McQuade Associates', 'Topkick Productions'],
#  ['Antoinine Green Bridge',
#   'Scottish Arts Council, The',
#   'The Scottish Arts Council'],
#  ['Daiei Studios'],
#  ['Arsénico Producciones',
#   'Zip Films',
#   'Fine Productions',
#   'Karbo Vantas Entertainment'],
#  ['New Line Cinema', 'American Zoetrope'],
#  ['Universal Pictures', 'Jersey Films'],
#  ['TriStar Pictures', 'Delphi III Productions'],
#  ['BIM Distribuzione', 'Wild Bunch'],
#  ['Blind Spot Pictures Oy', '27 Films Production', 'New Holland Pictures'],
#  ['Studio Babelsberg',
#   'DC Comics',
#   'Virtual Studios',
#   'Anarchos Productions',
#   'Silver Pictures',
#   'Warner Bros.',
#   'Medienboard Berlin-Brandenburg',
#   'Fünfte Babelsberg Film'],
#  ['Zentropa Entertainments', 'Nordisk Film'],
#  ['Dune Entertainment',
#   'Mandate Pictures',
#   'Vincent Pictures',
#   'Barry Mendel Productions',
#   'Flower Films (II)',
#   'Rye Road Productions',
#   'Babe Ruthless Productions'],
#  ['Alcon Entertainment',
#   'FilmNation Entertainment',
#   'Oren Peli / Brian Witten Pictures'],
#  [],
#  ['Gato Negro Films'],
#  ['WingNut Films',
#   'New Line Cinema',
#   'Warner Bros. Pictures',
#   'Metro-Goldwyn-Mayer (MGM)'],
#  ['Darko Entertainment', 'Freeman Film', 'Subotica Entertainment'],
#  ['BBC Films',
#   'Element Pictures',
#   'Irish Film Board',
#   'Lipsync Productions',
#   'Unanimous Pictures',
#   'UKFS'],
#  ['Sandollar Productions', 'Touchstone Pictures'],
#  ['Norma Productions'],
#  ['Eros Entertainment', 'Nadiadwala Grandson Entertainment'],
#  ['Warner Bros.',
#   'Warner Bros. Interactive Entertainment',
#   'Rob Thomas Productions',
#   'Spondoolie Productions',
#   'WARNER BROS DIGITAL DISTRIBUTION',
#   'In The Groove'],
#  ['United Artists', 'Valkyrie Films'],
#  ['Laura Ziskin Productions',
#   'Original Film',
#   'Columbia Pictures Corporation',
#   'Phoenix Pictures',
#   'AFG Talons Productions'],
#  ['Warner Bros. Pictures',
#   'Warner Bros. Animation',
#   'Cartoon Network Studios'],
#  ['Universal Pictures', 'Marv Films'],
#  ['Cruise/Wagner Productions', 'Warner Bros.'],
#  ['Davis Entertainment', 'The Film Department', 'MJW Films'],
#  ['Paramount Pictures'],
#  ['Lions Gate Films',
#   'Twentieth Century Fox Film Corporation',
#   'Centropolis Entertainment',
#   'Mark Gordon Productions',
#   "Mel's Cite du Cinema"],
#  ['Twentieth Century Fox Film Corporation', 'TAFT Entertainment Pictures'],
#  ['Columbia Pictures',
#   'New Line Cinema',
#   'Castle Rock Entertainment',
#   'Nelvana Limited'],
#  ['Columbia Pictures',
#   'Happy Madison Productions',
#   'Relativity Media',
#   'Hey Eddie'],
#  ['Walt Disney Pictures', 'Mandeville Films'],
#  ["Loew's", 'Metro-Goldwyn-Mayer (MGM)'],
#  ['The Mark Gordon Company',
#   'Green Hat Films',
#   'Warner Bros.',
#   'Joint Effort'],
#  ['Seven Arts Productions', 'Carolco Pictures'],
#  ['Dor Film Produktionsgesellschaft GmbH',
#   'Österreichischer Rundfunk (ORF)',
#   'ARTE',
#   'Bayerischer Rundfunk (BR)',
#   'Film House Germany',
#   'Bahr Productions Inc.',
#   'Construction Film'],
#  ['Lucasfilm'],
#  ['Grandon Productions'],
#  ['Twentieth Century Fox Film Corporation',
#   'N1 European Film Produktions GmbH & Co. KG',
#   'Baumgarten Merims Productions'],
#  ['Touchstone Pictures'],
#  ['The Combine', 'Bluegrass Films'],
#  ['Metro-Goldwyn-Mayer (MGM)', 'Peerford Ltd.'],
#  ['People Tree Films'],
#  ['Universal Pictures'],
#  ['Gotham Group', 'Abbolita Productions', 'Starstream Entertainment'],
#  ['Participant Media', 'Focus Features', 'Red Crown Productions'],
#  ['Universal Pictures',
#   'Cube Vision',
#   'Will Packer Productions',
#   'Reel Chefs Catering'],
#  ['The Geffen Company', 'Warner Bros.'],
#  ['Blumhouse Productions', 'Blinding Edge Pictures'],
#  ['Universal Pictures',
#   'Summit Entertainment',
#   'Newmarket Capital Group',
#   'Zide-Perry Productions'],
#  ['Imagine Entertainment', 'Universal Pictures', 'Lionsgate'],
#  ['Universal Pictures', 'American Zoetrope', 'Morgan Creek Productions'],
#  ['Paramount Pictures'],
#  ['Columbia Pictures', 'Innovisions'],
#  ['Schorr Pictures', 'Provenance Pictures', 'RCR Pictures'],
#  ['Davis-Films',
#   'Nu Image Films',
#   'LionsGate',
#   'Millennium Films',
#   'Ex3 Productions',
#   'Fipex Holding'],
#  ['United Artists'],
#  ['Arte France Cinéma',
#   'Forthcoming Productions',
#   'Beachfront Films',
#   'Chimera Films LLC',
#   'Informant Media'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Walt Disney Pictures',
#   'Spyglass Entertainment',
#   'Vertigo Entertainment',
#   'Kennedy/Marshall Company, The',
#   'Mandeville Films',
#   'Winking Productions'],
#  ['Lawrence Bender Productions', 'Marty Katz Productions'],
#  ['Twentieth Century Fox Film Corporation'],
#  ['River Road Entertainment', 'Participant Media'],
#  ['Universal Pictures'],
#  ['TriStar Pictures', 'Allied Filmmakers', 'Pricel', 'Lightmotive'],
#  ['Twentieth Century Fox Film Corporation',
#   'Kroyer Films',
#   'Youngheart Productions',
# ...
#  [],
#  ['Fox 2000 Pictures'],
#  [],
#  ['Tax Credit Finance',
#   'Oceana Media Finance',
#   'Anchor Bay Films',
#   'Barbarian Films',
#   'Overnight Films',
#   'Cinedigm',
#   'Magnet Media Productions',
#   'Magnet Media Group',
#   'Red Dragon Productions',
#   'Morabito Picture Company',
#   'Number 13'],
#  ['Imax Film Entertainment'],
#  ['Bazmark Films',
#   'Ingenious Film Partners',
#   'Twentieth Century Fox Film Corporation',
#   'Dune Entertainment III',
#   'ScreenWest'],
#  ['Universal Pictures',
#   'Atlas Entertainment',
#   'Legendary Pictures',
#   'China Film Group',
#   'Le Vision Pictures',
#   'Legendary East',
#   'Kava Productions'],
#  ['Universal Pictures',
#   'Artina Films',
#   'Fade to Black Productions',
#   'Focus Features'],
#  ['Universal Pictures',
#   'StudioCanal',
#   'Working Title Films',
#   'Ringerike Erste Filmproduktion'],
#  ['21 Laps Entertainment', '3311 Productions', 'Story Ink'],
#  ['Bron Studios', 'RatPac Entertainment'],
#  ['Universal Pictures', 'Amblin Entertainment', 'U-Drive Productions'],
#  ['Twentieth Century Fox Film Corporation',
#   'Gruskoff/Levy Company',
#   'ML Film Entertainment International'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Fine Line Features', 'August Entertainment', 'Mindel-Shaw Productions'],
#  ['Gaylord Films',
#   'Warner Bros.',
#   'Dylan Sellers Productions',
#   'Clifford Werber Productions'],
#  ['Mantarraya Producciones', 'No Dream Cinema', 'Coproduction Office'],
#  [],
#  ['Beijing New Picture Film Co. Ltd.', 'EDKO Film', 'New Picture Company'],
#  ['Twentieth Century Fox Film Corporation', 'Cupid Productions'],
#  ['Walt Disney Pictures', 'Silver Screen Partners IV'],
#  ['Twentieth Century Fox Film Corporation', 'Alcon Entertainment'],
#  ['Paramount Pictures', 'Extreme Productions', 'ApolloMedia Distribution'],
#  ['Paramount Pictures'],
#  ['Universal Pictures'],
#  ['Film It Suda'],
#  ['Head Gear Films', 'Metrol Technology', 'Langley Park Productions'],
#  ['Burgundy Films'],
#  ['Ingenious Film Partners',
#   'Twentieth Century Fox Film Corporation',
#   'Dune Entertainment',
#   'Scott Free Productions',
#   'Top Cow Productions',
#   'Stephen J. Cannell Productions',
#   'Big Screen Productions',
#   'Phoenix Film Partners'],
#  ['Blumhouse Productions',
#   'Blue-Tongue Films',
#   'Huayi Brothers Media',
#   'STX Entertainment',
#   'Ahimsa Films'],
#  ['Blinder Films',
#   'Chic Films',
#   'Amazon Studios',
#   'Westerly Films',
#   'Revolver Amsterdam'],
#  ['Wild Bunch', 'Likely Story', 'Tax Credit Finance', '3 Arts Entertainment'],
#  ['Walt Disney Productions'],
#  ['Walt Disney Pictures',
#   'Walt Disney Television Animation',
#   'Walt Disney Animation Australia',
#   'DisneyToon Studios'],
#  ['First Generation Films',
#   'Antena 3 Films',
#   'Televisió de Catalunya TV3',
#   'Canal+ España',
#   'Instituto de la Cinematografía y de las Artes Audiovisuales (ICAA)',
#   'Millennium Films',
#   'Nostromo Pictures',
#   'Generalitat de Catalunya - Institut Català de les Indústries Culturals (ICIC)',
#   'Cindy Cowan Entertainment',
#   'La Sexta',
#   'Attitude Pinículas y Films A.I.E.'],
#  ['Fox Searchlight Pictures', 'Broken Lizard Industries'],
#  ['Zeynofilm', 'Production 2006', '1000 Volt'],
#  ['Film4', 'Rook Films'],
#  ['Columbia Pictures',
#   'Imagine Entertainment',
#   'Mid Atlantic Films',
#   'Sony Pictures Releasing',
#   'LStar Capital'],
#  ['Bookshop Productions',
#   'Notting Hill Pictures',
#   'Working Title Films',
#   'Polygram Filmed Entertainment'],
#  ['Warner Bros.', 'WW Production'],
#  ['New Line Cinema'],
#  ['Twentieth Century Fox Film Corporation',
#   'Fox 2000 Pictures',
#   'Zucker/Netter Productions'],
#  ['Paramount Pictures', 'Rysher Entertainment'],
#  ['New Line Cinema', 'DC Comics', 'BenderSpink'],
#  ['Universal Pictures',
#   'Brillstein-Grey Entertainment',
#   'Robert Simonds Productions'],
#  ['P & L'],
#  ['Regency Enterprises',
#   'Fox 2000 Pictures',
#   'Sunswept Entertainment',
#   'Bagdasarian Productions',
#   'TSG Entertainment'],
#  ['Paramount Classics'],
#  ['Worldview Entertainment', 'Arcade Pictures'],
#  ['RKO Radio Pictures'],
#  ['Miramax Films'],
#  ['American International Pictures (AIP)', 'Santa Clara Productions'],
#  ['Walt Disney Pictures'],
#  ['Castle Rock Entertainment',
#   'Detour Film Production',
#   'Warner Independent Pictures (WIP)'],
#  ['The Weinstein Company',
#   'Block 2 Pictures',
#   'Wild Bunch',
#   'Annapurna Pictures',
#   'Jet Tone Films',
#   'Sil-Metropole Organisation Ltd.'],
#  ['Hengdian Chinese Film Production Co.',
#   'Beijing Weiyingshidai Culture & Media'],
#  ['City Light Films', 'Revolution Studios', 'Casey Silver Productions'],
#  [],
#  ['Barwood Films', 'Warner Bros.'],
#  ['2929 Productions', 'Wild Bunch', 'Tempesta Films'],
#  ['DC Comics',
#   'Legendary Pictures',
#   'Warner Bros.',
#   'DC Entertainment',
#   'Syncopy',
#   'Patalex III Productions Limited'],
#  ['Europa Corp'],
#  ['Universal Pictures', 'Playtone Productions', 'Vendome Pictures'],
#  ['Aurora Productions LLC', 'Kodiak Films'],
#  ['Fox Searchlight Pictures',
#   'Dune Entertainment',
#   'Flavor Unit Entertainment'],
#  ['Village Roadshow Pictures', 'Kennedy Miller Productions', 'Warner Bros.'],
#  ['Focus Features'],
#  ['No Frills Film Production'],
#  ['Fox Star Studios', 'Bling Unplugged'],
#  ['Patriot Pictures',
#   'Maverick Films',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Rafter H Entertainment'],
#  ['Gaumont',
#   'Australian Film Finance Corporation (AFFC)',
#   'Gaumont Production'],
#  ['Triggerfish Animation'],
#  ['Universal Pictures'],
#  ['Paramount Pictures'],
#  ['Living Films',
#   'Hwy61',
#   'Black Bear Pictures',
#   'Boies / Schiller Film Group'],
#  ['New Line Cinema'],
#  ['Eros International', 'Colour Yellow Pictures'],
#  ['United Artists', 'Charles Chaplin Productions'],
#  ['Fox Searchlight Pictures',
#   'Cowboy Films',
#   'DNA Films',
#   'Scottish Screen',
#   'UK Film Council',
#   'Filmfour',
#   'Slate Films',
#   'Tatfilm'],
#  ['Warner Bros.', 'Morgan Creek Productions'],
#  ['Ferndale Films', 'Irish Film Board', 'Apollo Media'],
#  ['Paramount Pictures'],
#  ['Talent House'],
#  ['Harvey Mason Media'],
#  ['Focus Films'],
#  ['Twentieth Century Fox Film Corporation',
#   'Blue Sky Studios',
#   'Twentieth Century Fox Animation'],
#  ['Be Good Productions',
#   'Scion Films',
#   'Mandeville Films',
#   'Inferno Distribution'],
#  ['Téléfilm Canada', 'Morgan Creek Productions', 'Mantle Clinic II'],
#  ['Spyglass Entertainment',
#   "Donners' Company",
#   'Epsilon Motion Pictures',
#   'Touchstone Pictures'],
#  ['TriStar Pictures', 'Ghost House Pictures', 'FilmDistrict'],
#  ['Mary Murphy & Company'],
#  ['Participant Media',
#   'Imagenation Abu Dhabi FZ',
#   'Parkes+MacDonald Image Nation'],
#  ['Glass Key', 'Wildcard Productions'],
#  ['Kanzaman',
#   'The Saul Zaentz Company',
#   'Antena 3 Televisión',
#   'Xuxa Producciones S.L.'],
#  ['MelinaFilm', 'Lopert Pictures Corporation'],
#  ['Film 4', 'Film Four International', 'Beambright'],
#  ['Miramax Films',
#   'Imagine Entertainment',
#   'Universal Pictures',
#   'Parkway Pictures (I)',
#   'Touchstone Pictures'],
#  ['Twentieth Century Fox Film Corporation',
#   'Epsilon Motion Pictures',
#   'Franchise Pictures',
#   'Scott Free Productions',
#   'World 2000 Entertainment',
#   'Stillking Films',
#   'ApolloProMedia GmbH & Co. 1. Filmproduktion KG (I)',
#   'QI Quality International GmbH & Co. KG'],
#  ['MeniThings LLC'],
#  ['barefoot films'],
#  [],
#  ['Hollywood Pictures', 'Cinergi Pictures Entertainment'],
#  ['Universal Pictures', 'Toma 78', 'De Milo'],
#  ['Paramount Pictures', 'Dino De Laurentiis Company', 'Spelling Films'],
#  ['Columbia Pictures'],
#  ['Cliffjack Motion Pictures', 'Morgan Creek Productions'],
#  ['Warner Bros.', 'Morgan Creek Productions'],
#  ['Relativity Media',
#   'Virgin Produced',
#   'Mandeville Films',
#   'SkyLand Entertainment'],
#  ['BBC Films',
#   'Synchronistic Pictures',
#   'Icon Entertainment International',
#   'Lipsync Productions',
#   'Atlantic Swiss Productions',
#   'Hermetof Pictures',
#   'Magna Films',
#   'Kalkronkie',
#   'Artemis Films',
#   'Lonely Dragon',
#   'Magnolia Mae Films'],
#  ['Walt Disney Pictures',
#   'Team Todd',
#   'Tim Burton Productions',
#   'Roth Films',
#   'Zanuck Company, The'],
#  ['Columbia Pictures',
#   'Imagenation Abu Dhabi FZ',
#   'Marvel Entertainment',
#   'Marvel Knights',
#   'Hyde Park Entertainment',
#   'Crystal Sky Pictures',
#   'Michael De Luca Productions'],
#  ['Scott Free Productions',
#   '1984 Private Defense Contractors',
#   'LD Entertainment',
#   'Open Road Films',
#   'Inferno Distribution',
#   'Chambara Pictures'],
#  ['Melnitsa Animation Studio'],
#  ['United Artists',
#   'Jewel Productions',
#   'Pimlico Films',
#   'Sellers-Edwards productions'],
#  ['Centerstage Productions', 'Film Development Council of the Philippines'],
#  ['Focus Features'],
#  ['Home Box Office (HBO)',
#   'Playtone',
#   'Gold Circle Films',
#   'Ontario Film Development Corporation',
#   'MPH Entertainment Productions'],
#  ['Film Council',
#   'StudioCanal',
#   'Midfield Films',
#   'Canal+',
#   'Working Title Films',
#   'WT2 Productions'],
#  ['Lorimar Film Entertainment', 'Warner Bros.'],
#  ['Lucasfilm', 'Universal Pictures'],
#  ['Back Allie Productions'],
#  ['Twentieth Century Fox Film Corporation',
#   'Fox 2000 Pictures',
#   'Adam Fields Productions',
#   'Two Girls Productions'],
#  ['Village Roadshow Pictures',
#   'NPV Entertainment',
#   'Regency Enterprises',
#   'Kopelson Entertainment',
#   'Epsilon Motion Pictures',
#   'New Regency Pictures',
#   'Furthur Films'],
#  ['Universal Pictures', 'The Mirisch Corporation'],
#  ['Summit Entertainment',
#   'Offspring Entertainment',
#   'Touchstone Pictures',
#   'Eketahuna LLC'],
#  ['Twentieth Century Fox Film Corporation', 'Warner Bros.'],
#  ['Twentieth Century Fox Film Corporation',
#   'Starz Animation',
#   'IDT Entertainment'],
#  ['AVM Productions'],
#  ['Summit Entertainment',
#   'Intrepid Pictures',
#   'Film Rites',
#   'Galavis Film',
#   'Picture Machine',
#   'Fria Luz Del Dia, A.I.E.'],
#  ['Angoa-Agicoa',
#   'Procirep',
#   'MEDIA Programme of the European Union',
#   'Arte France',
#   'Région Ile-de-France',
#   'Catherine Dussart Productions (CDP)',
#   "Centre National du Cinéma et de L'image Animée (CNC)",
#   'Bophana Production'],
#  ['Lucasfilm', 'Paramount Pictures'],
#  ['Lorimar Film Entertainment'],
#  ['Imagine Entertainment',
#   'Columbia Pictures Corporation',
#   'JC 23 Entertainment'],
#  ['Castle Rock Entertainment', 'Nelson Entertainment'],
#  ['Legendary Pictures', 'Warner Bros.', 'DC Entertainment', 'Syncopy'],
#  ['Universal Pictures', 'Mirage Entertainment'],
#  ['Echo Lake Entertainment',
#   'RatPac Entertainment',
#   'Mythology Entertainment (II)'],
#  ['Automatik Entertainment', 'Hydraulx', 'Baltimore Pictures'],
#  ['Kim Ki-Duk Film'],
#  ['Nord-Ouest Films'],
#  ['Universal Pictures',
#   'Village Roadshow Pictures',
#   'China Film Group Corporation (CFGC)',
#   'Company Films',
#   'Dalian Wanda Group'],
#  ['Columbia Pictures', 'Castle Rock Entertainment', 'Malpaso Productions'],
#  ['LD Entertainment', '22h22', 'Lucky Man Films'],
#  ['Warner Bros.', 'Studio Swan', 'RoC Works Co.'],
#  ['Columbia Pictures'],
#  ['Touchstone Pictures'],
#  ['Madras Talkies', 'Studio Green'],
#  [],
#  ['Simcom Limited',
#   'Allarcom Limited',
#   'British Columbia Television',
#   'CFCN Communications',
#   'TBA Film'],
#  ['Trans Pacific Films'],
#  ['Walt Disney Pictures'],
#  ['Metro-Goldwyn-Mayer (MGM)', 'NHK', 'Mico', 'Mount Film Group'],
#  ['Televisión Española (TVE)',
#   'AXN',
#   'Televisió de Catalunya (TV3)',
#   'Canal+ España',
#   'Instituto de la Cinematografía y de las Artes Audiovisuales (ICAA)',
#   'Instituto de Crédito Oficial (ICO)',
#   'Rodar y Rodar Cine y Televisión',
#   'Institut Català de les Empreses Culturals (ICEC)'],
#  ['Aegis Film Fund',
#   'Altus Productions',
#   'Ealing Metro International',
#   'Occupant Entertainment'],
#  ['Columbia Pictures Corporation',
#   'Hofflund/Polone',
#   'Global Entertainment Productions GmbH & Company Medien KG'],
#  ['New Line Cinema',
#   'Original Film',
#   'Legendary Pictures',
#   'Warner Bros.',
#   'Big Kid Pictures',
#   'Bad Hat Harry Productions'],
#  ['Vertigo Films'],
#  ['Handmade Films Ltd.'],
#  ['Splendid Pictures',
#   'Maverick Films',
#   'Metro-Goldwyn-Mayer (MGM)',
#   'Dylan Sellers Productions',
#   'Madacy Entertainment'],
#  ['Waadi Animations', 'ARY Films', 'SOC Films'],
#  ['Silver Pictures', 'Warner Bros.'],
#  ['Imagine Entertainment',
#   'DreamWorks SKG',
#   'Universal Pictures',
#   'platinum studios',
#   'Reliance Entertainment',
#   'Relativity Media',
#   'K/O Paper Products',
#   'Fairview Entertainment',
#   'K/O Camera Toys'],
#  ['Thunder Road Pictures', 'LionsGate', '87Eleven'],
#  ['Paramount Pictures', 'RKO Pictures'],
#  ['Wide Angle Creations', 'Rajkumar Theatres'],
#  ['Emperor Motion Pictures'],
#  ['KODA Entertainment'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Lions Gate Films',
#   '2929 Productions',
#   'Out of the Blue... Entertainment',
#   'Starbucks Entertainment',
#   'Cinema Gypsy Productions'],
#  ['Walt Disney Pictures', 'Walt Disney Studios Motion Pictures', 'Roth Films'],
#  ['IM Global', 'Shoebox Films', 'A24'],
#  [],
#  ['Polygon Entertainment', 'CJ Entertainment', 'Doosabu Film'],
#  ['Universal Pictures', 'Spyglass Entertainment'],
#  ['Columbia Pictures',
#   'Spyglass Entertainment',
#   'Peninsula Films',
#   'StudioCanal',
#   'Sony Pictures Releasing',
#   'GK Films',
#   'Sony Pictures Worldwide Acquisitions (SPWA)',
#   'Italian Tax Credit',
#   'Birnbaum/Barber',
#   'Cineroma SRL',
#   'French Tax Credit'],
#  ['Channel Four Films', 'The Samuel Goldwyn Company'],
#  ['TriStar Pictures', 'Carolco Pictures'],
#  ['Metro-Goldwyn-Mayer (MGM)'],
#  ['Warner Bros.'],
#  ['Universal Pictures', 'The Bubble Factory', 'American Films'],
#  ['Jalem Productions'],
#  ['Gravier Productions', 'Medusa Film', 'Mediapro', 'Perdido Productions'],
#  ['StudioCanal',
#   'Ministero per i Beni e le Attività Culturali (MiBAC)',
#   'Frenesy Film Company',
#   'Sensi Contemporanei Cinema e Audiovisivo',
#   'Cota Film',
#   'Regione Siciliana',
#   'Sicilia Film Commission'],
#  [],
#  ['Verisimilitude', 'Kotva Films'],
#  ['Medusa Film', 'Opera Film (II)'],
#  ['Warner Bros.'],
#  ['Universal Pictures', 'Amblin Entertainment'],
#  ['Constantin Film'],
#  ['Warner Bros.', 'Heyday Films'],
#  ['Columbia Pictures', 'Don Simpson/Jerry Bruckheimer Films'],
#  ['Diaphana Films'],
#  ['Igor Film', 'Casbah Film'],
#  ['Jerry Weintraub Productions', 'Warner Bros.'],
#  ['Fox Searchlight Pictures', 'DNA Films', 'BBC Films'],
#  ['Ciby 2000', 'Film Victoria', 'House & Moorhouse Films'],
#  ['Spyglass Entertainment',
#   'Twentieth Century Fox Film Corporation',
#   'Dune Entertainment',
#   'UTV Motion Pictures',
#   'Blinding Edge Pictures'],
#  ['Millennium Films'],
#  ['Nadiadwala Grandsons'],
#  ['New Line Cinema', 'The Safran Company', 'Evergreen Media Group'],
#  ['Wildwood Enterprises', 'Warner Bros.'],
#  ['New Line Cinema', 'Metro-Goldwyn-Mayer (MGM)'],
#  ['Walt Disney Pictures', 'Lisberger/Kushner'],
#  ['Lions Gate Family Entertainment',
#   'Relativity Media',
#   'Crest Animation Productions'],
#  ['DreamWorks SKG',
#   'Twentieth Century Fox Film Corporation',
#   'Wildwood Enterprises',
#   'Epsilon Motion Pictures',
#   'Allied Filmmakers'],
#  ['Colorado Film Production', "Film Commission Regione Valle d'Aosta"],
#  ['Columbia Pictures', 'Gaumont'],
#  [],
#  ['DreamWorks', 'Roth-Arnold Productions'],
#  [],
#  ['Telecinco Cinema',
#   'Vaca Films',
#   'Morena Films',
#   'Telefónica Studios',
#   'Coproducción España-Argentina-Francia',
#   'K&S Films'],
#  ['Columbia Pictures Corporation', 'Stonebridge Entertainment'],
#  ['SND'],
#  ['Life Sentence Films'],
#  ['Universal Pictures', 'Amblin Entertainment'],
#  ['Fox Searchlight Pictures',
#   'Ingenious Media',
#   'Dune Entertainment',
#   'Cold Spring Pictures',
#   'The Montecito Picture Company',
#   'Big Screen Productions',
#   'Prana Studios'],
#  ['Universal Pictures', 'City Light Films'],
#  ['Paramount Pictures'],
#  ['Darlow Smithson Productions', 'UK Film Council', 'PBS', 'Film4'],
#  ['Haile Addis Pictures'],
#  ['RKO Radio Pictures'],
#  ['Columbia Pictures',
#   'Delphi II Productions',
#   'Industrial Light & Magic (ILM)'],
#  ['Universal Pictures', 'The Badham-Cohen Group'],
#  [],
#  ['Cine Bazar', 'Toho Pictures'],
#  ['Lions Gate Films',
#   'Twisted Pictures',
#   'Evolution Entertainment',
#   'Saw Productions Inc.'],
#  ['Columbia Pictures', 'Revolution Studios', 'Davis Entertainment'],
#  ['Les Films du Carrosse',
#   'PECF',
#   'Produzione Intercontinentale Cinematografica (PIC)'],
#  ...]

# %%
Counter([i for j in prod_comp_list for i in j]).most_common()
# Out:
# [('Warner Bros.', 202),
#  ('Universal Pictures', 188),
#  ('Paramount Pictures', 161),
#  ('Twentieth Century Fox Film Corporation', 138),
#  ('Columbia Pictures', 91),
#  ('Metro-Goldwyn-Mayer (MGM)', 84),
#  ('New Line Cinema', 75),
#  ('Touchstone Pictures', 63),
#  ('Walt Disney Pictures', 62),
#  ('Columbia Pictures Corporation', 61),
#  ('TriStar Pictures', 53),
#  ('Relativity Media', 48),
#  ('Canal+', 46),
#  ('United Artists', 44),
#  ('Miramax Films', 40),
#  ('Village Roadshow Pictures', 36),
#  ('Regency Enterprises', 31),
#  ('BBC Films', 30),
#  ('Dune Entertainment', 30),
#  ('Working Title Films', 30),
#  ('Fox Searchlight Pictures', 29),
#  ('StudioCanal', 28),
#  ('Lionsgate', 28),
#  ('DreamWorks SKG', 27),
#  ('Fox 2000 Pictures', 25),
#  ('Summit Entertainment', 24),
#  ('Hollywood Pictures', 24),
#  ('Orion Pictures', 24),
#  ('Amblin Entertainment', 23),
#  ('Dimension Films', 23),
#  ('Castle Rock Entertainment', 21),
#  ('Epsilon Motion Pictures', 21),
#  ('Morgan Creek Productions', 21),
#  ('Original Film', 21),
#  ('Focus Features', 21),
#  ('Legendary Pictures', 19),
#  ('Participant Media', 19),
#  ('Blumhouse Productions', 18),
#  ('New Regency Pictures', 18),
#  ('Film4', 18),
#  ('Spyglass Entertainment', 17),
#  ('Imagine Entertainment', 16),
#  ('Screen Gems', 16),
#  ('Millennium Films', 16),
#  ('TSG Entertainment', 16),
#  ('Lakeshore Entertainment', 15),
#  ('France 2 Cinéma', 15),
#  ('Silver Pictures', 15),
#  ('The Weinstein Company', 14),
#  ('PolyGram Filmed Entertainment', 14),
#  ('Eon Productions', 14),
#  ('Scott Rudin Productions', 14),
#  ('Dune Entertainment III', 13),
#  ('Happy Madison Productions', 13),
#  ('Studio Babelsberg', 13),
#  ('Lions Gate Films', 13),
#  ('EuropaCorp', 12),
#  ('Gaumont', 12),
#  ('Carolco Pictures', 12),
#  ('American Zoetrope', 12),
#  ('UK Film Council', 11),
#  ('TF1 Films Production', 11),
#  ('Ciné+', 11),
#  ('Revolution Studios', 11),
#  ('Davis Entertainment', 11),
#  ('Canal+ España', 11),
#  ('Ingenious Film Partners', 11),
#  ('Scott Free Productions', 11),
#  ('Wild Bunch', 11),
#  ('Wildwood Enterprises', 10),
#  ('Icon Entertainment International', 10),
#  ('Killer Films', 10),
#  ('Phoenix Pictures', 10),
#  ('Cannon Group', 10),
#  ('NPV Entertainment', 10),
#  ('Emmett/Furla Films', 10),
#  ('Malpaso Productions', 10),
#  ('Twentieth Century Fox Animation', 9),
#  ('2929 Productions', 9),
#  ('Walden Media', 9),
#  ('WingNut Films', 9),
#  ('Alcon Entertainment', 9),
#  ('Saturn Films', 9),
#  ('Nu Image Films', 9),
#  ('Dentsu', 9),
#  ('Channel Four Films', 9),
#  ('Appian Way', 9),
#  ('Di Bonaventura Pictures', 9),
#  ('The Criterion Collection', 9),
#  ('Tribeca Productions', 9),
#  ('Sidney Kimmel Entertainment', 9),
#  ('Miramax', 9),
#  ('Double Feature Films', 8),
#  ('Arte France Cinéma', 8),
#  ('Blue Sky Studios', 8),
#  ("Donners' Company", 8),
#  ('Franchise Pictures', 8),
#  ('Pixar Animation Studios', 8),
#  ('Chernin Entertainment', 8),
#  ('Plan B Entertainment', 8),
#  ('Anonymous Content', 8),
#  ("Mel's Cite du Cinema", 8),
#  ('Platinum Dunes', 8),
#  ('Lucasfilm', 8),
#  ('LStar Capital', 8),
#  ('Sony Pictures Releasing', 8),
#  ('Cinergi Pictures Entertainment', 8),
#  ('Dino De Laurentiis Company', 8),
#  ('Marvel Studios', 8),
#  ('Revolution Sun Studios', 8),
#  ('Universal Studios', 8),
#  ('Interscope Communications', 7),
#  ('Studio Canal', 7),
#  ('Westdeutscher Rundfunk (WDR)', 7),
#  ('Stillking Films', 7),
#  ('Warner Independent Pictures (WIP)', 7),
#  ('Intermedia Films', 7),
#  ('Isle of Man Film', 7),
#  ('CBS Films', 7),
#  ('Marvel Enterprises', 7),
#  ('Dark Castle Entertainment', 7),
#  ('Apatow Productions', 7),
#  ('3 Arts Entertainment', 7),
#  ('Silver Screen Partners IV', 7),
#  ('Golan-Globus Productions', 7),
#  ('Playtone', 7),
#  ('Impact Pictures', 7),
#  ('UTV Motion Pictures', 7),
#  ('Annapurna Pictures', 7),
#  ('A24', 7),
#  ('Artisan Entertainment', 7),
#  ('DC Entertainment', 7),
#  ('Imagenation Abu Dhabi FZ', 7),
#  ('Mirage Enterprises', 7),
#  ('DC Comics', 7),
#  ('Vertigo Entertainment', 7),
#  ('Fine Line Features', 7),
#  ('Big Screen Productions', 7),
#  ('Jerry Bruckheimer Films', 7),
#  ('Jersey Films', 6),
#  ('BenderSpink', 6),
#  ('Dark Horse Entertainment', 6),
#  ('CinéCinéma', 6),
#  ('IM Global', 6),
#  ('Gold Circle Films', 6),
#  ('Atlas Entertainment', 6),
#  ('Kennedy/Marshall Company, The', 6),
#  ('Golden Harvest Company', 6),
#  ('Canal Plus', 6),
#  ('British Film Institute (BFI)', 6),
#  ('Bad Hat Harry Productions', 6),
#  ('Rai Cinema', 6),
#  ('Constantin Film Produktion', 6),
#  ('Allied Filmmakers', 6),
#  ('Why Not Productions', 6),
#  ('Forward Pass', 6),
#  ('1492 Pictures', 6),
#  ('Syncopy', 6),
#  ('Capitol Films', 6),
#  ('WWE Studios', 6),
#  ('Centropolis Entertainment', 6),
#  ('Reliance Entertainment', 6),
#  ('GK Films', 6),
#  ('RKO Radio Pictures', 6),
#  ('Sony Pictures Classics', 6),
#  ('Dino de Laurentiis Cinematografica', 6),
#  ('DreamWorks Animation', 6),
#  ('FilmNation Entertainment', 6),
#  ('Warner Bros. Pictures', 6),
#  ('Sunswept Entertainment', 6),
#  ('Robert Simonds Productions', 6),
#  ('FilmDistrict', 6),
#  ('Focus Films', 6),
#  ('Pathé', 6),
#  ('Marc Platt Productions', 6),
#  ('MTV Films', 6),
#  ('Rogue Pictures', 6),
#  ('Ghost House Pictures', 5),
#  ('Cruise/Wagner Productions', 5),
#  ('BIM Distribuzione', 5),
#  ('France 3 Cinéma', 5),
#  ('Lawrence Bender Productions', 5),
#  ('Walt Disney Productions', 5),
#  ('Alphaville Films', 5),
#  ('Scion Films', 5),
#  ('Centre National de la Cinématographie (CNC)', 5),
#  ('The Ladd Company', 5),
#  ('The Mirisch Corporation', 5),
#  ('Cheyenne Enterprises', 5),
#  ('Hyde Park Entertainment', 5),
#  ('Spring Creek Productions', 5),
#  ('Roth Films', 5),
#  ('The Saul Zaentz Company', 5),
#  ('Emperor Motion Pictures', 5),
#  ('40 Acres & A Mule Filmworks', 5),
#  ('CJ Entertainment', 5),
#  ('Yari Film Group', 5),
#  ('Toho Company', 5),
#  ('Bel Air Entertainment', 5),
#  ('The Australian Film Commission', 5),
#  ('Cross Creek Pictures', 5),
#  ('Fuji Television Network', 5),
#  ('Exclusive Media Group', 5),
#  ('Goldcrest Films International', 5),
#  ('Blinding Edge Pictures', 5),
#  ('Initial Entertainment Group (IEG)', 5),
#  ('Media Rights Capital', 5),
#  ('QED International', 5),
#  ('Rysher Entertainment', 5),
#  ('Mace Neufeld Productions', 5),
#  ('Skydance Productions', 5),
#  ('Nickelodeon Movies', 5),
#  ('Pathé Renn Productions', 5),
#  ('Propaganda Films', 5),
#  ('Brandywine Productions', 5),
#  ('Newmarket Capital Group', 5),
#  ('Magnolia Pictures', 5),
#  ('Protozoa Pictures', 5),
#  ('Troublemaker Studios', 5),
#  ('Moving Picture Company (MPC)', 5),
#  ('RatPac-Dune Entertainment', 5),
#  ('Flower Films (II)', 5),
#  ('Nelson Entertainment', 5),
#  ('Endgame Entertainment', 5),
#  ('Constantin Film', 5),
#  ('Warner Bros. Animation', 5),
#  ('Zide-Perry Productions', 5),
#  ('Davis-Films', 5),
#  ('Temple Hill Entertainment', 5),
#  ('Marvel Entertainment', 5),
#  ('Baltimore Pictures', 5),
#  ('Thunder Road Pictures', 5),
#  ('DreamWorks', 5),
#  ('Ingenious Media', 5),
#  ('The Montecito Picture Company', 5),
#  ('TF1 Films Productions', 5),
#  ('Edward R. Pressman Film', 5),
#  ('Bold Films', 4),
#  ('Right of Way Films', 4),
#  ('De Laurentiis Entertainment Group (DEG)', 4),
#  ('Bavaria Film', 4),
#  ('Automatik Entertainment', 4),
#  ('Bórd Scannán na hÉireann', 4),
#  ('Kopelson Entertainment', 4),
#  ('Revelations Entertainment', 4),
#  ('FilmColony', 4),
#  ('Affirm Films', 4),
#  ('LD Entertainment', 4),
#  ('Babelsberg Film', 4),
#  ('Sean S. Cunningham Films', 4),
#  ('Paramount Vantage', 4),
#  ('Bona Fide Productions', 4),
#  ('Section Eight', 4),
#  ('Mandalay Pictures', 4),
#  ('New World Pictures', 4),
#  ('PalmStar Media', 4),
#  ('Hyde Park Films', 4),
#  ('Alcor Films', 4),
#  ('Gran Via Productions', 4),
#  ('Metrol Technology', 4),
#  ('Baltimore Spring Creek Productions', 4),
#  ('Green Hat Films', 4),
#  ('Parts and Labor', 4),
#  ('Northern Lights Entertainment', 4),
#  ('Lipsync Productions', 4),
#  ('DisneyToon Studios', 4),
#  ('Kennedy Miller Productions', 4),
#  ('Screen Australia', 4),
#  ('Avery Pix', 4),
#  ('Gracie Films', 4),
#  ('Michael De Luca Productions', 4),
#  ('Goldcrest Pictures', 4),
#  ('EMI Films Ltd.', 4),
#  ('River Road Entertainment', 4),
#  ('Savoy Pictures', 4),
#  ('Gunn Films', 4),
#  ('MK2 Productions', 4),
#  ('Sony Pictures Animation', 4),
#  ('Sony Pictures Entertainment (SPE)', 4),
#  ('Genre Films', 4),
#  ('Rat Entertainment', 4),
#  ('Likely Story', 4),
#  ('Overbrook Entertainment', 4),
#  ('Closest to the Hole Productions', 4),
#  ('Kanzaman', 4),
#  ('Walt Disney Feature Animation', 4),
#  ('Jerry Weintraub Productions', 4),
#  ('Paradox Entertainment', 4),
#  ('Bazelevs Production', 4),
#  ('Team Todd', 4),
#  ('SLM Production Group', 4),
#  ('FilmEngine', 4),
#  ('Egoli Tossell Film AG', 4),
#  ('ApolloMedia Distribution', 4),
#  ('Mutual Film Company', 4),
#  ('Industry Entertainment', 4),
#  ('Tim Burton Productions', 4),
#  ('Marv Films', 4),
#  ('DNA Films', 4),
#  ('Icon Productions', 4),
#  ('John Wells Productions', 4),
#  ('Big Beach Films', 4),
#  ('Escape Artists', 4),
#  ('Mad Chance', 4),
#  ('Téléfilm Canada', 4),
#  ('Home Box Office (HBO)', 4),
#  ('Instituto de la Cinematografía y de las Artes Audiovisuales (ICAA)', 4),
#  ('Mandeville Films', 4),
#  ('The Mark Gordon Company', 4),
#  ('Seven Arts Productions', 4),
#  ('ARTE', 4),
#  ('Bluegrass Films', 4),
#  ('Palace Pictures', 4),
#  ('Maverick Films', 4),
#  ('British Screen Productions', 4),
#  ('Polygram Filmed Entertainment', 4),
#  ('Worldview Entertainment', 4),
#  ('Parkes+MacDonald Image Nation', 4),
#  ('Open Road Films', 4),
#  ('Lorimar Film Entertainment', 4),
#  ('Intrepid Pictures', 4),
#  ('Televisión Española (TVE)', 4),
#  ('Heyday Films', 4),
#  ('The Safran Company', 4),
#  ('Cold Spring Pictures', 4),
#  ('TV Tokyo', 4),
#  ('HandMade Films', 4),
#  ('Nick Wechsler Productions', 4),
#  ('Chockstone Pictures', 4),
#  ('Walt Disney', 4),
#  ('Indian Paintbrush', 4),
#  ('uFilm', 4),
#  ('Weed Road Pictures', 4),
#  ('Hasbro Studios', 4),
#  ('Big Talk Productions', 4),
#  ('Solana Films', 4),
#  ('Konrad Pictures', 4),
#  ('Metropolitan Filmexport', 4),
#  ('Central Partnership', 4),
#  ('Pacific Western', 4),
#  ('Gary Sanchez Productions', 4),
#  ('TLA Releasing', 4),
#  ('De Line Pictures', 4),
#  ('Film i Väst', 4),
#  ('Craven-Maddalena Films', 3),
#  ('Prescience', 3),
#  ('Current Entertainment', 3),
#  ('TPS Star', 3),
#  ('Largo Entertainment', 3),
#  ('JVC Entertainment Networks', 3),
#  ('TF1', 3),
#  ('Centre National de la Cinématographie', 3),
#  ('Eurimages', 3),
#  ('Goldmann Pictures', 3),
#  ('Punch Productions', 3),
#  ('Arnold Kopelson Productions', 3),
#  ('Indigo Film', 3),
#  ('Medusa Film', 3),
#  ('Shanghai Film Group', 3),
#  ('Rising Star', 3),
#  ('Senator Film Produktion', 3),
#  ('Sound for Film', 3),
#  ('A Band Apart', 3),
#  ('Media Programme of the European Community', 3),
#  ('Rastar Pictures', 3),
#  ('China Film Co.', 3),
#  ('Fandango', 3),
#  ('Cinedigm', 3),
#  ('Whitewater Films', 3),
#  ('The Canton Company', 3),
#  ('IRE Productions', 3),
#  ('Santa Fe Institute for Regional Education', 3),
#  ('Firm Films', 3),
#  ('Screen NSW', 3),
#  ('Hughes Entertainment', 3),
#  ('Reel FX Creative Studios', 3),
#  ('Dune Films', 3),
#  ('Australian Film Finance Corporation (AFFC)', 3),
#  ('Merchant Ivory Productions', 3),
#  ('MICA Entertainment', 3),
#  ('Madhouse', 3),
#  ('Österreichischer Rundfunk (ORF)', 3),
#  ('Norddeutscher Rundfunk (NDR)', 3),
#  ('Laurence Mark Productions', 3),
#  ('Broken Lizard Industries', 3),
#  ('Darko Entertainment', 3),
#  ('Bandai Visual Company', 3),
#  ('Kodansha', 3),
#  ('Production I.G.', 3),
#  ('IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG', 3),
#  ('Art Linson Productions', 3),
#  ('Color Force', 3),
#  ('Caravan Pictures', 3),
#  ('Destination Films', 3),
#  ('5150 Action', 3),
#  ('DreamWorks Pictures', 3),
#  ('Shady Acres Entertainment', 3),
#  ('Montecito Picture Company, The', 3),
#  ('Aardman Animations', 3),
#  ('Misher Films', 3),
#  ('RatPac Entertainment', 3),
#  ('thinkfilm', 3),
#  ('Danjaq', 3),
#  ('MHF Zweite Academy Film', 3),
#  ('Valhalla Motion Pictures', 3),
#  ('Baldwin Entertainment Group', 3),
#  ('Les Films Du Fleuve', 3),
#  ('France Télévisions', 3),
#  ('Thinkfilm', 3),
#  ('Cecchi Gori Group Tiger Cinematografica', 3),
#  ('Bedford Falls Productions', 3),
#  ('Lonely Film Productions GmbH & Co. KG.', 3),
#  ('Pathe', 3),
#  ('Grindstone Entertainment Group', 3),
#  ('Cheetah Vision', 3),
#  ('Mandalay Entertainment', 3),
#  ('Canal+ Droits Audiovisuels', 3),
#  ('The Kennedy/Marshall Company', 3),
#  ('Antidote Films (I)', 3),
#  ('Televisió de Catalunya (TV3)', 3),
#  ('Katalyst Films', 3),
#  ('Province of British Columbia Production Services Tax Credit', 3),
#  ('Manifest Film Company', 3),
#  ('David Foster Productions', 3),
#  ('Signature Entertainment', 3),
#  ('Beacon Communications', 3),
#  ('Forge', 3),
#  ('Signature Pictures', 3),
#  ('Nordisk Film', 3),
#  ('Irish Film Board', 3),
#  ('Vinyl Films', 3),
#  ('Voltage Pictures', 3),
#  ('Original Pictures', 3),
#  ('Pariah', 3),
#  ('Renaissance Pictures', 3),
#  ('Don Simpson/Jerry Bruckheimer Films', 3),
#  ('Snoot Entertainment', 3),
#  ('Kadokawa Shoten Publishing Co.', 3),
#  ('Ópalo Films', 3),
#  ('Detour Filmproduction', 3),
#  ('Faliro House Productions', 3),
#  ('Warner Bros. Family Entertainment', 3),
#  ('Sveriges Television (SVT)', 3),
#  ('Svenska Filminstitutet (SFI)', 3),
#  ('Red Chillies Entertainment', 3),
#  ('New Deal Productions', 3),
#  ('Anarchos Productions', 3),
#  ('Element Pictures', 3),
#  ('Sandollar Productions', 3),
#  ('Hey Eddie', 3),
#  ('Film House Germany', 3),
#  ('Gotham Group', 3),
#  ('Filmax', 3),
#  ('Zweites Deutsches Fernsehen (ZDF)', 3),
#  ('Wild West Picture Show Productions', 3),
#  ('Arte', 3),
#  ('Hemisphere Media Capital', 3),
#  ('DMG Entertainment', 3),
#  ('Anchor Bay Films', 3),
#  ('21 Laps Entertainment', 3),
#  ('Head Gear Films', 3),
#  ('Hwy61', 3),
#  ('Black Bear Pictures', 3),
#  ('Eros International', 3),
#  ('Film 4', 3),
#  ('Film Four International', 3),
#  ('1984 Private Defense Contractors', 3),
#  ('Starz Animation', 3),
#  ('Arte France', 3),
#  ('Région Ile-de-France', 3),
#  ('Hydraulx', 3),
#  ('Big Kid Pictures', 3),
#  ('The Samuel Goldwyn Company', 3),
#  ('Verisimilitude', 3),
#  ('Evergreen Media Group', 3),
#  ('Telecinco Cinema', 3),
#  ('Prana Studios', 3),
#  ('Twisted Pictures', 3),
#  ('Les Films du Carrosse', 3),
#  ('Lagniappe Films', 3),
#  ('Hammer Film Productions', 3),
#  ('Junction Entertainment', 3),
#  ('Neal Street Productions', 3),
#  ('HanWay Films', 3),
#  ('David Brown Productions', 3),
#  ('Red Granite Pictures', 3),
#  ('Olympus Pictures', 3),
#  ('Bob Yari Productions', 3),
#  ('Les Productions Artistes Associés', 3),
#  ('Atlantic Entertainment Group', 3),
#  ('SKA Films', 3),
#  ('Umedia', 3),
#  ('Broken Road Productions', 3),
#  ('Number 9 Films', 3),
#  ('Haut et Court', 3),
#  ('Nintendo', 3),
#  ('Universal International Pictures (UI)', 3),
#  ('Studio Ghibli', 3),
#  ('Prime Focus', 3),
#  ('Studio Trite', 3),
#  ('Envision Entertainment Corporation', 3),
#  ('Picture Perfect Corporation', 3),
#  ('Room 101', 3),
#  ('Fortis Films', 3),
#  ('Bad Robot', 3),
#  ('Handsomecharlie Films', 3),
#  ('Granada Television', 3),
#  ('Ruby Films', 3),
#  ('Imagine Films Entertainment', 3),
#  ('Kinokompaniya CTB', 3),
#  ('Monarch Pictures', 3),
#  ('Depth of Field', 3),
#  ('Smokehouse Pictures', 3),
#  ('Provident Films', 3),
#  ('Overture Films', 3),
#  ('Tapestry Films', 3),
#  ('Fabula', 3),
#  ('Zephyr Films', 3),
#  ('Filmgate Films', 3),
#  ('Groundswell Productions', 3),
#  ('Don Carmody Productions', 3),
#  ('Kings Road Entertainment', 3),
#  ('China Film Co-Production Corporation', 3),
#  ('Section Eight Productions', 3),
#  ('Mandarin Films Distribution Co.', 3),
#  ('Gold/Miller Productions', 3),
#  ('This Is That Productions', 3),
#  ('Yash Raj Films', 3),
#  ('Saga Film', 3),
#  ('Tig Productions', 3),
#  ('American Entertainment Partners L.P.', 2),
#  ('Nina Saxon Film Design', 2),
#  ('Blue Tulip Productions', 2),
#  ('Magnolia Mae Films', 2),
#  ('Aegis Film Fund', 2),
#  ('Prelude Pictures', 2),
#  ('The Collective', 2),
#  ('Bloody Disgusting', 2),
#  ('8383 Productions', 2),
#  ('New Zealand Film Commission', 2),
#  ('Caramel Film', 2),
#  ('Hasbro', 2),
#  ('Chaocorp', 2),
#  ('Filmstiftung Nordrhein-Westfalen', 2),
#  ('Filmfonds Wien', 2),
#  ('Atmosphere Entertainment MM', 2),
#  ('One Race Films', 2),
#  ('NeoReel', 2),
#  ('Aperture Entertainment', 2),
#  ('TIK Films', 2),
#  ('Drafthouse Films', 2),
#  ('87Eleven', 2),
#  ('British Broadcasting Corporation (BBC)', 2),
#  ('Jalem Productions', 2),
#  ('26 Films', 2),
#  ('Ad Hominem Enterprises', 2),
#  ('Mon Voisin Productions', 2),
#  ('Turner Pictures (I)', 2),
#  ('Cannon Films', 2),
#  ('Company Films', 2),
#  ('VIP 2 Medienfonds', 2),
#  ('Filmfour', 2),
#  ('Spectacle Entertainment Group', 2),
#  ('Protagonist Pictures', 2),
#  ('MFPV Film', 2),
#  ('Les Films Alain Sarde', 2),
#  ('Procirep', 2),
#  ('Film Fund Luxembourg', 2),
#  ('Epic Productions', 2),
#  ('Vision International', 2),
#  ('Vision PDG', 2),
#  ('Film It Suda', 2),
#  ('DJ Films', 2),
#  ('Pinewood Studios', 2),
#  ('Empire Pictures', 2),
#  ('Cott Productions', 2),
#  ('Media Asia Films', 2),
#  ('Sil-Metropole Organisation Ltd.', 2),
#  ('Huayi Brothers Media', 2),
#  ('Australian Film Finance Corporation', 2),
#  ('Discovery Channel Pictures', 2),
#  ('ArieScope Pictures', 2),
#  ('Robert Wise Productions', 2),
#  ('Delux Productions', 2),
#  ('Duplass Brothers Productions', 2),
#  ('Moho Film', 2),
#  ('Social Capital', 2),
#  ('Film Afrika Worldwide', 2),
#  ('Magnet Media Productions', 2),
#  ('Magnet Media Group', 2),
#  ('Smart Entertainment', 2),
#  ('Walt Disney Television Animation', 2),
#  ('Walt Disney Animation Australia', 2),
#  ('Jewel Productions', 2),
#  ('Pimlico Films', 2),
#  ('Incorporated Television Company (ITC)', 2),
#  ('Parabolic Pictures', 2),
#  ('Stable Way Entertainment', 2),
#  ('Solaris Film', 2),
#  ('Kumar Mobiliengesellschaft mbH & Co. Projekt Nr. 1 KG', 2),
#  ('Film Council', 2),
#  ('Scottish Screen', 2),
#  ('Alliance Films', 2),
#  ('Trans Atlantic Entertainment', 2),
#  ('Major Studio Partners', 2),
#  ('Furthur Films', 2),
#  ('Kerner Entertainment Company', 2),
#  ('Triumph Films', 2),
#  ('Casey Silver Productions', 2),
#  ('Zanuck/Brown Productions', 2),
#  ('Stuber Productions', 2),
#  ('Toho', 2),
#  ('China Film Group Corporation (CFGC)', 2),
#  ('Penta Pictures', 2),
#  ('Mostow/Lieberman Productions', 2),
#  ('Free Range Films', 2),
#  ('Keep Your Head', 2),
#  ('Universal City Studios', 2),
#  ('Prana Animation Studios', 2),
#  ('Melvin Simon Productions', 2),
#  ('American International Pictures (AIP)', 2),
#  ('TPS Cinéma', 2),
#  ('Vertigo', 2),
#  ('Star Cinema Productions', 2),
#  ('Red Wagon Entertainment', 2),
#  ('WoWow', 2),
#  ('View Askew Productions', 2),
#  ('Victor & Grais Productions', 2),
#  ('Universal Pictures International (UPI)', 2),
#  ('Parkes/MacDonald Productions', 2),
#  ('Ce Qui Me Meut Motion Pictures', 2),
#  ('Hedge Fund Film Partners', 2),
#  ('Crave Films', 2),
#  ('Knightsbridge Entertainment', 2),
#  ('Kalima Productions GmbH & Co. KG', 2),
#  ('Hemdale Film Corporation', 2),
#  ('No Frills Film Production', 2),
#  ('The Cannon Group', 2),
#  ('Pearl Street Films', 2),
#  ('Alpha Core', 2),
#  ('Simon Kinberg Productions', 2),
#  ('The Rank Organisation', 2),
#  ('Grive Productions', 2),
#  ('Maguire Entertainment', 2),
#  ('AVCO Embassy Pictures', 2),
#  ('Guardian Trust Company', 2),
#  ('Greenestreet Films', 2),
#  ('Eclipse Catering', 2),
#  ('K/O Paper Products', 2),
#  ('Buckaroo Entertainment', 2),
#  ('Topcraft', 2),
#  ('Leverage Entertainment', 2),
#  ('Marvel Knights', 2),
#  ('Bristol Bay Productions', 2),
#  ('Sahara Productions', 2),
#  ('Key Creatives', 2),
#  ('Studio Green', 2),
#  ('Vlaams Audiovisueel fonds', 2),
#  ('Radio Télévision Belge Francophone (RTBF)', 2),
#  ('Page 114', 2),
#  ('VOO', 2),
#  ('Geffen Company, The', 2),
#  ('Virtual Studios', 2),
#  ('Tiger Aspect Productions', 2),
#  ('Colorado Film Production', 2),
#  ('Polar Entertainment', 2),
#  ('Summer Knowledge LLC', 2),
#  ('Paramount Animation', 2),
#  ('Knickerbocker Films', 2),
#  ('Max TV', 2),
#  ('Krane Entertainment', 2),
#  ('Tokyo Broadcasting System (TBS)', 2),
#  ('Mainichi Broadcasting System (MBS)', 2),
#  ('Shochiku Company', 2),
#  ('Shogakukan', 2),
#  ('Gravier Productions', 2),
#  ('Mediapro', 2),
#  ('Pandora Filmproduktion', 2),
#  ('Antena 3 Films', 2),
#  ('Cruel and Unusual Films', 2),
#  ('Les Productions du Trésor', 2),
#  ('Foresight Unlimited', 2),
#  ('Baumgarten Management and Productions (BMP)', 2),
#  ('Radiant Productions', 2),
#  ('ETIC Films', 2),
#  ('Trademark Films', 2),
#  ('Los Hooligans Productions', 2),
#  ('Mayhem Pictures', 2),
#  ('Clifford Werber Productions', 2),
#  ('Hopscotch Features', 2),
#  ('Delphi V Productions', 2),
#  ('Pacific Film and Television Commission', 2),
#  ('Melnitsa Animation Studio', 2),
#  ('icon', 2),
#  ('Andell Entertainment', 2),
#  ('Madhouse Entertainment', 2),
#  ('Linson Entertainment', 2),
#  ('Madras Talkies', 2),
#  ('Ghoulardi Film Company', 2),
#  ('Electric City Entertainment', 2),
#  ('Aascar Films', 2),
#  ('DiNovi Pictures', 2),
#  ('Blossom Films', 2),
#  ('Alphaville Productions', 2),
#  ('DENTSU Music And Entertainment', 2),
#  ('See-Saw Films', 2),
#  ('Animal Kingdom', 2),
#  ('Batjac Productions', 2),
#  ('Gladden Entertainment', 2),
#  ('Sovereign Pictures', 2),
#  ('M6 Films', 2),
#  ('Davis Films', 2),
#  ('William Castle Productions', 2),
#  ('Shadow Shows', 2),
#  ('TAFT Entertainment Pictures', 2),
#  ('Yong Film', 2),
#  ('Ugly Duckling Films', 2),
#  ('Altavista Films', 2),
#  ('Krasnoff Foster Productions', 2),
#  ('Shoebox Films', 2),
#  ('Touchwood Pacific Partners 1', 2),
#  ('Sikelia Productions', 2),
#  ('Rhino Films', 2),
#  ('Offspring Entertainment', 2),
#  ('Eddie Murphy Productions', 2),
#  ('Porchlight Films', 2),
#  ('FilmWorks', 2),
#  ('Marianne Productions', 2),
#  ('Delphi III Productions', 2),
#  ('Blind Spot Pictures Oy', 2),
#  ('Medienboard Berlin-Brandenburg', 2),
#  ('Mandate Pictures', 2),
#  ('Vincent Pictures', 2),
#  ('Bayerischer Rundfunk (BR)', 2),
#  ('Construction Film', 2),
#  ('Red Crown Productions', 2),
#  ('Cube Vision', 2),
#  ('LionsGate', 2),
#  ('Imprint Entertainment', 2),
#  ('Energy Entertainment', 2),
#  ('Stanley Kramer Productions', 2),
#  ('Walt Disney Animation Studios', 2),
#  ('Warp Films', 2),
#  ('C.R.R.A.V. Nord Pas de Calais', 2),
#  ('Région Nord-Pas-de-Calais', 2),
#  ('Mars Media Beteiligungs', 2),
#  ('Type A Films', 2),
#  ('Blackfriars Bridge Films', 2),
#  ('NALA Films', 2),
#  ('Latina Pictures', 2),
#  ('Tax Credit Finance', 2),
#  ('Overnight Films', 2),
#  ('China Film Group', 2),
#  ('U-Drive Productions', 2),
#  ('August Entertainment', 2),
#  ('Dylan Sellers Productions', 2),
#  ('Blue-Tongue Films', 2),
#  ('STX Entertainment', 2),
#  ('Amazon Studios', 2),
#  ('First Generation Films', 2),
#  ('Rook Films', 2),
#  ('Mid Atlantic Films', 2),
#  ('Paramount Classics', 2),
#  ('Block 2 Pictures', 2),
#  ('City Light Films', 2),
#  ('Vendome Pictures', 2),
#  ('Fox Star Studios', 2),
#  ('Charles Chaplin Productions', 2),
#  ('Ferndale Films', 2),
#  ('Inferno Distribution', 2),
#  ('Spelling Films', 2),
#  ('Atlantic Swiss Productions', 2),
#  ('Zanuck Company, The', 2),
#  ('Chambara Pictures', 2),
#  ('Midfield Films', 2),
#  ('WT2 Productions', 2),
#  ('Adam Fields Productions', 2),
#  ('AVM Productions', 2),
#  ('Picture Machine', 2),
#  ("Centre National du Cinéma et de L'image Animée (CNC)", 2),
#  ('Mythology Entertainment (II)', 2),
#  ('Occupant Entertainment', 2),
#  ('Handmade Films Ltd.', 2),
#  ('platinum studios', 2),
#  ('Italian Tax Credit', 2),
#  ('Perdido Productions', 2),
#  ('Ministero per i Beni e le Attività Culturali (MiBAC)', 2),
#  ('Film Victoria', 2),
#  ('House & Moorhouse Films', 2),
#  ('Crest Animation Productions', 2),
#  ('Roth-Arnold Productions', 2),
#  ('Vaca Films', 2),
#  ('Morena Films', 2),
#  ('Telefónica Studios', 2),
#  ('SND', 2),
#  ('Evolution Entertainment', 2),
#  ('Block / Hanson', 2),
#  ('Ram Bergman Productions', 2),
#  ('Oriental Light and Magic', 2),
#  ('Pikachu Project', 2),
#  ('Bridgit Folman Film Gang', 2),
#  ('Televisión Española TVE', 2),
#  ('Quinta Communications', 2),
#  ('Carthago Films S.a.r.l.', 2),
#  ('Doha Film Institute, The', 2),
#  ('Vestron Pictures', 2),
#  ('TC Productions', 2),
#  ('Sony Pictures', 2),
#  ('Frank Yablans Presentations', 2),
#  ('Future Films', 2),
#  ('10th Hole Productions', 2),
#  ('Benaroya Pictures', 2),
#  ('Super Crispy Entertainment', 2),
#  ('SenArt Films', 2),
#  ('Sociedad General de Televisión (Sogetel)', 2),
#  ('Waverly Films', 2),
#  ('Portman Entertainment Group', 2),
#  ('Feigco Entertainment', 2),
#  ('Toho-Towa', 2),
#  ('Marubeni', 2),
#  ('Tele München Fernseh Produktionsgesellschaft (TMG)', 2),
#  ('UGC PH', 2),
#  ('IFC Films', 2),
#  ('Hart-Sharp Entertainment', 2),
#  ('Outlaw Productions (I)', 2),
#  ('Revolution Films', 2),
#  ('Castleberg Productions', 2),
#  ('Maven Pictures', 2),
#  ('Broadway Video', 2),
#  ('Barclays Mercantile Industrial Finance', 2),
#  ('Showbox', 2),
#  ('One Race Productions', 2),
#  ('Crossbow Productions', 2),
#  ('Unique Features', 2),
#  ('Antidote Films', 2),
#  ('Aramid Entertainment Fund', 2),
#  ('Clinica Estetico', 2),
#  ('Herrick Entertainment', 2),
#  ('Lionsgate Premiere', 2),
#  ('Hypnotic', 2),
#  ('BBC', 2),
#  ('Huayi Brothers', 2),
#  ('Translux', 2),
#  ('International Film Investors', 2),
#  ('Anton Capital Entertainment (ACE)', 2),
#  ('Potboiler Productions', 2),
#  ('La Fabrique 2', 2),
#  ('Tornasol Films', 2),
#  ('Castafiore Films', 2),
#  ('Road Rebel', 2),
#  ('Dear Film Produzione', 2),
#  ('Astral Media', 2),
#  ('Buffalo Gal Pictures', 2),
#  ('Blake Edwards', 2),
#  ('Silver Screen Partners', 2),
#  ('Iris productions', 2),
#  ('Live Entertainment', 2),
#  ('Trimark Pictures', 2),
#  ('Carolco International N.V.', 2),
#  ('Mockingbird Pictures', 2),
#  ('Motown Productions', 2),
#  ('Permut Presentations', 2),
#  ('Denver and Delilah Productions', 2),
#  ('Pacific Standard', 2),
#  ('Brooksfilms', 2),
#  ('Georgetown Productions Inc.', 2),
#  ('Amen Ra Films', 2),
#  ('Twins Financing', 2),
#  ('Lorimar Motion Pictures', 2),
#  ('The Asylum', 2),
#  ('Mosfilm', 2),
#  ('Alfred J. Hitchcock Productions', 2),
#  ('Lotte Entertainment', 2),
#  ('Creative England', 2),
#  ('Anka Film', 2),
#  ('Filmförderung Hamburg', 2),
#  ('CinemaNX', 2),
#  ('Next Entertainment World', 2),
#  ('ARD Degeto Film', 2),
#  ('Canadian Film or Video Production Tax Credit (CPTC)', 2),
#  ('Envision Entertainment', 2),
#  ('Channel One Russia', 2),
#  ('TABBAK', 2),
#  ('Good Machine', 2),
#  ('Rising Sun Films', 2),
#  ('Boll Kino Beteiligungs GmbH & Co. KG', 2),
#  ('Brightlight Pictures', 2),
#  ('Herold Productions', 2),
#  ('Stage 6 Films', 2),
#  ('Belladonna Productions', 2),
#  ('QC Entertainment', 2),
#  ('Entertainment One', 2),
#  ('Rickshaw Productions', 2),
#  ('Planet Productions', 2),
#  ('Backup Films', 2),
#  ('Creative Scotland', 2),
#  ('Furst Films', 2),
#  ('Nic Arts', 2),
#  ('Mimran Schur Pictures', 2),
#  ('Producers Sales Organization (PSO)', 2),
#  ('Lion Rock Productions', 2),
#  ('Romulus Films', 2),
#  ('Rankin/Bass Productions', 2),
#  ('NEST Family Entertainment', 2),
#  ('Rich Animation Studios', 2),
#  ('Park Pictures', 2),
#  ('Houston King Productions', 2),
#  ('Upload Films', 2),
#  ('Samuel Goldwyn Company', 2),
#  ('Fox Atomic', 2),
#  ('Midnight Sun Pictures', 2),
#  ('City Films', 2),
#  ('October Films', 2),
#  ('The Department of Trade and Industry of South Africa', 2),
#  ('Société Nationale Pathé Cinéma', 2),
#  ('Steel Mill Pictures', 2),
#  ('Gordon Company', 2),
#  ('Sherwood Pictures', 2),
#  ('Rainforest Films', 2),
#  ('Dragonfly Entertainment', 2),
#  ('EFTI', 2),
#  ('MediaPro Pictures', 2),
#  ('Haxan Films', 2),
#  ('David Ladd Films', 2),
#  ('Strike Entertainment', 2),
#  ('Nu Image Entertainment GmbH', 2),
#  ('G.W. Films', 2),
#  ('Telefe', 2),
#  ('Raaj Kamal Films International', 2),
#  ('Mindshare Media', 2),
#  ('Media Asia Film', 2),
#  ('Media Rights Capital (MRC)', 2),
#  ('120dB Films', 2),
#  ('Entre Chien et Loup', 2),
#  ('Altitude Film Entertainment', 2),
#  ('Scope Pictures', 2),
#  ('Portobello Pictures', 2),
#  ('Opus Film', 2),
#  ('Polski Instytut Sztuki Filmowej', 2),
#  ('Next Wednesday Productions', 2),
#  ('Mandalay Vision', 2),
#  ('Gilbert Films', 2),
#  ('Fidélité Films', 2),
#  ('USA Films', 2),
#  ('Bedford Falls Company, The', 2),
#  ('Zenith Entertainment', 2),
#  ('Initial Pictures', 2),
#  ('Image Entertainment', 2),
#  ('Samuel Bronston Productions', 2),
#  ('Cinerenta Medienbeteiligungs KG', 2),
#  ('LivePlanet', 2),
#  ('Kontsept Film Company', 2),
#  ('Sil-Metropole Organisation', 2),
#  ('Insurge Pictures', 2),
#  ('Orion Pictures Corporation', 2),
#  ('Mosaic Media Group', 2),
#  ('Sean Daniel Company', 2),
#  ('International Traders', 2),
#  ('ContentFilm', 2),
#  ('El Deseo', 2),
#  ('CiBy 2000', 2),
#  ('La Petite Reine', 2),
#  ('Ecosse Films', 2),
#  ('Radar Pictures', 2),
#  ('Moonlighting Films', 2),
#  ('Callahan Filmworks', 2),
#  ('Twentieth Century Fox', 2),
#  ('Mod Producciones', 2),
#  ('Sun Pictures', 2),
#  ('Hard Eight Pictures', 2),
#  ('Le Tax Shelter du Gouvernement Fédéral de Belgique', 2),
#  ('Karz Entertainment', 2),
#  ('Gulfstream Pictures', 2),
#  ("Gettin' Rad Productions", 2),
#  ('Nine Yards Productions', 2),
#  ('IFC Productions', 2),
#  ('RT Features', 2),
#  ('Burn Later Productions', 2),
#  ('Egoli Tossell Film', 2),
#  ('Heyday films', 2),
#  ('Amblimation', 2),
#  ('Wayans Bros. Entertainment', 2),
#  ('Brad Grey Pictures', 2),
#  ('Golan-Globus', 2),
#  ('Michael White Productions', 2),
#  ('Incorporated Television Company', 2),
#  ('Fox Animation Studios', 2),
#  ('American Empirical Pictures', 2),
#  ('EMI Films', 2),
#  ('Desperate Pictures', 2),
#  ('Reveal Entertainment', 2),
#  ('Boram Entertainment Inc.', 2),
#  ('APJAC Productions', 2),
#  ('Kasdan Pictures', 2),
#  ('Act III Communications', 2),
#  ('ABC Pictures', 2),
#  ('Josephson Entertainment', 2),
#  ('Thousand Words', 2),
#  ('Dentsu Inc.', 2),
#  ('Star Partners II Ltd.', 2),
#  ...]

# %% [markdown]
# Films produced by Warner Bros , Universal pictures , Paramount have been represented more in this dataset.

# %% [markdown]
# Lets create a column - the number of production companies backing a movie , list of production company for a movie and whether top production company has been backing a movie.We create columns of production companies if it is backed by one of the top 15 production companies .

# %%
train['prod_comp']=train['production_companies'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
train['num_prod']=train['production_companies'].apply(lambda x:len(x) if x!={} else 0)
top_prod=[m[0] for m in Counter([i for j in prod_comp_list for i in j]).most_common(15)]
for g in top_prod:
    train['prod_' + g] = train['prod_comp'].apply(lambda x: 1 if g in x else 0)
    
test['prod_comp']=test['production_companies'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
test['num_prod']=test['production_companies'].apply(lambda x:len(x) if x!={} else 0)
for g in top_prod:
    test['prod_' + g] = test['prod_comp'].apply(lambda x: 1 if g in x else 0)
    
train=train.drop('production_companies',axis=1)
test=test.drop('production_companies',axis=1)

# %%
train[['prod_comp','num_prod']].head()
# Out:
#                                            prod_comp  num_prod
# 0  Metro-Goldwyn-Mayer (MGM) Paramount Pictures U...         3
# 1                               Walt Disney Pictures         1
# 2  Blumhouse Productions Bold Films Right of Way ...         3
# 3                                                            0
# 4                                                            0

# %% [markdown]
# ### Production Countries

# %%
for i,e in enumerate(train['production_countries'].head()):
    print(i,e)
# Out:
# 0 [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 1 [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 2 [{'iso_3166_1': 'US', 'name': 'United States of America'}]
# 3 [{'iso_3166_1': 'IN', 'name': 'India'}]
# 4 [{'iso_3166_1': 'KR', 'name': 'South Korea'}]

# %% [markdown]
# We take only the name from this column and create a feature.

# %%
train['production_countries'].apply(lambda x:len(x) if x!={} else 0).value_counts()
# Out:
# 1    2222
# 2     525
# 3     116
# 4      57
# 0      55
# 5      21
# 6       3
# 8       1
# Name: production_countries, dtype: int64

# %% [markdown]
# It is interesting to see that there are around 25 movies backed by more than 5 countries . Lets check which moves are they sorted by popularity.

# %%
train[train['production_countries'].apply(lambda x:len(x) if x!={} else 0) >=5][['original_title','popularity']].sort_values('popularity',ascending=False)
# Out:
#                       original_title  popularity
# 60                     Casino Royale   23.065078
# 777                   The Great Wall   15.884744
# 1775                           Filth   14.970485
# 710                         Hysteria   14.331454
# 801                Love & Friendship   12.822085
# 1606               Louder Than Bombs   12.293202
# 1338          The Secret of Moonacre   12.013340
# 2185      1492: Conquest of Paradise   11.618792
# 2170                     The Lobster   11.223033
# 2517     Astérix aux Jeux Olympiques    9.671944
# 2244                     Match Point    9.020372
# 2314                    The Congress    8.534039
# 33                   ABCs of Death 2    8.254856
# 1001                   The Salvation    8.253705
# 71            Diarios de motocicleta    7.667491
# 210    An American Werewolf in Paris    7.145784
# 1127                           Virus    7.116537
# 2360                          Neruda    6.997583
# 2810        Every Thing Will Be Fine    5.723103
# 31                             Caché    5.695860
# 1331                          وجدة‎‎    5.451273
# 661              Den Skaldede Frisør    4.711231
# 787              Batalla en el cielo    2.329513
# 2053  The Man with Rain in His Shoes    1.217192
# 2237                         Sankofa    0.045860

# %% [markdown]
# Lets create a column for the production country , number of production countries and most common production countries similar to what we did for genere and production company.

# %%
prod_count_list=list(train['production_countries'].apply(lambda x:[i['name'] for i in x] if x!={} else []).values)

# %%
prod_count_list
# Out:
# [['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['South Korea'],
#  [],
#  ['United States of America', 'Canada'],
#  [],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Serbia'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Austria', 'Germany', 'United Kingdom'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['New Zealand'],
#  ['Japan', 'United States of America'],
#  ['United States of America'],
#  ['Canada', 'Ireland'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['Austria', 'France', 'Germany', 'Italy', 'United States of America'],
#  ['United States of America'],
#  ['United States of America', 'New Zealand', 'Canada', 'Israel', 'Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Ireland', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  [],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Belgium'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'Germany'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy',
#   'United Kingdom',
#   'United States of America',
#   'Czech Republic',
#   'Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['China', 'France', 'Japan'],
#  ['United States of America'],
#  ['Japan', 'United States of America'],
#  ['Germany', 'United States of America'],
#  ['Brazil',
#   'Argentina',
#   'Chile',
#   'France',
#   'Germany',
#   'Peru',
#   'United Kingdom',
#   'United States of America'],
#  ['United States of America'],
#  ['Czech Republic'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['Germany', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Hong Kong'],
#  ['Czech Republic', 'United Kingdom', 'United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['Italy'],
#  ['France'],
#  ['United Kingdom'],
#  ['France', 'United States of America'],
#  ['Russia'],
#  ['France'],
#  ['Russia'],
#  ['Spain'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['South Korea'],
#  ['United States of America'],
#  ['Turkey'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['New Zealand', 'United States of America'],
#  ['United States of America'],
#  ['China'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'Hong Kong'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'China', 'Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America', 'United Kingdom', 'Germany', 'Sweden'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'Luxembourg'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['South Korea', 'France', 'Czech Republic', 'United States of America'],
#  ['United States of America'],
#  ['South Africa', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'Canada', 'United States of America'],
#  ['Russia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Australia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'United Kingdom'],
#  ['Germany', 'United States of America'],
#  ['Switzerland', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America', 'Germany'],
#  ['Ireland', 'United Kingdom'],
#  ['United States of America'],
#  ['Japan', 'United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Iran'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan', 'United States of America'],
#  ['Canada', 'United Kingdom', 'United States of America'],
#  ['United States of America', 'Morocco'],
#  ['France',
#   'United Kingdom',
#   'Luxembourg',
#   'Netherlands',
#   'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan'],
#  ['United States of America'],
#  ['Sweden'],
#  ['France', 'United States of America'],
#  ['China', 'Hong Kong'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['Australia', 'France', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany', 'Ireland', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['France', 'United Kingdom'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Spain'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India', 'United States of America'],
#  ['Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Austria', 'Germany', 'Italy'],
#  ['Australia', 'United States of America'],
#  ['United Kingdom'],
#  ['France'],
#  ['France', 'Germany', 'Italy', 'United States of America'],
#  ['United States of America'],
#  ['Russia'],
#  ['Philippines'],
#  ['United States of America'],
#  ['Iceland', 'United States of America', 'United Kingdom'],
#  ['United States of America'],
#  ['Japan'],
#  [],
#  ['United States of America'],
#  ['Germany', 'United Kingdom', 'United States of America'],
#  ['Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany', 'United Kingdom', 'United States of America'],
#  [],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['Ireland', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Ireland', 'United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Brazil'],
#  ['Germany', 'United States of America'],
#  ['Russia'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'Italy'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America', 'Canada'],
#  ['Canada', 'France'],
#  ['United States of America'],
#  ['Denmark', 'Sweden', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['Japan'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['Canada', 'Hong Kong', 'Taiwan', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['Australia'],
#  ['Canada'],
#  ['China'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America', 'France'],
#  ['Japan', 'South Korea'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'Taiwan'],
#  ['Russia', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Japan'],
#  ['United States of America'],
#  ['Hong Kong', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'Germany', 'United States of America'],
#  ['United States of America'],
#  ['Germany', 'Spain', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'New Zealand', 'United States of America'],
#  ['Mongolia', 'United States of America', 'United Kingdom'],
#  ['India'],
#  ['Russia'],
#  ['France', 'Belgium'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Canada', 'United Kingdom'],
#  ['Germany', 'United States of America'],
#  ['France', 'United Kingdom'],
#  ['United States of America'],
#  ['France', 'United Kingdom'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America', 'France', 'Germany'],
#  ['United States of America'],
#  ['Brazil', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy'],
#  ['Russia'],
#  ['France', 'Switzerland'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Netherlands'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['Japan'],
#  ['Italy'],
#  ['United States of America'],
#  ['India'],
#  ['Spain', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Hungary', 'Serbia', 'Spain', 'United States of America'],
#  ['Ireland'],
#  ['France'],
#  ['United States of America'],
#  ['Spain'],
#  ['Australia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['France', 'United States of America'],
#  ['Mexico', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'United Kingdom'],
#  ['United States of America'],
#  ['Brazil', 'France'],
#  ['United States of America'],
#  ['Canada'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'France', 'Belgium'],
#  [],
#  ['United States of America'],
#  ['Australia', 'United States of America'],
#  ['Germany', 'United States of America'],
#  ['Czech Republic', 'Germany', 'United Kingdom', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['Ireland', 'United Kingdom', 'Denmark'],
#  ['United States of America'],
#  [],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['Netherlands'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'Australia'],
#  ['United States of America'],
#  [],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['Austria', 'Hungary'],
#  ['United States of America', 'Russia'],
#  ['Mexico'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Russia'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['Australia'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  [],
#  ['United States of America'],
#  ['France', 'Italy'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan', 'United States of America'],
#  ['Romania', 'United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United Kingdom'],
#  ['Hungary', 'United States of America'],
#  ['United States of America', 'United Kingdom', 'Germany'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'United Kingdom', 'United States of America'],
#  ['Italy', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['New Zealand', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['Mexico', 'South Africa', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan'],
#  ['United States of America'],
#  ['Australia'],
#  ['United States of America'],
#  ['Germany', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Spain'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['France', 'Ireland', 'United Kingdom', 'United States of America'],
#  ['France', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['Canada', 'France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['India'],
#  ['France', 'Australia', 'Canada', 'Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Russia'],
#  ['United States of America'],
#  ['Greece', 'United States of America'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'United Arab Emirates'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['China', 'Hong Kong'],
#  ['United States of America'],
#  ['Canada'],
#  [],
#  ['United States of America'],
#  ['South Korea'],
#  ['United States of America', 'Spain'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United Kingdom'],
#  ['Mexico'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Sweden', 'Germany', 'France'],
#  ['Canada', 'United States of America'],
#  ['Mexico', 'Puerto Rico', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  [],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  [],
#  ['United States of America'],
#  ['New Zealand'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Mexico', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan'],
#  ['Australia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  [],
#  ['Japan'],
#  ['Spain'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'France', 'Germany', 'Italy'],
#  ['Finland', 'Germany', 'Australia'],
#  ['Germany', 'United Kingdom', 'United States of America'],
#  ['Denmark', 'France', 'Italy', 'Sweden', 'Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  [],
#  ['United States of America'],
#  ['New Zealand', 'United States of America'],
#  ['Ireland', 'United Kingdom', 'United States of America'],
#  ['Ireland', 'United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['Cambodia', 'United States of America'],
#  ['United States of America'],
#  ['Italy', 'Germany'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['India'],
#  ['United States of America', 'Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['Luxembourg', 'United Kingdom', 'France', 'Germany', 'Switzerland'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'United Arab Emirates'],
#  ['United States of America'],
#  ['France', 'United Kingdom'],
#  ['Australia', 'United States of America'],
#  ['Spain'],
#  ['Hong Kong'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'Norway', 'Poland'],
#  ['United States of America'],
#  ['Australia'],
#  ['South Korea'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  [],
#  ['Germany', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United Arab Emirates', 'United States of America'],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America', 'France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany', 'United States of America'],
#  ['Germany', 'United States of America'],
#  [],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Hong Kong'],
#  ['United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany'],
#  ['United States of America', 'Malta'],
#  ['United Kingdom'],
#  ['Germany', 'United States of America', 'China'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['Brazil', 'France', 'Greece', 'United States of America'],
#  ['Namibia', 'United States of America', 'South Africa'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'United States of America', 'United Kingdom'],
#  ['Australia', 'Canada', 'China', 'Hong Kong', 'United States of America'],
#  ['United States of America'],
#  ['France', 'Germany', 'United Kingdom', 'United States of America'],
#  ['United States of America', 'Finland'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['Mexico', 'Belgium', 'Netherlands', 'Germany', 'France'],
#  ['United States of America'],
#  ['China', 'Hong Kong'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['South Korea'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom',
#   'United States of America',
#   'Ireland',
#   'Netherlands',
#   'France'],
#  ['France', 'United States of America'],
#  ['United States of America'],
#  ['Australia', 'United States of America'],
#  ['Spain', 'United States of America'],
#  ['United States of America'],
#  ['Bosnia and Herzegovina', 'Turkey'],
#  ['United Kingdom'],
#  ['Hungary', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America', 'Canada', 'Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['China', 'Hong Kong'],
#  ['China'],
#  ['United States of America'],
#  [],
#  ['United States of America'],
#  ['France', 'United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['France'],
#  ['United States of America'],
#  ['United States of America', 'Canada'],
#  ['United States of America'],
#  ['Australia', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['France'],
#  ['South Africa'],
#  ['United States of America'],
#  ['Italy', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United Kingdom', 'Germany', 'United States of America'],
#  ['United States of America'],
#  ['Ireland'],
#  ['United States of America'],
#  ['Finland'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Arab Emirates', 'United States of America'],
#  ['United States of America'],
#  ['Spain', 'United States of America'],
#  ['Greece', 'United States of America'],
#  ['United Kingdom'],
#  ['United States of America'],
#  ['Czech Republic', 'Germany', 'United Kingdom'],
#  ['United States of America'],
#  ['Germany'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Spain', 'Canada'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy', 'Serbia and Montenegro', 'United States of America'],
#  ['United States of America'],
#  ['United Arab Emirates', 'United States of America'],
#  ['Canada', 'United States of America'],
#  ['Russia'],
#  ['United Kingdom', 'United States of America'],
#  ['Philippines'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['France', 'United Kingdom'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Canada', 'United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['Cambodia', 'France'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'Australia'],
#  ['United States of America'],
#  ['South Korea'],
#  ['France'],
#  ['China', 'Hong Kong', 'United States of America'],
#  ['United States of America'],
#  ['Czech Republic', 'France', 'United Kingdom'],
#  ['Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['Canada'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan', 'United States of America'],
#  ['Spain'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['United Kingdom'],
#  ['Canada', 'United States of America'],
#  ['Pakistan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Mexico', 'United States of America'],
#  ['India'],
#  ['Hong Kong', 'China'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America'],
#  ['Japan', 'United States of America'],
#  ['South Korea'],
#  ['United States of America'],
#  ['United Kingdom', 'United States of America', 'France', 'Italy'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Spain', 'United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy', 'Spain', 'United States of America'],
#  ['France', 'Italy'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Italy'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Germany'],
#  ['United Kingdom', 'United States of America'],
#  ['United States of America'],
#  ['France', 'Spain'],
#  ['Italy', 'Algeria'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Australia', 'France'],
#  ['United States of America', 'India', 'France'],
#  ['United States of America'],
#  ['India'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America', 'India'],
#  ['United States of America'],
#  ['Italy'],
#  ['France'],
#  [],
#  ['United States of America'],
#  ['United States of America'],
#  ['Argentina', 'France', 'Spain'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United Kingdom'],
#  ['Ethiopia'],
#  ['United States of America'],
#  ['United States of America'],
#  ['United States of America'],
#  ['Japan'],
#  ['Japan'],
#  ['United States of America'],
#  ['United States of America'],
#  ['France', 'Italy'],
#  ...]

# %%
Counter([i for j in prod_count_list for i in j]).most_common()
# Out:
# [('United States of America', 2282),
#  ('United Kingdom', 380),
#  ('France', 222),
#  ('Germany', 167),
#  ('Canada', 120),
#  ('India', 81),
#  ('Italy', 64),
#  ('Japan', 61),
#  ('Australia', 61),
#  ('Russia', 58),
#  ('Spain', 54),
#  ('China', 42),
#  ('Hong Kong', 42),
#  ('Ireland', 23),
#  ('Belgium', 23),
#  ('South Korea', 22),
#  ('Mexico', 19),
#  ('Sweden', 18),
#  ('New Zealand', 17),
#  ('Netherlands', 15),
#  ('Czech Republic', 14),
#  ('Denmark', 13),
#  ('Brazil', 12),
#  ('Luxembourg', 10),
#  ('South Africa', 10),
#  ('Hungary', 9),
#  ('United Arab Emirates', 9),
#  ('Austria', 8),
#  ('Switzerland', 8),
#  ('Romania', 8),
#  ('Greece', 7),
#  ('Norway', 7),
#  ('Argentina', 6),
#  ('Chile', 6),
#  ('Finland', 6),
#  ('Israel', 5),
#  ('Turkey', 5),
#  ('Iran', 5),
#  ('Poland', 5),
#  ('Morocco', 3),
#  ('Philippines', 3),
#  ('Taiwan', 3),
#  ('Bulgaria', 3),
#  ('Bahamas', 3),
#  ('Serbia', 2),
#  ('Iceland', 2),
#  ('Cambodia', 2),
#  ('Malta', 2),
#  ('Pakistan', 2),
#  ('Qatar', 2),
#  ('Tunisia', 2),
#  ('Ukraine', 2),
#  ('Singapore', 2),
#  ('Indonesia', 2),
#  ('Peru', 1),
#  ('Mongolia', 1),
#  ('Puerto Rico', 1),
#  ('Namibia', 1),
#  ('Bosnia and Herzegovina', 1),
#  ('Serbia and Montenegro', 1),
#  ('Algeria', 1),
#  ('Ethiopia', 1),
#  ('Portugal', 1),
#  ('Slovenia', 1),
#  ('Saudi Arabia', 1),
#  ('Jordan', 1),
#  ('Croatia', 1),
#  ('Cyprus', 1),
#  ('Uruguay', 1),
#  ('Paraguay', 1),
#  ('Mauritania', 1),
#  ('Costa Rica', 1),
#  ('Burkina Faso', 1),
#  ('Ghana', 1)]

# %% [markdown]
# Most of the movies in the database are produced by USA,UK,France and Germany

# %%
train['prod_country']=train['production_countries'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
train['num_country']=train['production_countries'].apply(lambda x:len(x) if x!={} else 0)
top_countries=[m[0] for m in Counter([i for j in prod_comp_list for i in j]).most_common(15)]
for g in top_prod:
    train['count_' + g] = train['prod_country'].apply(lambda x: 1 if g in x else 0)
    
test['prod_country']=test['production_countries'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
test['num_country']=test['production_countries'].apply(lambda x:len(x) if x!={} else 0)
for g in top_prod:
    test['count_' + g] = test['prod_country'].apply(lambda x: 1 if g in x else 0)
    
train=train.drop('production_countries',axis=1)
test=test.drop('production_countries',axis=1)

# %% [markdown]
# ### Spoken Languages

# %% [markdown]
# Lets check the spoken languages column.

# %%
for i,e in enumerate(train['spoken_languages'].head()):
    print(i,e)
# Out:
# 0 [{'iso_639_1': 'en', 'name': 'English'}]
# 1 [{'iso_639_1': 'en', 'name': 'English'}]
# 2 [{'iso_639_1': 'en', 'name': 'English'}]
# 3 [{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 4 [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]

# %% [markdown]
# Lets check which language movies are most represented in the database.

# %%
list_of_lang=list(train['spoken_languages'].apply(lambda x:[i['name'] for i in x] if x!={} else []).values)

# %%
Counter(i for j in list_of_lang for i in j).most_common(10)
# Out:
# [('English', 2618),
#  ('Français', 288),
#  ('Español', 239),
#  ('Deutsch', 169),
#  ('Pусский', 152),
#  ('Italiano', 124),
#  ('日本語', 89),
#  ('普通话', 68),
#  ('हिन्दी', 56),
#  ('', 47)]

# %% [markdown]
# English , France ,Spanish movies are most represented in the database .Lets create a column having the languages, number of languages and whether the movie is shot in top 5 most common language.

# %%
train['lang']=train['spoken_languages'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
train['num_lang']=train['spoken_languages'].apply(lambda x:len(x) if x!={} else 0)
top_langs=[m[0] for m in Counter([i for j in prod_comp_list for i in j]).most_common(5)]
for g in top_langs:
    train['lang_' + g] = train['lang'].apply(lambda x: 1 if g in x else 0)
    
test['lang']=test['spoken_languages'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
test['num_lang']=test['spoken_languages'].apply(lambda x:len(x) if x!={} else 0)
for g in top_langs:
    test['lang_' + g] = test['lang'].apply(lambda x: 1 if g in x else 0)
    
train=train.drop('spoken_languages',axis=1)
test=test.drop('spoken_languages',axis=1)

# %% [markdown]
# ### Keywords

# %% [markdown]
# Lets now check the keywords.

# %%
train['Keywords'].head()
# Out:
# 0    [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1    [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2    [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3    [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   {}
# Name: Keywords, dtype: object

# %%
for i,e in enumerate(train['Keywords'].head()):
    print(i,e)
# Out:
# 0 [{'id': 4379, 'name': 'time travel'}, {'id': 9663, 'name': 'sequel'}, {'id': 11830, 'name': 'hot tub'}, {'id': 179431, 'name': 'duringcreditsstinger'}]
# 1 [{'id': 2505, 'name': 'coronation'}, {'id': 4263, 'name': 'duty'}, {'id': 6038, 'name': 'marriage'}, {'id': 13072, 'name': 'falling in love'}]
# 2 [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'name': 'obsession'}, {'id': 1640, 'name': 'conservatory'}, {'id': 2176, 'name': 'music teacher'}, {'id': 14512, 'name': 'new york city'}, {'id': 14819, 'name': 'violence'}, {'id': 33896, 'name': 'montage'}, {'id': 156823, 'name': 'drummer'}, {'id': 170418, 'name': 'public humiliation'}, {'id': 176095, 'name': 'jazz band'}, {'id': 206298, 'name': 'young adult'}, {'id': 207739, 'name': 'music school'}]
# 3 [{'id': 10092, 'name': 'mystery'}, {'id': 10540, 'name': 'bollywood'}, {'id': 11734, 'name': 'police corruption'}, {'id': 14536, 'name': 'crime'}, {'id': 14636, 'name': 'india'}, {'id': 208364, 'name': 'missing husband'}, {'id': 220935, 'name': 'nerve gas'}]
# 4 {}

# %% [markdown]
# We find that a single movie has multiple keywords.Lets check the most common keywords in the database.

# %%
kwds=list(train['Keywords'].apply(lambda x:[i['name'] for i in x] if x!={} else []).values)

# %%
kwds
# Out:
# [['time travel', 'sequel', 'hot tub', 'duringcreditsstinger'],
#  ['coronation', 'duty', 'marriage', 'falling in love'],
#  ['jazz',
#   'obsession',
#   'conservatory',
#   'music teacher',
#   'new york city',
#   'violence',
#   'montage',
#   'drummer',
#   'public humiliation',
#   'jazz band',
#   'young adult',
#   'music school'],
#  ['mystery',
#   'bollywood',
#   'police corruption',
#   'crime',
#   'india',
#   'missing husband',
#   'nerve gas'],
#  [],
#  [],
#  [],
#  ['journalism',
#   'translation',
#   'television',
#   'manipulation of the media',
#   'iraq',
#   'reporter',
#   'woman director'],
#  ['island', 'pirate gang', 'puppet', 'treasure hunt'],
#  ['mockumentary', 'folk singer'],
#  ['underdog',
#   'philadelphia',
#   'transporter',
#   'italo-american',
#   'fight',
#   "love of one's life",
#   'publicity',
#   'boxer',
#   'independence',
#   'boxing match',
#   'training',
#   'lovers',
#   'surprise',
#   'world champion',
#   'amateur',
#   'victory'],
#  ['nerd', 'vacation', 'farce', 'jock', 'frame up', 'defector'],
#  ['male nudity',
#   'female nudity',
#   'adultery',
#   'parent child relationship',
#   'midlife crisis',
#   'coming out',
#   'first time',
#   'camcorder',
#   'virgin',
#   'nudity',
#   'film maker',
#   'estate agent',
#   'satire',
#   'loneliness',
#   'dark comedy',
#   'suburbia',
#   'coming of age',
#   'marijuana',
#   'exercise',
#   'bittersweet',
#   'affair'],
#  ['baseball bat',
#   'widow',
#   'recording contract',
#   'recording studio',
#   'russian mafia',
#   'music business',
#   'night club',
#   'pawnshop'],
#  ['self-fulfilling prophecy',
#   'washington d.c.',
#   'evidence',
#   'future',
#   'hologram',
#   'dystopia',
#   'murder',
#   'neo-noir',
#   'future noir'],
#  ['skinhead', 'serbia'],
#  ['hostage', 'menace', 'hitman', 'airplane'],
#  ['biography', 'charles dickens'],
#  ['competition',
#   'snowboarding',
#   'birthday party',
#   'chalet',
#   'snowboarding competition',
#   'skiing',
#   'engagement party'],
#  ['martial arts', 'war on drugs', 'kidnapping', 'bodyguard', 'baby-snatching'],
#  ['time travel', 'sabotage', 'deep space explorer'],
#  ['lake',
#   'summer camp',
#   'murder',
#   'serial killer',
#   'slasher',
#   'summer',
#   'jason voorhees',
#   'one by one',
#   'friday the thirteenth'],
#  ['webcam',
#   'anthology',
#   'vhs',
#   'burglary',
#   'split screen',
#   'found footage',
#   'mumblecore',
#   'ghost child',
#   'boxer shorts',
#   'vcr',
#   'halloween mask',
#   'mumblegore',
#   'horror anthology'],
#  [],
#  ['new zealand', 'sheep', 'animal horror'],
#  [],
#  ['dialogue', 'confidence', 'invention', 'independent film'],
#  ['male female relationship', 'best friend', 'falling in love'],
#  ['toy',
#   'transformation',
#   'based on toy',
#   'transformers',
#   'robots',
#   'intergalactic war'],
#  ['new york', 'custody battle', 'suspense', 'lawyer'],
#  ['male friendship',
#   'masseuse',
#   'friendship',
#   'aristocrat',
#   'interracial friendship',
#   'unlikely friendship',
#   'duringcreditsstinger'],
#  ['paris',
#   'upper class',
#   'puberty',
#   'anonymous letter',
#   'suppressed past',
#   'massacre on french algerians 1961',
#   'confidence',
#   'moderator',
#   'camcorder',
#   'menace',
#   'lie',
#   'algerian',
#   'videoband',
#   'intellectual',
#   'conscience'],
#  ['new york', 'witch', 'uprising', 'witch hunter'],
#  ['anthology', 'woman director', 'mumblegore', 'horror anthology'],
#  ['ambassador'],
#  ['broken trachea'],
#  ['sex',
#   'waitress',
#   'sister sister relationship',
#   'infidelity',
#   'virgin',
#   'seduction',
#   'brother',
#   'girlfriend',
#   'marriage',
#   'engagement',
#   'love',
#   'independent film',
#   'relationship',
#   'customer'],
#  ['river',
#   'general',
#   'research',
#   'army',
#   'serum',
#   'monkey',
#   'epidemic',
#   'medical research'],
#  [],
#  ['mexico', 'prisoners of war', 'apache', 'raid', 'confederate'],
#  ['cocaine', 'drug dealer'],
#  ['prison',
#   'rebel',
#   'loss of mother',
#   'harassment',
#   'imprisonment',
#   'dying and death',
#   'boxing match',
#   'escape',
#   'barbed wire',
#   'punched in the face',
#   'eggs',
#   'death'],
#  ['gay',
#   'parent child relationship',
#   'custody battle',
#   'flush',
#   'yoga',
#   'single',
#   'best friend',
#   'los angeles',
#   'single father',
#   'co-parenting'],
#  ['new york', 'married couple', 'moving out', 'moving', 'apartment'],
#  ['based on novel',
#   'callboy',
#   'wedding',
#   'escort',
#   'fake boyfriend',
#   'woman director'],
#  ['suicide',
#   'sex',
#   'hotel',
#   'dream',
#   'psychology',
#   'loss',
#   'cop',
#   'love',
#   'microphone',
#   'photograph',
#   'death of lover'],
#  ['mammoth',
#   'sloth',
#   'ice age',
#   'barrier ice',
#   'ice melting',
#   'iceberg',
#   'flooding',
#   'adventure',
#   'lovers',
#   'deluge',
#   'saber-toothed tiger'],
#  ['bounty hunter',
#   'wyoming',
#   'mountain',
#   'narration',
#   'hangman',
#   'stagecoach',
#   'blizzard',
#   'post civil war'],
#  ['naivety',
#   'oddball',
#   'daughter',
#   'misfit',
#   'dog',
#   'divorcee',
#   'based on graphic novel',
#   'middle aged man'],
#  ['based on tv series',
#   'death',
#   'exploding planet',
#   'mountain cabin',
#   'solar system'],
#  ['supermarket',
#   'midlife crisis',
#   'truck',
#   'urban',
#   'lesbian',
#   'working class',
#   'cell phone',
#   'happiness',
#   'truck driver',
#   'tarot'],
#  ['slapstick',
#   'ensemble cast',
#   'automobile racing',
#   'cross country race',
#   'turn of the century'],
#  ['kids and family', 'aviation', 'castaway', 'pacific island', 'kids'],
#  ['from backpacks to strollers'],
#  ['christianity',
#   'jesus christ',
#   'apostle',
#   'crucifixion',
#   'jerusalem',
#   'ancient rome',
#   'faith',
#   'resurrection',
#   'dead body',
#   'judaism',
#   'religious',
#   'tomb'],
#  ['college', 'thanksgiving', 'farm', 'liar', 'pancreas', 'thong', 'city boy'],
#  ['chess', 'bicycle', 'woman director'],
#  ['double life',
#   'dc comics',
#   'dual identity',
#   'crime fighter',
#   'fictional place',
#   'gotham city',
#   'superhero',
#   'credit card',
#   'super powers'],
#  ['gay',
#   'shakespeare',
#   'homophobia',
#   'musical',
#   'high school',
#   'independent film',
#   'gay relationship',
#   'lgbt child',
#   'lgbt'],
#  ['record store',
#   'sexuality',
#   'autograph',
#   'underwear',
#   'painting',
#   'safe',
#   'sexual attraction',
#   'motorcycle',
#   'juvenile delinquent',
#   'stoner',
#   'music store',
#   'hand on crotch',
#   'premarital sex',
#   'raised middle finger',
#   'employer employee relationship',
#   'cupcake',
#   'twenty something',
#   'money bag',
#   'sidewalk',
#   'storem'],
#  ['italy',
#   'poker',
#   'casino',
#   'terrorist',
#   'banker',
#   'money',
#   'free running',
#   'torture',
#   'british secret service',
#   'montenegro'],
#  ['circus', 'trapeze artist'],
#  ['angel',
#   'riddle',
#   'detective',
#   'bible',
#   'police',
#   'supernatural',
#   'psychopath',
#   'murder',
#   'curse',
#   'religion',
#   'execution',
#   'series of murders',
#   'devil',
#   'family',
#   'evil',
#   'neo-noir'],
#  ['new york',
#   'boat',
#   'mask',
#   'psychopath',
#   'high school',
#   'sewerage',
#   'times square',
#   'serial killer',
#   'teenager',
#   'jason vorhees'],
#  ['montana',
#   'small town',
#   'dementia',
#   'aging',
#   'road trip',
#   'f word',
#   'pickup truck',
#   'lincoln nebraska',
#   'nebraska',
#   'sweepstakes',
#   'confronting the past'],
#  ['martial arts',
#   'biography',
#   'sport',
#   'sensei',
#   'mixed martial arts',
#   'hong kong'],
#  ['vomit', 'food poisoning'],
#  ['china', 'violence', 'modern china', 'return of son', 'suicide jump'],
#  ['black people',
#   'based on novel',
#   'brother sister relationship',
#   'becoming an adult',
#   'isolation',
#   'arbitrary law',
#   'socially deprived family',
#   'tree house',
#   'wrong accusal',
#   'farm worker',
#   'intolerance',
#   'exclusion',
#   'court case',
#   'defence',
#   'right and justice',
#   'court',
#   'child'],
#  ['car race',
#   'car journey',
#   'car mechanic',
#   'auto',
#   'car garage',
#   'auto-tuning',
#   'drifting',
#   'car',
#   'automobile racing'],
#  ['smoking',
#   'medicine',
#   'psychology',
#   'hallucination',
#   'human experimentation',
#   'time travel',
#   'war',
#   'love',
#   'psychologist',
#   'soldier',
#   'psychiatrist',
#   'medical experiment',
#   'dead',
#   'wrongful arrest',
#   'iraq veteran',
#   'near-death experience',
#   'truck stop',
#   'murder of a police officer'],
#  ['brazilian',
#   'revolution',
#   'communist',
#   'asthma',
#   'peru',
#   'chile',
#   'cuban revolution',
#   'che guevara',
#   'argentina',
#   'motorcycle',
#   'guajira peninsula',
#   'leper colony',
#   'biochemist'],
#  ['prison',
#   'rock and roll',
#   'jealousy',
#   'stage',
#   'arrest',
#   'singer',
#   'juvenile delinquent'],
#  ['commercial', 'supermarket', 'disaster', 'consumerism', 'theme song'],
#  ['female nudity',
#   'prison',
#   'rape',
#   'nudity',
#   'escape from prison',
#   'murder',
#   'car crash',
#   'independent film',
#   'escape',
#   'hitchhiker',
#   'car chase',
#   'psychotic',
#   'roadblock',
#   'car theft',
#   'cross country trip'],
#  ['sunrise', 'vampire', 'suspicion', 'remake', 'suburbia'],
#  [],
#  ['golf', 'underwear', 'sport', 'golf course', 'gopher'],
#  ['transvestism',
#   'robbery',
#   'martial arts',
#   'jazz',
#   'finger',
#   'vice',
#   'police',
#   'revenge',
#   'murder',
#   'scam',
#   'prostitution',
#   'gangster',
#   'white slavery'],
#  ['clown',
#   'carnival',
#   'sadism',
#   'survival',
#   'chainsaw',
#   'maniac',
#   'game',
#   'betting',
#   'killer clown',
#   'satanic',
#   'axe',
#   'midget',
#   'nazi'],
#  ['corruption',
#   'police brutality',
#   'riot',
#   'ghetto',
#   'street war',
#   'hold-up robbery',
#   'moral conflict',
#   'special unit',
#   'police everyday life',
#   'cops',
#   'independent film',
#   'los angeles',
#   'family'],
#  ['salesclerk'],
#  ['nurse',
#   'secret',
#   'dream',
#   'fight',
#   'kidnapping',
#   'new orleans',
#   'key',
#   'plantation',
#   'voodoo',
#   'party',
#   'lawyer',
#   'blood',
#   'violence',
#   'mirror',
#   'attic',
#   'occult'],
#  ['jupiter',
#   'super computer',
#   'space travel',
#   'space mission',
#   'ghost ship',
#   'outer space',
#   'astronaut',
#   'monolith'],
#  ['supernatural',
#   'remake',
#   'suspense',
#   'beer bottle',
#   'real time',
#   'candelabra',
#   'reference to facebook',
#   'padlock',
#   'woman director'],
#  ['gorilla', 'kongo', 'diamond mine', 'diamond'],
#  ['wife husband relationship',
#   'custody battle',
#   'marriage',
#   'falling from height',
#   'divorce',
#   'family',
#   'couple',
#   'selfishness',
#   'manhattan, new york city',
#   'child custody',
#   'blood on face',
#   'abandonment'],
#  ['new york',
#   'martial arts',
#   'supermarket',
#   'gang war',
#   'disabled child',
#   'gang',
#   'wedding',
#   'diamond',
#   'bronx',
#   'duringcreditsstinger'],
#  ['holocaust',
#   'world war ii',
#   'nazis',
#   'biography',
#   'jewish',
#   'zookeeper',
#   'poland'],
#  ['southern usa',
#   'wife husband relationship',
#   'amnesia',
#   'war veteran',
#   'return',
#   'village life',
#   'death penalty',
#   'gallows',
#   'violent husband',
#   'suspicion of murder',
#   'court case',
#   'death sentence',
#   'sentence',
#   'false identity',
#   'one-sided love',
#   'wife',
#   'peasant',
#   'loss of husband',
#   'village',
#   'agriculture',
#   'war',
#   'violence'],
#  ['japan',
#   'coma',
#   'martial arts',
#   'kung fu',
#   'underworld',
#   'yakuza',
#   'sword',
#   'bride',
#   'revenge',
#   'gore',
#   'female yakuza',
#   'blood',
#   'wedding',
#   'samurai sword',
#   'part animation'],
#  ['aids', 'gay relationship', 'family'],
#  ['italian', 'new love', 'provence', 'horse', 'exile'],
#  ['prison', 'prisoner', 'hunger', 'hunger strike', 'northern ireland'],
#  ['schizophrenia',
#   'identity',
#   'amnesia',
#   'loss of sense of reality',
#   'suppressed past',
#   'trauma',
#   'key',
#   'bisexuality',
#   'hallucination',
#   'surreal',
#   'job interview',
#   'casting',
#   'suspense',
#   'independent film',
#   'lesbian',
#   'los angeles'],
#  [],
#  [],
#  [],
#  ['helicopter',
#   'treasure',
#   'pyramid',
#   'museum',
#   'parrot',
#   'hot air balloon',
#   'peru',
#   'jungle',
#   'train',
#   'dog',
#   'explorer',
#   'dessert',
#   'construction worker'],
#  ['police brutality',
#   'ghetto',
#   'delinquency',
#   'police',
#   'east los angeles',
#   'gang',
#   'gang member',
#   'mexican american',
#   'barrio',
#   'colleague'],
#  ['evidence',
#   'overdose',
#   'heroin',
#   'cop',
#   'alien',
#   'shootout',
#   'undercover cop',
#   'drug'],
#  ['individual',
#   'schizophrenia',
#   'massachusetts',
#   "love of one's life",
#   'intelligence',
#   'mathematician',
#   'market economy',
#   'economic theory',
#   'princeton university',
#   'nobel prize',
#   'mathematical theorem',
#   'm.i.t.',
#   'mathematics',
#   'delusion'],
#  [],
#  ['based on true story'],
#  [],
#  ['victorian england',
#   'trial',
#   'slave',
#   'black woman',
#   'high society',
#   'caribbean',
#   'woman director',
#   'social issues'],
#  [],
#  ['individual',
#   'scotland',
#   'in love with enemy',
#   'legend',
#   'independence',
#   'idealism',
#   'revolt',
#   'tyranny'],
#  [],
#  ['hawaii', 'epic'],
#  ['prison'],
#  ['plan'],
#  ['suicide',
#   'ocean',
#   'sea',
#   'hunger',
#   'shipwreck',
#   'ship',
#   'whale',
#   'based on true story',
#   'stranded',
#   'survival',
#   'whaling',
#   'death',
#   'new england',
#   'lost at sea',
#   'based on true events',
#   'whaling ship',
#   'starvation',
#   '19th century',
#   'cannibalism',
#   'reference to moby dick',
#   'whale oil',
#   'nantucket'],
#  ['world war ii', 'boot camp', 'biloxi mississippi'],
#  ['elves',
#   'dwarves',
#   'orcs',
#   'middle-earth (tolkien)',
#   'hobbit',
#   'based on novel',
#   'mountain',
#   'fireworks',
#   'castle',
#   'volcano',
#   'password',
#   'death of a friend',
#   'uncle',
#   'mirror',
#   'wizard',
#   'sword and sorcery'],
#  ['usa president',
#   'double life',
#   'policy and organisations',
#   'undercover',
#   'intelligence',
#   'partner',
#   'duringcreditsstinger'],
#  ['china', 'drought'],
#  ['midlife crisis',
#   'road trip',
#   'politically incorrect',
#   'motorcycle gang',
#   'biker film',
#   'awkwardness',
#   'travel writer',
#   'middle age',
#   'middle aged man'],
#  ['obsession',
#   'dream',
#   'kidnapping',
#   'nudity',
#   'suspense',
#   'unrequited love',
#   'doctor',
#   'car accident',
#   'obsessive love',
#   'woman director',
#   'captivity'],
#  ['journalist', 'martial arts', 'cook', 'drug dealer'],
#  ['duringcreditsstinger'],
#  ['gorilla',
#   'baby',
#   'adoption',
#   'feral child',
#   'nest',
#   'animation',
#   'jungle',
#   'camp',
#   'orphan'],
#  ['helicopter', 'subway', 'german', 'sadomasochism'],
#  ['martial arts', 'hip-hop', 'oakland', 'asian', 'asian man', 'asian lead'],
#  ['date',
#   'sex',
#   'jealousy',
#   'fight',
#   'architect',
#   'gallery',
#   'interview',
#   'sister',
#   'party',
#   'love',
#   'friends',
#   'fate',
#   'los angeles',
#   'summer',
#   'ikea',
#   'year',
#   'heartache'],
#  ['based on true story', 'duringcreditsstinger'],
#  ['corvette stingray'],
#  ['fortune teller', 'dream', 'pond', 'extrasensory perception'],
#  ['prophecy',
#   'fire',
#   'sea',
#   'beach',
#   'cemetery',
#   'gold',
#   'small town',
#   'beheading',
#   'sword',
#   'penalty',
#   'narration',
#   'fog',
#   'leprosy',
#   'ship',
#   'ghost ship',
#   'lighthouse',
#   'weather service',
#   'unatoned crime',
#   'mother daughter relationship',
#   'killer',
#   'denunciation'],
#  ['washington d.c.', 'bus', 'march'],
#  ['disc jockey',
#   'radio station',
#   'hostage',
#   'hostage situation',
#   'radio broadcast',
#   'laid off'],
#  [],
#  ['expedition', 'glacier', 'rescue', 'antarctic'],
#  ['highway',
#   'slacker',
#   'hitchhiker',
#   'wallet',
#   'sunglasses',
#   'rest stop',
#   'vicodin',
#   'waffle'],
#  ['father son relationship',
#   'new love',
#   'fianc√©',
#   'training',
#   'rent',
#   'jogging',
#   'marathon',
#   'wedding',
#   'pregnancy'],
#  ['male nudity',
#   'female nudity',
#   'nudity',
#   'swamp',
#   'canoe',
#   'australia',
#   'tribe',
#   'hunting',
#   'death',
#   'storytelling',
#   'native peoples',
#   'hunt',
#   'australian aborigine'],
#  ['rodeo', 'texas', 'horse', 'girl', 'cowgirl', 'missing father'],
#  ['mascot',
#   'beer keg',
#   'political correctness',
#   'ultimate frisbee',
#   'funky music',
#   'fund raiser',
#   'stage diving'],
#  ['loss of lover',
#   'mountain',
#   'winter',
#   'wolf',
#   'conversation',
#   'death of a friend',
#   'aggression by animal',
#   'cold',
#   'horror',
#   'fall from height',
#   'suspense',
#   'snow',
#   'best friend',
#   'animal attack',
#   'ski lift',
#   'frostbite'],
#  ['mutant', 'marvel comic', 'superhero', 'based on comic', 'superhuman'],
#  ['musical', 'singing', 'actress'],
#  ['painter', 'biography', 'painting', 'maid'],
#  ['gymnastics',
#   'small town',
#   'gymnast',
#   'olympic athlete',
#   'olympic hopeful',
#   'local celebrity'],
#  ['sex',
#   'slice of life',
#   'hollywood',
#   'drug',
#   'hedonism',
#   'ensemble cast',
#   'child murder',
#   '1980s',
#   'dysfunctional',
#   'intersecting lives'],
#  ['photographer',
#   'heroin',
#   'police',
#   'murder',
#   'neighbor',
#   'search',
#   'doll',
#   'apartment',
#   'blindness',
#   'blind woman'],
#  ['paris',
#   'sex',
#   'jealousy',
#   'secret',
#   'restaurant',
#   'love',
#   'relationship',
#   'las vegas',
#   'chef'],
#  ['handcuffs',
#   'police operation',
#   'investigation',
#   'police everyday life',
#   'miami beach'],
#  ['father son relationship',
#   'child labour',
#   'brothel',
#   'winter',
#   'allegory',
#   'bridge',
#   'post-apocalyptic',
#   'dystopia',
#   'hijacking of train',
#   'based on comic',
#   'dam',
#   'rifle',
#   'pregnant',
#   'train',
#   'violence',
#   'based on graphic novel',
#   'guilt',
#   'revolt',
#   'duplicity',
#   'tunnel',
#   'social class',
#   'population control',
#   'perpetual winter',
#   'city ruin'],
#  ['puppy', "st. bernard's dog", 'family'],
#  ['suspense', 'shark', 'diver', 'diver instructor'],
#  ['mountain',
#   'kidnapping',
#   'wind',
#   'wolf',
#   'narration',
#   'snow',
#   'twins',
#   'death',
#   'missing son',
#   'indigenous peoples'],
#  ['religious cult', '1980s'],
#  ['nightmare', 'house'],
#  ['male nudity',
#   'female nudity',
#   'sex',
#   'adultery',
#   'infidelity',
#   'obsession',
#   'blackmail',
#   'villain',
#   'hidden camera',
#   'blind date',
#   'death of a friend',
#   'insanity',
#   'high school',
#   'stalker',
#   'sociopath',
#   'unrequited love',
#   'neighbor',
#   'unfaithfulness',
#   'los angeles',
#   'principal',
#   'car accident',
#   'violence',
#   'sex scene',
#   'extramarital affair',
#   'tied up',
#   'car explosion',
#   'high school teacher',
#   'fatal attraction',
#   'mother son relationship',
#   'older woman younger man relationship',
#   'critically bashed',
#   'loss of friend',
#   'woman in jeopardy',
#   'crying woman',
#   'damsel in distress',
#   'erotic thriller',
#   'muscular'],
#  ['rape', 'police', 'vigilante', 'revenge', 'murder', 'jail', 'gang', 'drug'],
#  ['animation'],
#  [],
#  ['cyborg',
#   'kung fu',
#   'ship',
#   'post-apocalyptic',
#   'terrorism',
#   'anarchy',
#   'fetus'],
#  ['ritual', 'pornographic video', 'car crash', 'dvd'],
#  ['gunslinger', 'revenge', 'prairie', 'shootout', 'pistol'],
#  ['independent film', 'book editor'],
#  ['holiday',
#   'sex',
#   'dream',
#   'nudity',
#   'friends',
#   'resort',
#   'dating',
#   'attitude'],
#  ['sister sister relationship',
#   'secret',
#   'romance',
#   'cottage',
#   'relationship',
#   'mumblecore',
#   'woman director'],
#  ['private school',
#   'lone wolf',
#   'theatre play',
#   'theatre group',
#   'theatre director',
#   'independent film'],
#  ['river', 'miracle', 'bible', 'louisiana', 'frog', 'grasshopper', 'faith'],
#  [],
#  ['technology',
#   'civilization',
#   'human vs nature',
#   'living together',
#   'rural setting',
#   'social commentary',
#   'nature',
#   'environment',
#   'lost civilization'],
#  ['epilepsy',
#   'possession',
#   'teenage girl',
#   'spirit',
#   'umbrella',
#   'cross',
#   'prosecutor',
#   'catholicism',
#   'negligent homicide',
#   'archdiocese',
#   'agnostic',
#   'malnutrition',
#   'burning',
#   'psychotic epileptic disorder'],
#  ['robbery', 'diamant', "c√¥te d'azur", 'inspector', 'panther'],
#  ['explosive',
#   'boomerang',
#   'pilot',
#   'chase',
#   'post-apocalyptic',
#   'dystopia',
#   'deal',
#   'survivor',
#   'feral child',
#   'australia',
#   'community',
#   'ex-cop',
#   'truck',
#   'sequel',
#   'independent film',
#   'oil',
#   'wasteland',
#   'gang rape',
#   'motorcycle gang',
#   'violence',
#   'dog',
#   'desolate',
#   'oil refinery',
#   'disfigurement mask',
#   'music box',
#   'oil tanker',
#   'wanderer',
#   'ozploitation'],
#  ['handcuffs',
#   'police chief',
#   'police operation',
#   'spying',
#   'investigation',
#   'police everyday life',
#   'police academy',
#   'commandant'],
#  ['con man', 'fraud', 'gambling debts', 'noir'],
#  ['private eye', 'lew harper'],
#  ['island',
#   'marooned',
#   'pacific island',
#   'teenager',
#   'deserted island',
#   'tropical island'],
#  ['drug dealer', 'best friend', 'wedding', 'australian outback'],
#  ['street gang',
#   'car race',
#   'undercover',
#   'auto-tuning',
#   'los angeles',
#   'car',
#   'automobile racing',
#   'aftercreditsstinger',
#   'duringcreditsstinger'],
#  ['black people', 'starships', 'future', 'star', 'supernova', 'blast'],
#  ['gay', 'woman director'],
#  ['prison',
#   'vietnam veteran',
#   'falsely accused',
#   'police brutality',
#   'sheriff',
#   'guerrilla',
#   'submachine gun',
#   'gun',
#   'destroy',
#   'self-defense',
#   'vietnam',
#   'vietnam war',
#   'prosecution',
#   'dying and death',
#   'police operation',
#   'attempt to escape',
#   'matter of life and death',
#   'survivor',
#   'tramp',
#   'national guard',
#   'weapon',
#   'firearm',
#   'police',
#   'escape',
#   'rural setting'],
#  ['corruption',
#   'florida',
#   'secret identity',
#   'liberation of prisoners',
#   'drug traffic',
#   'floatplane',
#   'transport of prisoners',
#   'tank car',
#   'florida keys',
#   'coast guard',
#   'airplane',
#   'british secret service'],
#  ['megacity', 'brother-in-law', 'police'],
#  ["girls' boarding school",
#   'sexual harassment',
#   'punishment',
#   'irish',
#   'ireland',
#   'catholic',
#   'convent school'],
#  ['jealousy', "mama's boy", 'falling in love'],
#  ['japan',
#   'suicide',
#   'samurai',
#   'immortality',
#   'remake',
#   'swordsman',
#   'suicide mission',
#   'stick fight',
#   'rooftop',
#   'samurai sword',
#   'seppuku',
#   'code of honor',
#   'samurai era'],
#  ['regret',
#   'workaholic',
#   'heart attack',
#   'architect',
#   'dying and death',
#   'time travel',
#   'remote control',
#   'children',
#   'liposuction',
#   'hospital',
#   'wedding',
#   'dog',
#   'second chance',
#   'alternate reality',
#   'fatherhood',
#   'obese'],
#  ['based on true story', 'murder', 'true crime'],
#  ['trailer park',
#   'canada',
#   'nova scotia',
#   'dark comedy',
#   'marijuana',
#   'mockumentary'],
#  ['magic', 'silent film'],
#  ['romantic comedy'],
#  [],
#  ['artificial intelligence',
#   'engineer',
#   'hell',
#   'pinhead',
#   'demon',
#   'puzzle box',
#   'cenobites',
#   'artificial'],
#  ['based on novel',
#   'adoption',
#   'pregnant',
#   'miscarriage',
#   'expectant father',
#   'pregnant wife',
#   'vomiting',
#   'expecting twins',
#   'open air cinema',
#   'giving birth'],
#  ['smoking',
#   'based on tv series',
#   'best friend',
#   'fashion',
#   'drunk',
#   'grandmother',
#   'public relations',
#   'woman director',
#   'celebrity cameo',
#   'london',
#   'p.a'],
#  ['japan',
#   'female nudity',
#   'martial arts',
#   'kung fu',
#   'nudity',
#   'sequel',
#   'sword fight',
#   'ninja',
#   'gang',
#   'violence',
#   'stabbing',
#   'sword duel',
#   'throwing star'],
#  ['dark comedy', 'independent film'],
#  ['iran', 'farmer', 'hearing impaired'],
#  ['telekinesis', 'psychokinesis', 'psychic', 'demon', 'mayan'],
#  ['usa president', 'agent'],
#  ['wrestling', 'sport'],
#  ['robbery',
#   'bar',
#   'winter',
#   'blackmail',
#   'hitman',
#   'bartender',
#   'crime boss',
#   'organized crime',
#   'mobster',
#   'pitbull',
#   'church',
#   'catholic',
#   'brooklyn new york city',
#   'ex-con',
#   'super bowl',
#   'abandoned puppy'],
#  ['hero',
#   'barn',
#   'spider',
#   'pig',
#   'egg',
#   'friendship',
#   'spring',
#   'uncle',
#   'friends',
#   'rescue',
#   'survival',
#   'talking animal',
#   'grass',
#   'family',
#   'desk',
#   'raincoat',
#   'talking pig'],
#  ['dancing',
#   'sex',
#   'dream',
#   'musical',
#   'police',
#   'bikini',
#   'swimming pool',
#   'beauty salon',
#   'romantic comedy',
#   'spaceship',
#   'romance',
#   'alien',
#   'furry',
#   'hospital',
#   'makeover',
#   'nosy neighbor',
#   'discotheque',
#   'valley girl'],
#  ['holiday', 'thanksgiving', 'freedom', 'duringcreditsstinger', '3d'],
#  ['father son relationship',
#   'lake',
#   'springfield',
#   'the simpsons',
#   'duff beer',
#   'garbage',
#   'pig',
#   'pollution',
#   'environmental protection agency',
#   'quarantine',
#   'alcoholism',
#   'love',
#   'alaska',
#   'dysfunctional family',
#   'dysfunctional marriage',
#   'ecology',
#   'saving lives',
#   'first love',
#   'duringcreditsstinger',
#   'donuts'],
#  [],
#  ['hostage',
#   'based on true story',
#   'murder',
#   'independent film',
#   'single mother',
#   'drug',
#   'drug addict',
#   'recovering drug addict',
#   'auto theft',
#   'based on true events'],
#  ['arkansas', 'suspense', 'independent film', 'los angeles', 'criminal'],
#  ['based on tv series',
#   'tokusatsu',
#   'superhero team',
#   'ethnic diversity',
#   'super sentai',
#   'power rangers',
#   'mighty morphin power rangers',
#   'mmpr'],
#  ['video game', 'pretended murder', 'hypnosis', 'virtual reality', 'trance'],
#  ['horse race', 'horse', 'racehorse'],
#  ['paris', 'meat', 'cowardliness', 'animal horror'],
#  ['fishing',
#   'atlantic ocean',
#   'bathing',
#   'shipwreck',
#   'police chief',
#   'ferry boat',
#   'dying and death',
#   'dolly zoom',
#   'shark',
#   'great white shark',
#   'animal horror'],
#  ['kidnapping',
#   'highway',
#   'police',
#   'road trip',
#   'based on true story',
#   'reporter',
#   'criminal',
#   'convict'],
#  ['fight',
#   'cop',
#   'love',
#   'thief',
#   'revenge',
#   'look-alike',
#   'goon',
#   'remake of telugu film'],
#  ['new jersey',
#   'restaurant',
#   'hitman',
#   'van',
#   'arrest',
#   'psychopath',
#   'based on true story',
#   'jail',
#   'serial murder',
#   'stabbing',
#   'crime family',
#   'bombing',
#   'ice cream man \xa0',
#   'drug deal',
#   'contract killer',
#   'crime syndicate',
#   'poisoning'],
#  [],
#  ['based on manga'],
#  ['date', 'ex-girlfriend', 'u.s. army', 'military spoof'],
#  ['fear of flying',
#   'tourist',
#   'barbecue',
#   'travel',
#   'summer vacation',
#   'mass tourism',
#   'charter',
#   'gran canaria',
#   'kanarie√∂arna'],
#  ['ocean',
#   'california',
#   'sea',
#   'beach',
#   'surfer',
#   'hawaii',
#   'wave',
#   'sun',
#   'surfboard',
#   'lifestyle',
#   'extremsport'],
#  ['war crimes',
#   'mass murder',
#   'war victim',
#   'sino japanese war',
#   'massacre',
#   'japanese army',
#   'duringcreditsstinger',
#   'imperial japan'],
#  ['new love', 'affection'],
#  ['stripper', 'older woman seduces younger guy', 'independent film'],
#  ['dancing',
#   'male nudity',
#   'female nudity',
#   'sexual obsession',
#   'san francisco',
#   'sadistic',
#   'detective',
#   'jealousy',
#   'gun',
#   'eroticism',
#   'menace',
#   'nudity',
#   'suspicion of murder',
#   'ex-lover',
#   'planned murder',
#   'cigarette',
#   'bisexuality',
#   'orgasm',
#   'bedroom',
#   'bed',
#   'underwear',
#   'dying and death',
#   'auto',
#   'dangerous',
#   'lover',
#   'striptease',
#   'sadism',
#   'police',
#   'psychopath',
#   'femme fatale',
#   'sociopath',
#   'bdsm',
#   'erotic thriller'],
#  ['stand-up comedy', 'observational comedy', 'comedy'],
#  ['australia', 'lawlessness', 'widerstand', 'gang', 'capture'],
#  ['bone',
#   'car explosion',
#   'premarital sex',
#   'satanic cult',
#   "driver's license",
#   'finger gun',
#   'backhand slap',
#   'car jump',
#   'man punching a woman',
#   'magic trick'],
#  ['adolescence',
#   'age difference',
#   'parent child relationship',
#   'self-discovery',
#   'coming of age',
#   'love affair',
#   'youth',
#   'family',
#   'woman director',
#   'teaching the ways of the world',
#   'love and romance',
#   'teenage life'],
#  ['underdog',
#   'robbery',
#   'bounty hunter',
#   'texas',
#   'mexican revolution',
#   'friendship',
#   'honor',
#   'gang',
#   'shootout',
#   'soldier',
#   'steam locomotive',
#   'righteous rage'],
#  ['france', 'revolution', 'biography', 'president', 'history'],
#  ['paris',
#   'london england',
#   'new york',
#   'jules verne',
#   'san francisco',
#   'istanbul',
#   'hot air balloon',
#   'journey round the world'],
#  ['independent film'],
#  [],
#  ['woman director'],
#  ['based on novel',
#   'river',
#   'snake',
#   'expedition',
#   'world war i',
#   'biography',
#   'amazon',
#   'tribe',
#   'jungle',
#   'explorer',
#   'journey',
#   '1920s',
#   'mysterious lands'],
#  ['parent child relationship', 'cuddle rabbit', 'children'],
#  ['female nudity',
#   'brothel',
#   'vampire',
#   'private investigator',
#   'born again christian',
#   'televangelist'],
#  ['politics',
#   'surrealism',
#   'business',
#   'hunt',
#   'high society',
#   'class relations',
#   'absurdism'],
#  ['corruption',
#   'fortune teller',
#   'money transfer',
#   'money laundering',
#   'pottery',
#   'afterlife',
#   'spiritism'],
#  ['music rehearsal',
#   'fraternity initiation',
#   'television broadcast',
#   'white male pretending to be black',
#   'sorority party',
#   'push ups'],
#  ['detective',
#   'surgeon',
#   'stripper',
#   'profanity',
#   'murder',
#   'brutality',
#   'buddy'],
#  [],
#  ['artificial intelligence',
#   'card game',
#   'hacker',
#   'virtual reality',
#   'computer',
#   'family holiday'],
#  ['baltimore',
#   'thanksgiving',
#   'family clan',
#   'family conflict',
#   'generations conflict',
#   'woman director'],
#  ['coffin', 'vampire', 'dracula', 'romantic comedy', 'spoof', 'disco'],
#  ['sex',
#   'jealousy',
#   'virgin',
#   'nudity',
#   'community',
#   'friendship',
#   'high school',
#   'road trip',
#   'friends',
#   'romance',
#   'redneck',
#   'loss of virginity',
#   'hitchhiker',
#   'teen movie',
#   'boyfriend',
#   'pickup',
#   'knoxville'],
#  ['dual identity',
#   'bank',
#   'mockery',
#   'green',
#   'balloon',
#   'jail cell',
#   'norse mythology'],
#  ['berlin',
#   'poison',
#   'dictator',
#   'clerk',
#   'ideology',
#   'world war ii',
#   'traitor',
#   'despair',
#   'destroy',
#   'testament',
#   'capitulation',
#   'soviet troops',
#   'race politics',
#   'national socialism',
#   'adolf hitler',
#   'ultimate victory',
#   'minister',
#   'national socialist party',
#   'dying and death',
#   'historical figure',
#   'german shepherd'],
#  ['female nudity',
#   'hacker',
#   'terrorism',
#   'violence',
#   'ex-con',
#   'wire',
#   'los angeles international airport (lax)',
#   'misdirection',
#   'aftercreditsstinger'],
#  ['egypt', 'hercule poirot', 'shipboard', 'murder mystery'],
#  [],
#  ['exotic island', 'treasure', 'map', 'ship', 'scalp', 'pirate'],
#  ['island', 'machete', 'beautiful woman', 'serial killer', 'murder hunt'],
#  ['dancer', 'ballet'],
#  ['staged death', 'lgbt'],
#  ['competition',
#   'satire',
#   'spelling bee',
#   'estranged father',
#   'unlikely friendship',
#   'anger issues'],
#  ['mountain',
#   'snow storm',
#   'hiking',
#   'climbing',
#   'snow',
#   'death',
#   'blizzard',
#   'mountain climbing',
#   'based on true events',
#   'mount everest',
#   '3d'],
#  ['civil war'],
#  ['artificial intelligence',
#   'man vs machine',
#   'cyborg',
#   'android',
#   'computer virus',
#   'dystopia',
#   'implantat',
#   'fugitive',
#   'female protagonist',
#   'cyberpunk',
#   'based on manga'],
#  [],
#  [],
#  ['father son relationship',
#   'workaholic',
#   'camping',
#   'colorado',
#   'rocky mountains',
#   'marriage',
#   'slapstick',
#   'car crash',
#   'family vacation',
#   'family holiday'],
#  ['teenager', 'the beatles song', 'young man', 'reading'],
#  ['android', 'wilderness', 'post-apocalyptic', 'dystopia', 'tracker', 'robot'],
#  ['uncle', 'grandparents', 'independent film'],
#  ['prison',
#   'prisoner',
#   'dream',
#   'drug dealer',
#   'nightclub',
#   'american dream',
#   'male friendship',
#   'melancholy',
#   'girlfriend',
#   'friendship',
#   'aftercreditsstinger'],
#  ['male nudity',
#   'parent child relationship',
#   'camping',
#   'cutting the cord',
#   'self-discovery',
#   'wilderness',
#   'biography',
#   'based on true story',
#   'pubic hair',
#   'alaska',
#   'journey'],
#  ['salesclerk', 'loser', 'aftercreditsstinger'],
#  ['england',
#   'secret intelligence service',
#   'child hero',
#   'wretch',
#   'teen spy',
#   'based on young adult novel'],
#  [],
#  ['based on novel', 'middle school'],
#  ['north carolina',
#   'prayer',
#   'family dinner',
#   'motorcycle',
#   'advertising',
#   'divorce',
#   'automobile racing',
#   'nascar',
#   'dog trainer',
#   'car movie',
#   'sport competition',
#   'psychosomatic illness',
#   'french stereotype',
#   'aftercreditsstinger',
#   'duringcreditsstinger'],
#  ['voodoo', 'cop', 'murder', 'family'],
#  [],
#  ['romantic comedy', 'online dating', 'woman director'],
#  [],
#  ['suspense'],
#  ['overleven', 'family guy'],
#  ['brother brother relationship',
#   'college',
#   'based on true story',
#   'hazing',
#   'student',
#   'fraternity'],
#  ['california',
#   'taxi',
#   'assassin',
#   'hostage',
#   'taxi driver',
#   'fbi',
#   'hitman',
#   'police',
#   'los angeles',
#   'murderer',
#   'crime',
#   'criminal',
#   'gun violence'],
#  ['mutation', 'bat', 'attack', 'closed mine', 'bat attack', 'boy eaten'],
#  ['cabin',
#   'plot twist',
#   'cabin in the woods',
#   'filmed killing',
#   'video wall',
#   'speaker phone',
#   'mounted animal head',
#   'young adult'],
#  ['female protagonist', 'relationship', 'divorce', 'brooklyn bridge'],
#  ['paris',
#   'mother',
#   'city portrait',
#   'new love',
#   'dance',
#   'tv station',
#   'dying and death',
#   'market',
#   'vegetable',
#   'student',
#   'university',
#   'death by accident'],
#  ['los angeles',
#   'bullet proof vest',
#   'u.s. marine',
#   'medal of valor',
#   'police sergeant',
#   'felon',
#   'golden gun'],
#  ['killer robot', 'space war', 'dangerous', 'state of emergency'],
#  ['child abuse',
#   'kidnapping',
#   'gore',
#   'stalking',
#   'teenage girl',
#   'blood',
#   'violence',
#   'mental illness',
#   'super powers',
#   'multiple personality',
#   'traumatic childhood',
#   'dissociative identity disorder'],
#  ['female nudity',
#   'sexuality',
#   'island',
#   'love',
#   'mistress',
#   'kinky',
#   'smuggler',
#   'bdsm'],
#  ['father son relationship',
#   'loss of father',
#   'biker',
#   'motor sport',
#   'gang',
#   'motorcycle'],
#  ['based on fairy tale'],
#  ['upper class',
#   'love at first sight',
#   'wedding vows',
#   'marriage proposal',
#   'yuppie',
#   "love of one's life",
#   'lone wolf',
#   'snob',
#   'witness',
#   'bride',
#   'bridegroom',
#   'bridesmaid',
#   'funeral',
#   'clumsy fellow',
#   'friendship',
#   'wedding',
#   'gay couple'],
#  ['robbery',
#   'mentally disabled',
#   'bank robber',
#   'car crash',
#   'suspense',
#   'extreme violence',
#   'bank robbery'],
#  ['world war ii',
#   'prisoners of war',
#   'biography',
#   'sport',
#   'war',
#   'athlete',
#   'woman director',
#   'olympic athlete'],
#  ['assassination',
#   'brazilian',
#   'ambassador',
#   'freedom',
#   'drama',
#   'plot',
#   'revolutionary'],
#  ['revolution',
#   'strong woman',
#   'dystopia',
#   'game of death',
#   '3d',
#   'based on young adult novel'],
#  ['strugatsky'],
#  ['pregnancy and birth',
#   'voice',
#   'dragonfly',
#   'car crash',
#   'jungle',
#   'hospital',
#   'doctor',
#   'humanitarian',
#   'spiritism'],
#  ['robbery',
#   'diamant',
#   'intelligence',
#   'bank robber',
#   'thief',
#   'bank robbery',
#   'financial transactions',
#   'hoodlum'],
#  [],
#  [],
#  ['nevada',
#   'small town',
#   'tractor',
#   'stranded',
#   'cult favorite',
#   'rural setting',
#   'tentacle',
#   'graboids',
#   'seismologist',
#   'binoculars',
#   'man eaten by monster',
#   'giant worm'],
#  ['romantic comedy'],
#  ['infidelity', 'lovers', 'working class', 'new york city'],
#  [],
#  ['vietnam veteran', 'orphanage', 'rescue mission', 'long abandoned'],
#  ['fire',
#   'irish-american',
#   'immigrant',
#   'gang war',
#   'pickpocket',
#   'ship',
#   'gang of thieves',
#   'butcher',
#   'pig',
#   'army',
#   'rescue',
#   'gang'],
#  ['creature',
#   "based on children's book",
#   "children's book",
#   'lying',
#   'overflowing with imagination',
#   "children's perspectives"],
#  ['based on novel',
#   'prohibition',
#   'florida',
#   'love',
#   'revenge',
#   'betrayal',
#   'organized crime',
#   '1920s',
#   '1930s'],
#  ['baseball', 'sport'],
#  ['single parent',
#   'brother sister relationship',
#   'mistake in person',
#   'bride',
#   'talk show',
#   'body exchange',
#   'motherly love',
#   'high school',
#   'mother daughter relationship',
#   'wedding',
#   'psychiatrist',
#   'body-swap',
#   'music band',
#   'teen comedy',
#   'child as an adult',
#   'adult as a child'],
#  ['toronto',
#   'lesbian',
#   'remake of french film',
#   'suspicious wife',
#   'female doctor',
#   'playing piano'],
#  ['homosexuality',
#   'transgender',
#   'family',
#   'lgbt',
#   'drag',
#   'romantic drama',
#   'social issues',
#   'self-liberation',
#   'fearless',
#   'sex change operation'],
#  ['comedy'],
#  [],
#  ['cgi', 'anthropomorphism'],
#  ['corruption',
#   'mother',
#   'nudity',
#   'minister',
#   'power',
#   'public',
#   'government',
#   'police',
#   'reunion',
#   'murder',
#   'conspiracy',
#   'los angeles',
#   'missing',
#   'mother love',
#   'criticism'],
#  ['rivalry',
#   'stop motion',
#   'pirate',
#   'aftercreditsstinger',
#   'duringcreditsstinger'],
#  ['dystopia', 'space station', 'class conflict'],
#  ['manga'],
#  ['corruption',
#   'detective',
#   'police brutality',
#   'amish',
#   'suspense',
#   'barn raising',
#   'lancaster, pa'],
#  ['kgb', 'thriller', 'reporter', 'newspaper man', 'member of parliament'],
#  ['attempted murder',
#   'fairy tale',
#   'black magic',
#   'cockroach',
#   'villainess',
#   'good vs evil',
#   'woman fights man',
#   'insecurity',
#   'mirror',
#   'snow kingdom',
#   'snow white',
#   'evil queen',
#   'enchantress',
#   'gala',
#   'financial problem',
#   'pendant',
#   'half naked man',
#   'returning money',
#   'evil plot',
#   'duringcreditsstinger'],
#  ['father son relationship',
#   'rape',
#   'based on novel',
#   'mountain',
#   'winter',
#   'grizzly bear',
#   'wilderness',
#   'frontier',
#   'revenge',
#   'murder',
#   'native american',
#   'survival',
#   'bear',
#   'snow',
#   'violence',
#   'animal death',
#   'bear attack',
#   'death of son',
#   'based on true events',
#   'fur trapper'],
#  ['new york', 'heroin', 'money', 'criminal'],
#  ['texas', 'murder', 'on the run'],
#  ['talking to animals', 'woman director'],
#  ['divorce', 'divorced woman', 'reunited friends'],
#  ['street gang', 'uncle', 'female assassin', 'witness to murder'],
#  ['suicide',
#   'alcohol',
#   'adultery',
#   'country music',
#   'bar',
#   'infidelity',
#   'texas',
#   'paparazzi',
#   'musician',
#   'musical',
#   'van',
#   'addiction',
#   'biker',
#   'love',
#   'singer',
#   'woman director'],
#  ['ocean',
#   'fish',
#   'zoo',
#   'penguin',
#   'tap dancing',
#   'love',
#   'crush',
#   'snow',
#   'anthropomorphism',
#   'singing',
#   'antarctica',
#   'family',
#   'duringcreditsstinger'],
#  ['love', 'escape', 'teenager', 'desert', 'temptation'],
#  ['assassination',
#   'martial arts',
#   'sword',
#   'blood splatter',
#   'impalement',
#   'beaten to death',
#   'hong kong',
#   'head bashed in',
#   'extreme violence',
#   'violent death',
#   'hook',
#   'bloody fight',
#   'throat slitting',
#   'violence'],
#  ['adultery',
#   'candy',
#   'mentor',
#   'high school',
#   'independent film',
#   'marijuana',
#   'drug',
#   'injury',
#   'franchise',
#   'woman director',
#   'accident'],
#  ['world war ii', 'u.s. air force', 'military base', 'nazi germany'],
#  [],
#  ['baseball', 'sport', 'duringcreditsstinger'],
#  ['paris',
#   'bank',
#   'secret',
#   'fbi',
#   'vault',
#   'magic',
#   'new orleans',
#   'investigation',
#   'heist',
#   'conspiracy',
#   'money',
#   'escape',
#   'new york city',
#   'las vegas',
#   'explosion'],
#  [],
#  ['restaurant',
#   'sport',
#   'coach',
#   'athlete',
#   'newcastle united',
#   'computer games'],
#  ['pennsylvania',
#   'miner',
#   'coal mining',
#   'coal mine',
#   'pennsylvania coal miner'],
#  ['vacation', 'family'],
#  ['washington d.c.',
#   'covered investigation',
#   'investigation',
#   'north carolina',
#   'missing person'],
#  ['gay', 'lesbian relationship', 'gay relationship', 'wedding'],
#  ['mission', 'commando', 'commando mission'],
#  ['london england',
#   'corruption',
#   'cia',
#   'terrorist',
#   'sniper',
#   'explosive',
#   'intelligence',
#   'russia',
#   'murder',
#   'conspiracy',
#   'surveillance',
#   'agent',
#   'jack ryan',
#   'u.s. marine',
#   'rehab',
#   'analyst'],
#  ['billionaire', 'alcoholic'],
#  ['despair',
#   'loss',
#   'grief',
#   'death',
#   'ensemble cast',
#   'grieving father',
#   'anguish'],
#  [],
#  ['saving the world',
#   'human vs nature',
#   'fungus spores   ',
#   'future',
#   'airplane',
#   'post-apocalyptic',
#   'war',
#   'toxic',
#   'based on manga',
#   'ecology',
#   'giant insect',
#   'duringcreditsstinger',
#   'anime'],
#  ['prostitute',
#   'red-light disctrict',
#   'human trafficking',
#   'calcutta',
#   'illegal prostitution',
#   'woman director'],
#  ['post traumatic stress  disorder',
#   'sea',
#   'based on true story',
#   'rescue',
#   'disaster',
#   'explosion',
#   'oil spill',
#   'trapped',
#   'oil rig\xa0',
#   'gulf of mexico',
#   'disaster movie',
#   'bp'],
#  ['spy',
#   'fight',
#   'secret organization',
#   'satellite',
#   'secret agent',
#   'plastic surgery',
#   'smuggling',
#   'murder',
#   'extortion',
#   'violence',
#   'millionaire',
#   'fingerprints',
#   'dirt bike',
#   'casino owner',
#   'old woman murdered',
#   'high dive',
#   'gender disguise',
#   'aftercreditsstinger',
#   'master villain'],
#  ['sex',
#   'nudity',
#   'strip club',
#   'police',
#   'high school',
#   'party',
#   'teenager',
#   'drug',
#   'voyeur'],
#  ['sex',
#   'fight',
#   'music',
#   'illegal drug',
#   'black american stereotype',
#   'cashier',
#   'disgruntled worker',
#   'low rider',
#   'caller id',
#   'duringcreditsstinger'],
#  ['broken neck',
#   'fbi agent',
#   'wall safe',
#   'trashed house',
#   'aerial shot',
#   'military dress uniform',
#   'vanity',
#   'flare',
#   'woman director'],
#  [],
#  ['tyrant', 'ironclad ship'],
#  ['loss of parents',
#   'wild boar',
#   'uncle',
#   'shaman',
#   'redemption',
#   'king',
#   'scar',
#   'hyena',
#   'meerkat'],
#  ['space marine', 'dystopia', 'alien planet', 'genetic engineering'],
#  ['rape',
#   '1970s',
#   'evidence',
#   'tree',
#   'afterlife',
#   'loss of daughter',
#   'serial killer',
#   'corpse',
#   'pedophile',
#   'teenage love',
#   'grieving',
#   'childhood sexual abuse',
#   'based on young adult novel'],
#  [],
#  ['police investigation', 'land theft', 'land mafia'],
#  [],
#  ['father son relationship',
#   'underwater',
#   'killer whale',
#   'surveillance camera',
#   'antibes',
#   'animal park',
#   'accident'],
#  ['spy',
#   'newspaper',
#   'research',
#   'interview',
#   'tobacco',
#   'insider',
#   'conspiracy theory',
#   'reporter',
#   'whistleblower',
#   'columbia broadcasting system (cbs)',
#   'tobacco industry'],
#  ['distrust',
#   'garage',
#   'identity crisis',
#   'time travel',
#   'time machine',
#   'mathematics',
#   'independent film',
#   'paradox',
#   'mechanical engineering'],
#  ['based on novel', 'faith', 'based on true events'],
#  ['rome',
#   'resistance',
#   'roman empire',
#   'fight',
#   'sinti and romanies ',
#   'roman',
#   'ancient rome',
#   'fistfight',
#   'asterix',
#   'julius caesar'],
#  ['woman director', 'blended family'],
#  ['terror',
#   'experiment',
#   'afterlife',
#   'paranormal',
#   'violence',
#   'death',
#   'evil',
#   'researcher',
#   'possesion'],
#  ['independent film'],
#  [],
#  ['helicopter',
#   'war crimes',
#   'sniper',
#   'bosnia and herzegovina',
#   'fighter pilot',
#   'bosnian war of 1992-1995',
#   'rescue',
#   'escape',
#   'tank',
#   'atrocity',
#   'gunfight',
#   'combat',
#   'military',
#   'mine field',
#   'action hero',
#   'aircraft carrier',
#   'reconnaissance',
#   'mass grave'],
#  ['suicide',
#   'new york',
#   'date',
#   'subway',
#   'nightclub',
#   'overdose',
#   'artist',
#   'surreal',
#   'night',
#   'punk',
#   'murder',
#   'coincidence',
#   'mobster',
#   'vortex',
#   'one night',
#   'soho',
#   'district',
#   'circumstance'],
#  ['hotel',
#   'small town',
#   'siege',
#   'independent film',
#   'corpse',
#   'tarantula',
#   'death',
#   'animal attack',
#   'spiders'],
#  ['jupiter',
#   'wife husband relationship',
#   'marshal',
#   'wife',
#   'dystopia',
#   'earth',
#   'space centre'],
#  ['brother brother relationship',
#   'baby',
#   'home',
#   'pregnancy and birth',
#   'sequel',
#   'kids and family',
#   'comedy',
#   'pregnancy',
#   'aftercreditsstinger'],
#  ['corruption',
#   'street gang',
#   'prohibition',
#   'gun',
#   'irish-american',
#   'gambling debts',
#   'irish mob',
#   'violence'],
#  ['animation', 'animal', '3d'],
#  ['jazz', 'biography', 'historical figure'],
#  ['rebel',
#   'journalist',
#   'journalism',
#   'loss of family',
#   'slavery',
#   'mercenary',
#   'diamond mine',
#   'sierra leone',
#   'bootlegger',
#   'fisherman',
#   'special unit',
#   'smuggling',
#   'genocide in rwanda',
#   'oppression'],
#  ['brother brother relationship',
#   'loss of brother',
#   'cambodia',
#   'chase',
#   'tiger',
#   'governor',
#   'royalty',
#   'travelling circus',
#   'archaeologist'],
#  ['sheriff', 'wyoming', 'hitman', 'bag of money', 'neo-noir'],
#  ['based on novel',
#   'st. petersburg russia',
#   'high society',
#   'imperial russia',
#   'tragic death',
#   '19th century'],
#  ['american football',
#   'trainer',
#   'training',
#   'american football coach',
#   'sport',
#   'american football stadium'],
#  ['holiday',
#   'france',
#   'film director',
#   'chaos',
#   'clumsy fellow',
#   'to drop brick',
#   'aftercreditsstinger'],
#  ['independent film', 'duringcreditsstinger'],
#  ['missionary', 'civilization', 'tribe'],
#  ['heist', 'betrayal'],
#  ['penalty',
#   'therapist',
#   'psychology',
#   'aggression',
#   'rage',
#   'anger',
#   'anger management'],
#  [],
#  ['astronaut', 'spacewalk'],
#  [],
#  ['holiday',
#   'christmas party',
#   'santa claus',
#   'toy',
#   'puppet',
#   'christmas',
#   'turboman',
#   'navidad'],
#  ['cross country race', 'all-star supporting cast'],
#  ['magic show', 'career', 'comeback', 'drop-out'],
#  ['stand-up comedy',
#   'manhattan, new york city',
#   'madison square garden',
#   'duringcreditsstinger'],
#  ['male nudity',
#   'based on novel',
#   'paranoia',
#   'nudity',
#   'halloween',
#   'hypnosis',
#   'cabin',
#   'ufo',
#   'alien',
#   'independent film',
#   'alien abduction',
#   'new york city',
#   'psychiatrist',
#   'christmas'],
#  ['secret love',
#   'mohawk',
#   'native american',
#   '18th century',
#   'french and indian war'],
#  ['housewife',
#   'protection',
#   'motherly love',
#   'evil mother',
#   'murder',
#   'independent film',
#   'perfection'],
#  ['sister sister relationship',
#   'make a match',
#   'single',
#   'children',
#   'teacher',
#   'dating',
#   'divorce',
#   'pet dog',
#   'computer dating',
#   'internet dating',
#   'wooden boats'],
#  [],
#  ['babysitter',
#   'based on short film',
#   'new york city',
#   'attempted suicide',
#   'uncle niece relationship'],
#  ['courier', 'gangster', 'crime lord'],
#  ['ocean',
#   'sea',
#   'deep sea',
#   'water monster',
#   'scuba diving',
#   'scuba',
#   'trapped underwater\xa0'],
#  ['secret',
#   'blackmail',
#   'fisherman',
#   'police',
#   'high school',
#   'cover-up',
#   'friends',
#   'revenge',
#   'murder',
#   'pageant',
#   'slasher',
#   'teenager',
#   'killer'],
#  ['sex',
#   'seduction',
#   'comic book',
#   'alternate dimension',
#   'adult animation',
#   'cartoonist',
#   'live action and animation'],
#  ['car breakdown', 'wilderness', 'kiss', 'gambling debts', 'car garage'],
#  ['jealousy',
#   'journey in the past',
#   'sigmund freud',
#   'time travel',
#   'heavy metal',
#   'socrates',
#   'billy the kid',
#   'school presentation',
#   'rhinoceros',
#   'phone booth',
#   'world peace',
#   'past',
#   'history',
#   'metal',
#   'best friend',
#   'napoleon bonaparte'],
#  ['single parent',
#   'jealousy',
#   'opression',
#   'seattle',
#   'car mechanic',
#   'step father',
#   'alcoholic'],
#  ['android',
#   'extraterrestrial technology',
#   'space marine',
#   'spaceman',
#   'cryogenics',
#   'vacuum',
#   'space colony',
#   'warrior woman',
#   'settler',
#   'space travel',
#   'colony',
#   'alien',
#   'xenomorph'],
#  ['horse race', 'american dream', 'racehorse', 'great depression'],
#  ['based on novel',
#   'small town',
#   'widower',
#   'single father',
#   'abusive husband'],
#  [],
#  ['kurdish'],
#  ['suicide',
#   'detective',
#   'based on novel',
#   'bondage',
#   'general',
#   'paranoia',
#   'nudity',
#   'u.s. army',
#   'investigation',
#   'politics',
#   'cover-up',
#   'murder',
#   'betrayal',
#   'conspiracy',
#   'gang rape',
#   'father daughter relationship',
#   'videotape',
#   'military law'],
#  ['oscar award', 'dying and death', 'funeral', 'musical', 'odd job'],
#  ['female nudity',
#   'miami',
#   'prostitute',
#   'rape',
#   'cocaine',
#   'nudity',
#   'strip club',
#   'murder',
#   'gore',
#   'jungle',
#   'decapitation',
#   'reporter',
#   'jim jones',
#   'violence',
#   'drug',
#   'illegal drugs'],
#  ['cheating',
#   'dysfunctional family',
#   'teen angst',
#   'underage drinking',
#   'domestic violence',
#   'makeover',
#   'drug overdose',
#   'teacher student relationship',
#   'street life',
#   'movie theater',
#   'razor blade',
#   'tattoo shop',
#   'peer pressure',
#   'shoe store',
#   'overachiever',
#   'reference to jack black',
#   'flunking out of school',
#   'promiscuous mother',
#   'glue sniffing',
#   'woman director'],
#  [],
#  ['paris',
#   'painter',
#   'detective',
#   'based on novel',
#   'screenwriter',
#   'forbidden love',
#   'time travel',
#   'midnight',
#   'nostalgia',
#   'past',
#   'sculpture',
#   'hemingway'],
#  ['monster', 'poltergeist', 'supernatural powers', 'family secrets'],
#  ['black people', 'blaxploitation', 'spoof', 'duringcreditsstinger'],
#  ['poison',
#   'blackmail',
#   'masked ball',
#   'historical figure',
#   'buried alive',
#   'serial killer',
#   'deadline',
#   'edgar allan poe',
#   'newspaper review',
#   'baltimore maryland',
#   'newspaper office',
#   'hard times',
#   'life imitates art',
#   'pendulum'],
#  ['independent film'],
#  ['limousine',
#   'multiple identities',
#   'wig',
#   'penis',
#   'talking car',
#   'sewer of paris',
#   'traveling through a sewer',
#   'multiple roles'],
#  ['competition',
#   'grandfather grandson relationship',
#   'vomit',
#   'summer camp',
#   'toilet',
#   'rivalry',
#   'colonel'],
#  ['friendship', 'romantic comedy', 'teenager', 'lovesick', 'bilbao'],
#  ['dream',
#   'nightmare',
#   'voodoo',
#   'water',
#   'australia',
#   'sign',
#   'court',
#   'lawyer',
#   'shaman',
#   'storm',
#   'manslaughter',
# ...
#   'luxury',
#   'oscar award',
#   'charisma',
#   'polygamy',
#   'uganda',
#   'dictatorship'],
#  ['bully'],
#  ['based on novel', 'ireland', '1920s', '1930s'],
#  ['japan',
#   'usa',
#   'factory worker',
#   'factory',
#   'culture clash',
#   'worker',
#   'automobile industry',
#   'business',
#   'unemployment',
#   'auto industry',
#   'car factory'],
#  ['sport', 'male female relationship', 'soccer'],
#  ['sport', 'high school', 'basketball', 'high school sports'],
#  ['beach',
#   'infidelity',
#   'boat',
#   'writing',
#   'biography',
#   'poet',
#   'love',
#   'snow',
#   'drinking',
#   'woman director'],
#  ['human evolution',
#   'parent child relationship',
#   'squirrel',
#   'ice',
#   'loss of child',
#   'mammoth',
#   'sloth',
#   'dying and death',
#   'stone age',
#   'prehistoric',
#   'saber-toothed tiger',
#   'cavemen',
#   'prehistoric creature',
#   'prehistoric adventure',
#   'prehistoric times',
#   'prehistoric man'],
#  ['robbery',
#   'death penalty',
#   'lethal injection',
#   'criminal past',
#   'symbol',
#   'chainsaw'],
#  ['nurse',
#   'sex',
#   'based on novel',
#   'bondage',
#   'obsession',
#   'nudity',
#   'sadism',
#   'sadomasochism',
#   'twin brother',
#   'murder',
#   'prostitution',
#   'drug',
#   'twins',
#   'receptionist',
#   'extramarital affair',
#   'medical profession',
#   'gynecologist',
#   'voyeurism',
#   'spectacle',
#   'body horror',
#   'identical twins'],
#  ['manager',
#   'alcohol',
#   'races',
#   'mountain',
#   'gondola',
#   'snowboarding',
#   'airplane',
#   'father',
#   'sport',
#   'prank',
#   'alaska',
#   'male female relationship',
#   'drug humor',
#   'hot tub',
#   'ski resort'],
#  ['remake', 'demon', 'necronomicon', 'duringcreditsstinger'],
#  ['woman director'],
#  ['education', 'terrorism', 'activist', 'nobel peace prize winner'],
#  ['independent film'],
#  ['rape',
#   'verlies',
#   'heresy',
#   'religion and supernatural',
#   'napoleon',
#   'biography',
#   'unwillingly pregnant',
#   'muse'],
#  ['prostitute', 'greece'],
#  ['male nudity',
#   'female nudity',
#   'brother sister relationship',
#   'river thames',
#   'wheelchair',
#   'forbidden love',
#   'marriage',
#   'pubic hair',
#   'based on play or musical',
#   'wealth',
#   'incest',
#   'brother sister incest',
#   'erotica'],
#  ['transporter',
#   'netherlands',
#   'world cup',
#   'socially deprived family',
#   "family's daily life",
#   'boxer',
#   'boxing match',
#   'comeback',
#   'training',
#   'heavy weight',
#   'folk hero',
#   'biography',
#   'daughter',
#   'defeat',
#   'sport'],
#  ['in love with enemy',
#   'castle',
#   'lovers',
#   'hostility',
#   'revenge',
#   'murder',
#   'knight',
#   'battle',
#   'middle ages'],
#  ['mutiny',
#   'cave',
#   'chase',
#   'invasion',
#   'surrealism',
#   'robot',
#   'air battle',
#   'pacifist',
#   'council'],
#  [],
#  [],
#  ['based on novel',
#   'burning of witches',
#   'puritan',
#   'pregnancy',
#   'period drama',
#   'extramarital affair'],
#  ['supernatural horror'],
#  ['california',
#   'bank',
#   'ransom',
#   'car breakdown',
#   'kidnapping',
#   'donut',
#   'highway',
#   'barn',
#   'vacation',
#   'stranded',
#   'deception',
#   'murder',
#   'suspense',
#   'redneck',
#   'diner',
#   'extortion',
#   'captive',
#   'car chase',
#   'desert',
#   'moving',
#   'trucker'],
#  ['kgb', 'tap dancing', 'escape', 'emigrant'],
#  ['house fire', 'extension ladder', 'last day on job'],
#  ['baseball', 'trainer', 'baseball bat', 'career', 'training', 'sport'],
#  ['alcohol', 'birthday', 'debauchery'],
#  ['senate',
#   'general',
#   'market',
#   'rivalry',
#   'tragedy',
#   'tears',
#   'scar',
#   'stabbing',
#   'truce',
#   'flag',
#   'vote'],
#  ['based on novel',
#   'fictional place',
#   'queen',
#   'fantasy',
#   'alice in wonderland',
#   'fantasy world',
#   '3d'],
#  ['monk',
#   'eastern europe',
#   'skeleton',
#   'biker',
#   'marvel comic',
#   'superhero',
#   'motorcycle',
#   'devil',
#   'dark hero',
#   'ghost rider'],
#  ['alcohol',
#   'isolation',
#   'wolf',
#   'wilderness',
#   'forest',
#   'stranded',
#   'alaska',
#   'survival',
#   'airplane crash',
#   'fear',
#   'howling',
#   'death',
#   'animal killing',
#   'freezing',
#   'animal attack',
#   'campfire',
#   'male camaraderie',
#   'gun in mouth',
#   'aftercreditsstinger',
#   'bar fight',
#   'eaten alive',
#   'eaten by animal'],
#  [],
#  ['inspector'],
#  [],
#  ['gay',
#   'san francisco',
#   'homophobia',
#   'mayor',
#   'biography',
#   'politics',
#   'politician',
#   'election campaign',
#   'homosexuality',
#   'morality',
#   'election',
#   'candlelight vigil',
#   'mayoral campaign'],
#  ['usa',
#   'parent child relationship',
#   'greece',
#   'culture clash',
#   'midlife crisis',
#   'restaurant',
#   'bad mother-in-law',
#   'mother-in-law',
#   'parents-in-law',
#   'son-in-law',
#   'father-in-law',
#   'patriarch',
#   'bad father-in-law',
#   'greek',
#   'wedding',
#   'family',
#   'xenophobia'],
#  ['horror', 'ouija', 'spirit', 'game'],
#  ['neo-nazi', 'colorado', 'suspense', 'los angeles'],
#  ['duck',
#   'physicist',
#   'extraterrestrial',
#   'anthropomorphism',
#   'alien invasion',
#   'alternative reality'],
#  ['horseback riding',
#   'training',
#   'biography',
#   'duringcreditsstinger',
#   'woman director'],
#  ['holiday', 'prison', 'thailand', 'drug', 'injustice'],
#  ['cemetery', 'diamant', 'suspense', 'psychiatrist', 'killer'],
#  ['submarine',
#   'drowning',
#   'based on novel',
#   'rescue',
#   'disaster',
#   'underwater',
#   'disaster film',
#   'collision'],
#  ['dancing', 'new love', 'dance', 'baltimore', 'art school', 'woman director'],
#  ['moon',
#   'monk',
#   'swordplay',
#   'bishop',
#   'cathedral',
#   'falcon',
#   'twilight',
#   'solar eclipse',
#   'thief'],
#  ['baseball bat', 'sport', 'theft', 'new york yankees'],
#  ['black money', 'corrupt politician', 'education system'],
#  ['kidnapping', 'spying', 'government'],
#  ['cambodia', 'genocide', 'clay', 'khmer rouge', 'claymation'],
#  ['saving the world',
#   'riddle',
#   'whip',
#   'treasure',
#   'mexico city',
#   'leather jacket',
#   'machinegun',
#   'alien phenomenons',
#   'maya civilization',
#   'peru',
#   'treasure hunt',
#   'nuclear explosion',
#   'refrigerator',
#   'archaeologist',
#   'indiana jones',
#   'archeology\xa0'],
#  ['prostitute', 'showdown', 'tank', 'dirty cop', 'military'],
#  ['based on novel',
#   'desperation',
#   'robber',
#   'hold-up robbery',
#   'remake',
#   'suburbia',
#   'loss of job',
#   'humiliation',
#   'unemployment',
#   'bankruptcy',
#   'travel agent',
#   'riches to rags',
#   'bearer bonds',
#   'comeuppance'],
#  ['new york',
#   'wife husband relationship',
#   'restaurant',
#   'platonic love',
#   'orgasm',
#   'friendship',
#   'male female relationship'],
#  ['dc comics',
#   'crime fighter',
#   'terrorist',
#   'secret identity',
#   'burglar',
#   'hostage drama',
#   'time bomb',
#   'gotham city',
#   'vigilante',
#   'cover-up',
#   'superhero',
#   'villainess',
#   'tragic hero',
#   'terrorism',
#   'destruction',
#   'catwoman',
#   'cat burglar',
#   'imax',
#   'flood',
#   'criminal underworld',
#   'batman'],
#  ['skab under tv', 'bagved', '√òverste hylde'],
#  ['document',
#   'biography',
#   'tv reporter',
#   'presidential elections',
#   'political scandal'],
#  ['parasite', 'found footage'],
#  [],
#  ['nature', 'solitude', 'human nature'],
#  ['china', 'martial arts', 'tai chi', 'extortion', 'illegal matches'],
#  ['corruption',
#   'assassination',
#   'washington d.c.',
#   'rape',
#   'white house',
#   'usa president',
#   'daughter',
#   'government',
#   'suspense',
#   'secret service',
#   'secret service agent'],
#  ['germany',
#   'assassination',
#   'world war ii',
#   'nazis',
#   'prague',
#   'biography',
#   'female protagonist',
#   'third reich',
#   'operation anthropoid'],
#  ['samurai', 'japanese culture', 'based on manga', 'meiji period'],
#  ['ecstasy',
#   'drug dealing',
#   'drug',
#   'reference to family circus',
#   'high',
#   'bisexual man',
#   'multiple storylines'],
#  [],
#  ['living together',
#   'love',
#   'open relationship',
#   'sexual relationship',
#   'sentiments'],
#  ['surfing'],
#  ['cemetery',
#   'infidelity',
#   'shower',
#   'nudity',
#   'exorcism',
#   'night',
#   'high school',
#   'shooting',
#   'possession',
#   'revenge',
#   'murder',
#   'locker room',
#   'priest',
#   'prom',
#   'blood',
#   'unfaithfulness',
#   'camp',
#   'slasher',
#   'teenager',
#   'splatter',
#   'female homosexuality',
#   'high school friends',
#   'sexual repression',
#   'locker',
#   'incest',
#   'ghost',
#   'school principal',
#   'prom queen',
#   'flashback',
#   'supernatural power',
#   'canuxploitation'],
#  ['sheriff',
#   'barn',
#   'black',
#   'sequel',
#   'boogeyman',
#   'masked killer',
#   'slasher',
#   'youth',
#   'psychiatrist',
#   'killer',
#   'kitten',
#   'scythe',
#   'heroine',
#   'pitchfork',
#   'psychotronic',
#   'michael myers'],
#  ['father son relationship',
#   'pop singer',
#   'musical',
#   'celebrity',
#   'road trip',
#   'dead mother',
#   'first love',
#   'goofy'],
#  ['brother brother relationship'],
#  ['kidnapping', 'remake', 'dark comedy', 'relationship', 'crime', 'seville'],
#  ['pharmacist', 'dark comedy', 'trophy wife'],
#  ['pornography',
#   'porn actor',
#   'loss of daughter',
#   'child pornography',
#   'private investigator',
#   'subculture',
#   'private detective'],
#  ['based on fairy tale', 'giant'],
#  ['viking'],
#  ['treasure',
#   'map',
#   'magic',
#   'time travel',
#   'titanic',
#   'cage',
#   'steampunk',
#   'minotaur',
#   'independent film',
#   'good vs evil',
#   'tank',
#   'burglary'],
#  ['spy', 'cia', 'killer robot', 'delinquent', 'teen spy'],
#  [],
#  ['helicopter',
#   'martial arts',
#   'crime fighter',
#   'social control',
#   'museum',
#   'future',
#   'cryogenics',
#   'utopia',
#   'dystopia',
#   'fistfight',
#   'police',
#   'psychopath',
#   'betrayal',
#   'shootout',
#   'cyberpunk',
#   'explosion',
#   'violence',
#   'foot chase',
#   'car chase',
#   'warden',
#   'prison escape',
#   'subterranean',
#   'censorship',
#   'culture shock',
#   'knitting'],
#  ['robbery',
#   'sheriff',
#   'arizona',
#   'laser',
#   'outlaw',
#   'ufo',
#   'spaceship',
#   'alien',
#   'native american',
#   'escape',
#   'gunfight'],
#  ['italy', 'gun', 'roof', 'party', 'sequel', 'handshake'],
#  ['boat', 'chase', 'girlfriend', 'smuggling', 'rescue'],
#  ['innocence', 'revenge', 'family relationships', 'remake of malayalam film'],
#  ['biography'],
#  [],
#  ['spy', 'world war i'],
#  ['black people', 'spelling', 'spelling bee'],
#  ['fairy tale',
#   'villain',
#   'sleeping beauty',
#   'dark fantasy',
#   'based on fairy tale',
#   'adaptation',
#   'retelling',
#   'literary adaptation',
#   '3d'],
#  ['london england',
#   'england',
#   'cheating husband',
#   'pregnancy',
#   'construction site',
#   'one night',
#   'road movie',
#   'driving',
#   'husband wife relationship',
#   'project manager',
#   'driving at night',
#   'car phone'],
#  ['sequel', 'pok√©mon', 'celebi'],
#  ['helicopter',
#   'beach',
#   'loss of father',
#   'giant wave',
#   'tsunami',
#   'family relationships',
#   'korea',
#   'disaster',
#   'cigarette smoking',
#   'tears',
#   'single father',
#   'tearjerker',
#   'stuck in elevator',
#   'tidal wave',
#   'disaster film'],
#  ['talk show'],
#  ['paris', 'hotel', 'false identity', 'undercover agent', 'romance'],
#  [],
#  ['usa',
#   'vietnam veteran',
#   'submachine gun',
#   'prisoner',
#   'prisoners of war',
#   'liberation of prisoners',
#   'liberation',
#   'vietnam',
#   'vietnam war',
#   'chase',
#   'machinegun',
#   'u.s. army',
#   'forest',
#   'photography',
#   'government',
#   'war',
#   'revenge',
#   'soldier',
#   'agent',
#   'denunciation'],
#  ['mafia', 'gangster', 'horse racing'],
#  ['biography', 'christopher columbus'],
#  ['dolphin', 'florida', 'florida keys', 'summer'],
#  [],
#  ['rome', 'expatriate', 'episodic'],
#  ['italy', 'fish', 'rock star', 'vacation', 'rock concert'],
#  ['sport', 'duringcreditsstinger'],
#  ['brother brother relationship',
#   'father son relationship',
#   'manhattan, new york city',
#   'woman director',
#   'confinement'],
#  ['italian',
#   'police',
#   'serial killer',
#   'giallo',
#   'slasher',
#   'card playing',
#   'video poker'],
#  ['soulmates',
#   'midlife crisis',
#   'marriage crisis',
#   'womanizer',
#   'law school',
#   'crazy',
#   'relationship'],
#  ['extraterrestrial technology',
#   'alien life-form',
#   'alien phenomenons',
#   'spaceship'],
#  ['school'],
#  ['witch',
#   'magic',
#   'broom',
#   'school of witchcraft',
#   'wizardry',
#   'apparition',
#   'teenage crush',
#   'werewolf'],
#  ['miami',
#   'detective',
#   'handcuffs',
#   'airport',
#   'mexican standoff',
#   'strip club',
#   'witness protection',
#   'car crash',
#   'internal affairs',
#   'gunfight',
#   'explosion',
#   'brutality',
#   'foot chase',
#   'car chase',
#   'drug lord',
#   'hangar',
#   'loose cannon',
#   'bust',
#   'reference to skittles',
#   'black cop',
#   'badge',
#   'action hero',
#   'corrupt cop'],
#  [],
#  ['bomb',
#   'muslim',
#   'resistance',
#   'revolution',
#   'algerian',
#   'independence',
#   'insurrection',
#   'government',
#   'torture',
#   'united nations',
#   'military',
#   'casbah'],
#  ['gambling', 'chaos', 'roulette', 'family holiday'],
#  ['sheep', 'rural setting', 'housekeeper'],
#  ['individual',
#   'becoming an adult',
#   'dream',
#   'return',
#   "love of one's life",
#   'overweight',
#   'province',
#   'bathing',
#   'olympic games',
#   'empowerment',
#   'boredom',
#   'daughter',
#   'friendship'],
#  ['tree', 'natural disaster', 'crisis', 'park', 'strange behavior'],
#  ['tattoo',
#   'martial arts',
#   'sniper',
#   'island',
#   'mercenary',
#   'bridge',
#   'rescue',
#   'escape',
#   'church',
#   'drug',
#   'blade',
#   'ensemble cast',
#   'duringcreditsstinger'],
#  [],
#  ['sister sister relationship',
#   'exorcism',
#   'rhode island',
#   'based on true story',
#   'farmhouse',
#   'paranormal investigation',
#   'ghost',
#   'supernatural power',
#   'paranormal investigator',
#   'annabelle'],
#  ['usa',
#   'journalist',
#   'newspaper',
#   'burglar',
#   'fbi',
#   'wiretap',
#   'watergate scandal',
#   'plan',
#   'shadowing',
#   'politics',
#   'newspaper man'],
#  ['coma',
#   'musician',
#   'teenage girl',
#   'car accident',
#   'teenager',
#   'out of body experience',
#   'teen drama',
#   'based on young adult novel'],
#  ['video game',
#   'hacker',
#   'virtual reality',
#   'dystopia',
#   'computer',
#   'science fiction'],
#  ['wolf',
#   'arranged marriage',
#   'forbidden love',
#   'road trip',
#   'park',
#   'park ranger',
#   'howling',
#   'social status'],
#  ['competition', 'world war i', 'great depression', 'caddy', 'savannah'],
#  [],
#  ['schizophrenia',
#   'france',
#   'rape',
#   'siege',
#   'biography',
#   'orl√©ans',
#   'charles vii.',
#   'false history',
#   'joan of arc',
#   'religious delusions'],
#  ['cold war',
#   'shipwreck',
#   'arcade',
#   'man hunt',
#   'shopping montage',
#   'go-kart'],
#  ['based on novel',
#   'trauma',
#   'castle',
#   'haunted house',
#   'insomnia',
#   'bone',
#   'poster',
#   'painting',
#   'remake',
#   'haunting',
#   'child labor',
#   'audio recording',
#   'spiral staircase',
#   'evil',
#   'loner',
#   'researcher',
#   'insomniac',
#   'paranormal activity',
#   'logbook',
#   '\xa0strange noise',
#   'spook',
#   'cherub'],
#  ['gay',
#   'roommate',
#   'male friendship',
#   'in vitro fertilisation',
#   'romantic comedy',
#   'lesbian relationship',
#   'gay relationship',
#   'gay interest'],
#  ['coma', 'government', 'tunnel', 'steal', 'accident'],
#  ['life and death',
#   'afterlife',
#   'swing',
#   'memory',
#   'medical student',
#   'confetti'],
#  ['professional thief', 'jewel robbery'],
#  [],
#  ['father son relationship', 'heart attack'],
#  ['wife husband relationship',
#   'film director',
#   'biography',
#   'movie set',
#   'movie actress',
#   'movie actor'],
#  ['suicide attempt',
#   'blindness and impaired vision',
#   'thanksgiving',
#   'boarding school',
#   'prank',
#   'colonel',
#   'student',
#   'new york city',
#   'tears',
#   'change of heart',
#   'ex military'],
#  [],
#  ['wound',
#   'mountaineer',
#   'peru',
#   'sport',
#   'glacier',
#   'climbing',
#   'rescue',
#   'snow',
#   'cordillera huayhuash'],
#  ['death penalty',
#   'ethiopia',
#   'human rights',
#   'attempted kidnapping',
#   'child kidnapping'],
#  ['venice',
#   'dance',
#   'musical',
#   'tap dancing',
#   'stage show',
#   'fashion designer',
#   'mistaken identity',
#   'fashion',
#   'valet',
#   'rapier'],
#  ['places and planets',
#   'widow',
#   'lovers',
#   'alien',
#   'police car',
#   'cherry pie'],
#  ['dual identity', 'identity', 'undercover agent', 'role reversal'],
#  ['man vs machine',
#   'mutant',
#   'future',
#   'post-apocalyptic',
#   'dystopia',
#   'distant future'],
#  ['monster', 'godzilla', 'giant monster', 'destruction', 'kaiju', 'toyko'],
#  ['shotgun',
#   'based on short film',
#   'sadist',
#   'pistol',
#   'chained',
#   'bludgeoning',
#   'game of death'],
#  ['competition', 'success', 'kindergarten', 'children', 'unemployment'],
#  ['lovesickness',
#   'film business',
#   'film making',
#   'cinema',
#   'nice',
#   'film maker',
#   'insurance salesman',
#   'extramarital affair'],
#  ...]

# %%
Counter(i for j in kwds for i in j).most_common(10)
# Out:
# [('woman director', 175),
#  ('independent film', 155),
#  ('duringcreditsstinger', 134),
#  ('murder', 123),
#  ('based on novel', 111),
#  ('violence', 87),
#  ('sport', 82),
#  ('biography', 77),
#  ('aftercreditsstinger', 75),
#  ('dystopia', 73)]

# %% [markdown]
# We find woman director , independent film ,duringcreditsstinger ,murder as most common keywords.

# %% [markdown]
# Similar to what we did for genere,production countries etc , here too we extract the number of keywords , most common keywords in separate columns.

# %%
train['keywords']=train['Keywords'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
train['num_kwds']=train['Keywords'].apply(lambda x:len(x) if x!={} else 0)
top_kwds=[m[0] for m in Counter([i for j in kwds for i in j]).most_common(5)]
for g in top_kwds:
    train['kwds_' + g] = train['keywords'].apply(lambda x: 1 if g in x else 0)
    
test['keywords']=test['Keywords'].apply(lambda x:' '.join(sorted([i['name'] for i in x])) if x != {} else '')
test['num_kwds']=test['Keywords'].apply(lambda x:len(x) if x!={} else 0)
for g in top_kwds:
    test['kwds_' + g] = test['keywords'].apply(lambda x: 1 if g in x else 0)
    
train=train.drop('Keywords',axis=1)
test=test.drop('Keywords',axis=1)

# %% [markdown]
# ### Cast

# %% [markdown]
# Lets check the cast column .

# %%
train['cast'].head()
# Out:
# 0    [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1    [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2    [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3    [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4    [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# Name: cast, dtype: object

# %%
for i,e in enumerate(train['cast'].head()):
    print(i,e)
# Out:
# 0 [{'cast_id': 4, 'character': 'Lou', 'credit_id': '52fe4ee7c3a36847f82afae7', 'gender': 2, 'id': 52997, 'name': 'Rob Corddry', 'order': 0, 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'cast_id': 5, 'character': 'Nick', 'credit_id': '52fe4ee7c3a36847f82afaeb', 'gender': 2, 'id': 64342, 'name': 'Craig Robinson', 'order': 1, 'profile_path': '/tVaRMkJXOEVhYxtnnFuhqW0Rjzz.jpg'}, {'cast_id': 6, 'character': 'Jacob', 'credit_id': '52fe4ee7c3a36847f82afaef', 'gender': 2, 'id': 54729, 'name': 'Clark Duke', 'order': 2, 'profile_path': '/oNzK0umwm5Wn0wyEbOy6TVJCSBn.jpg'}, {'cast_id': 7, 'character': 'Adam Jr.', 'credit_id': '52fe4ee7c3a36847f82afaf3', 'gender': 2, 'id': 36801, 'name': 'Adam Scott', 'order': 3, 'profile_path': '/5gb65xz8bzd42yjMAl4zwo4cvKw.jpg'}, {'cast_id': 8, 'character': 'Hot Tub Repairman', 'credit_id': '52fe4ee7c3a36847f82afaf7', 'gender': 2, 'id': 54812, 'name': 'Chevy Chase', 'order': 4, 'profile_path': '/svjpyYtPwtjvRxX9IZnOmOkhDOt.jpg'}, {'cast_id': 9, 'character': 'Jill', 'credit_id': '52fe4ee7c3a36847f82afafb', 'gender': 1, 'id': 94098, 'name': 'Gillian Jacobs', 'order': 5, 'profile_path': '/rBnhe5vhNPnhRUdtYahBWx90fJM.jpg'}, {'cast_id': 10, 'character': 'Sophie', 'credit_id': '52fe4ee7c3a36847f82afaff', 'gender': 1, 'id': 1159009, 'name': 'Bianca Haase', 'order': 6, 'profile_path': '/4x3nbtD8q8phAJPmoGWXPvz0iM.jpg'}, {'cast_id': 11, 'character': 'Kelly', 'credit_id': '5524ec51c3a3687df3000dbb', 'gender': 1, 'id': 86624, 'name': 'Collette Wolfe', 'order': 7, 'profile_path': '/aSD4h5379b2eEw3bLou9ByLimmq.jpg'}, {'cast_id': 13, 'character': 'Brad', 'credit_id': '5524ec8ec3a3687ded000d72', 'gender': 2, 'id': 466505, 'name': 'Kumail Nanjiani', 'order': 9, 'profile_path': '/x4nAztHY72SVciRfxEsbhIVTsIu.jpg'}, {'cast_id': 14, 'character': 'Courtney', 'credit_id': '5524ec9bc3a3687df8000d13', 'gender': 1, 'id': 70776, 'name': 'Kellee Stewart', 'order': 10, 'profile_path': '/w3xmsEPmJc1Cf0dQ4aIn8YmlHbk.jpg'}, {'cast_id': 15, 'character': 'Terry', 'credit_id': '5524eca892514171cb008237', 'gender': 2, 'id': 347335, 'name': 'Josh Heald', 'order': 11, 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'cast_id': 16, 'character': 'Susan', 'credit_id': '5524ecb7925141720c001116', 'gender': 0, 'id': 1451392, 'name': 'Gretchen Koerner', 'order': 12, 'profile_path': '/muULPexCTJGyJba4yKzxronpD50.jpg'}, {'cast_id': 17, 'character': 'Herself', 'credit_id': '5524ecc3c3a3687ded000d74', 'gender': 1, 'id': 98879, 'name': 'Lisa Loeb', 'order': 13, 'profile_path': '/bGqg58ca0bZR38z9HliUMmeNGE.jpg'}, {'cast_id': 18, 'character': 'Herself', 'credit_id': '5524ecd3c3a3687e11000ed3', 'gender': 1, 'id': 1394648, 'name': 'Jessica Williams', 'order': 14, 'profile_path': '/A4syKjkcYB92wLEhH0c0hC3BCpz.jpg'}, {'cast_id': 19, 'character': 'Himself', 'credit_id': '5524ece6925141718d001009', 'gender': 0, 'id': 1451393, 'name': 'Bruce Buffer', 'order': 15, 'profile_path': None}, {'cast_id': 20, 'character': 'Shot Girl', 'credit_id': '5524ecf5c3a3687e08000dc2', 'gender': 0, 'id': 1451394, 'name': 'Mariana Paola Vicente', 'order': 16, 'profile_path': '/ckPllza8624UHWGHCbLShkLxCD1.jpg'}, {'cast_id': 33, 'character': 'Choozy Doozy Host', 'credit_id': '555844da9251412afe0013a9', 'gender': 2, 'id': 2224, 'name': 'Christian Slater', 'order': 17, 'profile_path': '/3ElLWjnvchMS6Q4cIQOK8QNAoMG.jpg'}, {'cast_id': 35, 'character': 'Gary Winkle', 'credit_id': '55872027c3a3683853005074', 'gender': 0, 'id': 185805, 'name': 'Jason Jones', 'order': 18, 'profile_path': '/aIoCw6vo8AGMdsQRAI5g2t0yJT3.jpg'}, {'cast_id': 36, 'character': 'Bridesmaid', 'credit_id': '55efe971c3a368090c00cd1b', 'gender': 0, 'id': 1507448, 'name': 'Olivia Jordan', 'order': 19, 'profile_path': '/szMukAEiIDeasel0lvyaeyKuych.jpg'}, {'cast_id': 37, 'character': 'Christine', 'credit_id': '55efe980c3a36871bf008176', 'gender': 1, 'id': 1334091, 'name': 'Christine Bently', 'order': 20, 'profile_path': '/oUZltnGa55OXE52hfyPTfCshuNy.jpg'}, {'cast_id': 38, 'character': 'Excited Girl', 'credit ...
# 1 [{'cast_id': 1, 'character': 'Mia Thermopolis', 'credit_id': '52fe43fe9251416c7502561f', 'gender': 1, 'id': 1813, 'name': 'Anne Hathaway', 'order': 0, 'profile_path': '/jUMOKwSUBnTcMeN1HfhutiY49Ad.jpg'}, {'cast_id': 2, 'character': 'Queen Clarisse Renaldi', 'credit_id': '52fe43fe9251416c75025623', 'gender': 1, 'id': 5823, 'name': 'Julie Andrews', 'order': 1, 'profile_path': '/6t61jkmfSA6nbYRCKR9s97CgUN6.jpg'}, {'cast_id': 3, 'character': 'Joe', 'credit_id': '52fe43fe9251416c75025627', 'gender': 2, 'id': 1210, 'name': 'H√©ctor Elizondo', 'order': 2, 'profile_path': '/48UNfVFZVr0jyMIlLPhzm8IIM7f.jpg'}, {'cast_id': 4, 'character': 'Viscount Mabrey', 'credit_id': '52fe43fe9251416c7502562b', 'gender': 2, 'id': 655, 'name': 'John Rhys-Davies', 'order': 3, 'profile_path': '/zZ67PuoFfik9QlZyfaEsFBC1yVJ.jpg'}, {'cast_id': 5, 'character': 'Lilly Moscovitz', 'credit_id': '52fe43fe9251416c7502562f', 'gender': 1, 'id': 33656, 'name': 'Heather Matarazzo', 'order': 4, 'profile_path': '/xcwR8aPuSkUCDPIyKU049M1CXph.jpg'}, {'cast_id': 6, 'character': 'Nicholas Devereaux', 'credit_id': '52fe43fe9251416c75025633', 'gender': 2, 'id': 62064, 'name': 'Chris Pine', 'order': 5, 'profile_path': '/vSe6sIsdtcoqBhuWRXynahFg8Vf.jpg'}, {'cast_id': 7, 'character': 'Andrew Jacoby', 'credit_id': '52fe43fe9251416c75025637', 'gender': 2, 'id': 68287, 'name': 'Callum Blue', 'order': 6, 'profile_path': '/3qf8rLoWmXOcCA8Rs9RPIEQ9yLB.jpg'}, {'cast_id': 17, 'character': 'Paolo', 'credit_id': '52fe43fe9251416c75025671', 'gender': 2, 'id': 1211, 'name': 'Larry Miller', 'order': 7, 'profile_path': '/xA8zCxNrwtamLaLWNBkLyX5tGtU.jpg'}, {'cast_id': 18, 'character': 'Asana', 'credit_id': '52fe43fe9251416c75025675', 'gender': 1, 'id': 66896, 'name': 'Raven-Symon√©', 'order': 8, 'profile_path': '/nzklI9bgqsUKVWlnQcT5lSrCyaM.jpg'}, {'cast_id': 19, 'character': 'Charlotte Kutaway', 'credit_id': '52fe43fe9251416c75025679', 'gender': 1, 'id': 303542, 'name': 'Kathleen Marshall', 'order': 9, 'profile_path': '/4ANxOHPa81aqLyP8BQxkwmZrWgK.jpg'}, {'cast_id': 21, 'character': "Mia's Mom Helen", 'credit_id': '5687f876c3a3685f8900e2a1', 'gender': 1, 'id': 6692, 'name': 'Caroline Goodall', 'order': 10, 'profile_path': '/f3L5WmEtGjjONTe8qvBZOy2dWTJ.jpg'}, {'cast_id': 20, 'character': 'Princess Lorraine', 'credit_id': '5687f825c3a36860e9023861', 'gender': 1, 'id': 966053, 'name': 'Lorraine Nicholson', 'order': 11, 'profile_path': '/eCsoySifBALa6UecWWQ6XShkkeV.jpg'}, {'cast_id': 22, 'character': 'Lady Salsa', 'credit_id': '56b67fc4c3a3680700009953', 'gender': 1, 'id': 95469, 'name': 'Shannon Wilcox', 'order': 12, 'profile_path': '/dQTvcWdLyB5RIWNQxk4DWn6ko59.jpg'}, {'cast_id': 23, 'character': 'Baron Siegfried von Troken', 'credit_id': '56c0ad8cc3a36817f400cc2d', 'gender': 2, 'id': 33832, 'name': 'Greg Lewis', 'order': 13, 'profile_path': '/ys6erqERBQhfTsvCiarmwH8daUm.jpg'}, {'cast_id': 24, 'character': 'Carolina', 'credit_id': '575e0b469251415dd2004e97', 'gender': 1, 'id': 17140, 'name': 'Abigail Breslin', 'order': 14, 'profile_path': '/5zM4beIvrFKICiJXhQCqY3ORngR.jpg'}, {'cast_id': 25, 'character': 'Lord Crawley', 'credit_id': '575e0bc1c3a3683731002094', 'gender': 2, 'id': 155403, 'name': 'Paul Vogt', 'order': 15, 'profile_path': None}, {'cast_id': 26, 'character': 'Monsieur Dupont', 'credit_id': '57c8cc429251410d5000019d', 'gender': 2, 'id': 1665036, 'name': 'Joseph Leo Bwarie', 'order': 16, 'profile_path': '/9H8u70pOBdk0xZsRcKIleBEAyLK.jpg'}, {'cast_id': 27, 'character': 'Lady Caroline', 'credit_id': '57dd9a1092514178550018e1', 'gender': 1, 'id': 83053, 'name': 'Hope Alexander-Willis', 'order': 17, 'profile_path': '/uMA3E1OUniek80LNbqf8ejK2edW.jpg'}, {'cast_id': 28, 'character': 'Lord Peroit', 'credit_id': '57eecf689251416cd60095c1', 'gender': 2, 'id': 1451161, 'name': 'Rowan Joseph', 'order': 18, 'profile_path': '/6zUforjrDfcPoP8YMsdIaoygHmz.jpg'}, {'cast_id': 29, 'character': 'Genovian Cafe Owner', 'credit_id': '57eed0ff9251415ddb00752b', 'gender': 2, 'id': 156005, 'name': 'Jeffrey  ...
# 2 [{'cast_id': 5, 'character': 'Andrew Neimann', 'credit_id': '52fe4ef7c3a36847f82b3fc3', 'gender': 2, 'id': 996701, 'name': 'Miles Teller', 'order': 0, 'profile_path': '/o2wfvYAvspsKqYVt4ORR8VWjB7H.jpg'}, {'cast_id': 6, 'character': 'Terence Fletcher', 'credit_id': '52fe4ef7c3a36847f82b3fc7', 'gender': 2, 'id': 18999, 'name': 'J.K. Simmons', 'order': 1, 'profile_path': '/jPoNW5fugs5h8AbcE7H5OBm04Tm.jpg'}, {'cast_id': 11, 'character': 'Nicole', 'credit_id': '52fe4ef7c3a36847f82b3fe3', 'gender': 1, 'id': 129104, 'name': 'Melissa Benoist', 'order': 2, 'profile_path': '/fj3Va0w2OyKaQALGomMgpq2B2Fu.jpg'}, {'cast_id': 12, 'character': 'Ryan', 'credit_id': '52fe4ef7c3a36847f82b3fe7', 'gender': 2, 'id': 970216, 'name': 'Austin Stowell', 'order': 3, 'profile_path': '/su6KMYwfr4qVXRjlXi4u0h16Fxg.jpg'}, {'cast_id': 13, 'character': 'Travis', 'credit_id': '52fe4ef7c3a36847f82b3feb', 'gender': 2, 'id': 223012, 'name': 'Jayson Blair', 'order': 4, 'profile_path': '/lqWVUUOBrv4ANxyvsv5aagc6CBq.jpg'}, {'cast_id': 14, 'character': 'Assistant - Sophie', 'credit_id': '52fe4ef7c3a36847f82b3fef', 'gender': 1, 'id': 159366, 'name': 'Kavita Patil', 'order': 5, 'profile_path': '/z5tSybvNYudaFK2db7bTw9tDqyP.jpg'}, {'cast_id': 15, 'character': 'Mr. Neyman', 'credit_id': '5466cd46eaeb817274000acb', 'gender': 2, 'id': 781, 'name': 'Paul Reiser', 'order': 6, 'profile_path': '/fr53dQQrDGfETgbliCktwKqteRU.jpg'}, {'cast_id': 22, 'character': 'Carl Tanner', 'credit_id': '5525414d925141720c001b56', 'gender': 0, 'id': 1451540, 'name': 'Nate Lang', 'order': 7, 'profile_path': None}, {'cast_id': 23, 'character': 'Uncle Frank', 'credit_id': '5525415fc3a3687df80016c4', 'gender': 2, 'id': 15824, 'name': 'Chris Mulkey', 'order': 8, 'profile_path': '/ibXN9Ho0nCF4jbGHeQYRHI8AMjH.jpg'}, {'cast_id': 24, 'character': 'Mr. Kramer', 'credit_id': '5525416c9251417276001927', 'gender': 2, 'id': 53454, 'name': 'Damon Gupton', 'order': 9, 'profile_path': '/8t8IBqQjRJkPcugmcAAn1C7J0pg.jpg'}, {'cast_id': 25, 'character': 'Aunt Emma', 'credit_id': '55254179c3a3687ded0016cf', 'gender': 0, 'id': 1212459, 'name': 'Suanne Spoke', 'order': 10, 'profile_path': None}, {'cast_id': 26, 'character': 'Dorm Neighbor', 'credit_id': '552541869251417be200a8f2', 'gender': 2, 'id': 52939, 'name': 'Max Kasch', 'order': 11, 'profile_path': '/4NzNJEJ6NWU40GKO6BS1Ne6ECNL.jpg'}, {'cast_id': 27, 'character': 'Dustin', 'credit_id': '552541959251415c7c00bd61', 'gender': 0, 'id': 1451542, 'name': 'Charlie Ian', 'order': 12, 'profile_path': None}, {'cast_id': 29, 'character': 'Bassist (Nassau)', 'credit_id': '552541ae925141720c001b71', 'gender': 2, 'id': 1451543, 'name': 'Kofi Siriboe', 'order': 14, 'profile_path': '/4qxcHkPIMUMZCW7UNH9kIfRndgS.jpg'}, {'cast_id': 31, 'character': 'Metz', 'credit_id': '552541c7c3a3687e08001774', 'gender': 0, 'id': 1451545, 'name': 'C.J. Vana', 'order': 16, 'profile_path': None}, {'cast_id': 32, 'character': 'Pianist (Studio Band)', 'credit_id': '55e6d136c3a3685f85002956', 'gender': 0, 'id': 171766, 'name': 'Tarik Lowe', 'order': 17, 'profile_path': '/ze1kaigQO0wLP4DtLnDIdqtfxtZ.jpg'}, {'cast_id': 33, 'character': 'Saxophonist #2 (Studio Band)', 'credit_id': '55e6d136c3a3685f98002c48', 'gender': 0, 'id': 1398714, 'name': 'Tyler Kimball', 'order': 18, 'profile_path': None}, {'cast_id': 34, 'character': 'Trumpeter #1 (Studio Band)', 'credit_id': '55e6d136c3a3685f8e002617', 'gender': 0, 'id': 1503721, 'name': 'Rogelio Douglas Jr.', 'order': 19, 'profile_path': '/j7NJ52wEo58siDpkzIWIKyC7DD5.jpg'}, {'cast_id': 35, 'character': 'Trumpeter #2 (Studio Band)', 'credit_id': '55e6d137c3a3685f9100272e', 'gender': 0, 'id': 1503834, 'name': 'Adrian Burks', 'order': 20, 'profile_path': None}, {'cast_id': 36, 'character': 'Technician (Overbrook) - Mike', 'credit_id': '55e6d1379251410f0a0026b6', 'gender': 0, 'id': 1503835, 'name': 'Joseph Bruno', 'order': 21, 'profile_path': None}, {'cast_id': 37, 'character': 'Stage Hand (Overbrook)', 'credit_id': '55e6d1379251410f0d002526', 'gender': 0, 'id' ...
# 3 [{'cast_id': 1, 'character': 'Vidya Bagchi', 'credit_id': '52fe48779251416c9108d6d9', 'gender': 1, 'id': 35068, 'name': 'Vidya Balan', 'order': 0, 'profile_path': '/anMmmqKY11jcm0UnSSakfNOSCyB.jpg'}, {'cast_id': 5, 'character': '', 'credit_id': '57722abec3a368245b004519', 'gender': 2, 'id': 85047, 'name': 'Nawazuddin Siddiqui', 'order': 1, 'profile_path': '/2Kv2ENAs1ETAFTQ6mC1jbDzEzIN.jpg'}, {'cast_id': 6, 'character': '', 'credit_id': '57722aea9251411dca003f8f', 'gender': 0, 'id': 1021524, 'name': 'Parambrata Chatterjee', 'order': 2, 'profile_path': '/Aif4X9ihmRrVzX1cbWDDznk8HZV.jpg'}, {'cast_id': 7, 'character': '', 'credit_id': '57722b069251411dcd003f73', 'gender': 0, 'id': 1093644, 'name': 'Saswata Chatterjee', 'order': 3, 'profile_path': '/vuHaLzSVRIo7pXSmhB7ko6YmNs.jpg'}, {'cast_id': 8, 'character': '', 'credit_id': '57722b26c3a36869a2000745', 'gender': 0, 'id': 86033, 'name': 'Indraneil Sengupta', 'order': 4, 'profile_path': '/4hLg7XIJdhrS3t0h5Q8vQxnp4DZ.jpg'}, {'cast_id': 9, 'character': '', 'credit_id': '57722b38c3a3682468004294', 'gender': 2, 'id': 92686, 'name': 'Darshan Jariwala', 'order': 5, 'profile_path': '/lWDqLNG6FKNv4VSQILiRMPxJ7Hh.jpg'}, {'cast_id': 10, 'character': '', 'credit_id': '57722b549251411dd90041dd', 'gender': 0, 'id': 35821, 'name': 'Masood Akhtar', 'order': 6, 'profile_path': None}]
# 4 [{'cast_id': 3, 'character': 'Chun-soo', 'credit_id': '52fe464b9251416c75073b47', 'gender': 2, 'id': 84751, 'name': 'Kim Kang-woo', 'order': 0, 'profile_path': '/lJvcgUx1qEnNfGcCtbmp3EC5vCG.jpg'}, {'cast_id': 4, 'character': 'Company president Kang', 'credit_id': '52fe464b9251416c75073b4b', 'gender': 2, 'id': 64453, 'name': 'Jo Jae-hyeon', 'order': 1, 'profile_path': '/2QVUP8t3zmKcwlm7IBOzPVikKe7.jpg'}, {'cast_id': 5, 'character': 'Yu-ri', 'credit_id': '52fe464b9251416c75073b4f', 'gender': 2, 'id': 84752, 'name': 'Park Si-yeon', 'order': 2, 'profile_path': '/pIWhmT2GTVcaNTb6Qta2KS9jyTT.jpg'}, {'cast_id': 7, 'character': 'Company president Hwang', 'credit_id': '52fe464b9251416c75073b59', 'gender': 2, 'id': 1130534, 'name': 'Kim Joon-bae', 'order': 3, 'profile_path': '/pMy3HSxj6DdysI1P2tpjcD4FyWM.jpg'}]

# %% [markdown]
# We have the information on cast id , character , credit id , gender , id , name ,order and  profile path .
# We extract the most common characters , actors from this column since its an intuition that people will watch a movie if their favourite actor stars in the movie or if its a series , the character would already made an impact and peoplw will love to watch it .

# %%
list_charac = list(train['cast'].apply(lambda x:[i['character'] for i in x] if x!={} else []).values)

# %%
Counter(i for j in list_charac for i in j).most_common(10)
# Out:
# [('', 818),
#  ('Himself', 610),
#  ('Herself', 155),
#  ('Dancer', 144),
#  ('Additional Voices (voice)', 100),
#  ('Doctor', 77),
#  ('Reporter', 70),
#  ('Waitress', 69),
#  ('Nurse', 65),
#  ('Bartender', 55)]

# %% [markdown]
# From the list it is seen that there are more entries where character name is not specified.

# %%
list_actors =list(train['cast'].apply(lambda x:[i['name'] for i in x] if x!={} else []).values)

# %%
Counter(i for j in list_actors for i in j).most_common(15)
# Out:
# [('Samuel L. Jackson', 30),
#  ('Robert De Niro', 30),
#  ('Morgan Freeman', 27),
#  ('J.K. Simmons', 25),
#  ('Bruce Willis', 25),
#  ('Liam Neeson', 25),
#  ('Susan Sarandon', 25),
#  ('Bruce McGill', 24),
#  ('John Turturro', 24),
#  ('Forest Whitaker', 23),
#  ('Willem Dafoe', 23),
#  ('Bill Murray', 22),
#  ('Owen Wilson', 22),
#  ('Nicolas Cage', 22),
#  ('Sylvester Stallone', 21)]

# %% [markdown]
# From the list we understand that the actors include both lead as well as supporting actors . We also want to separate out the lead actor from the movie .This can be extracted from the dictionary where the cast id is equal to 1 . Lets do it .

# %%
lead_actors=list(train['cast'].apply(lambda x:[i['name'] for i in x if i['cast_id']==1 or i['cast_id']==2] if x!={} else []).values)

# %%
Counter(i for j in lead_actors for i in j).most_common(15)
# Out:
# [('Mel Gibson', 12),
#  ('Denzel Washington', 11),
#  ('Eddie Murphy', 10),
#  ('John Travolta', 9),
#  ('Jeff Bridges', 9),
#  ('Nicolas Cage', 9),
#  ('Robert De Niro', 9),
#  ('Dennis Quaid', 9),
#  ('Gene Hackman', 8),
#  ('Sylvester Stallone', 8),
#  ('Owen Wilson', 8),
#  ('John Cusack', 8),
#  ('Clint Eastwood', 8),
#  ('Mark Wahlberg', 8),
#  ('Diane Keaton', 7)]

# %% [markdown]
# We have 12 movies from Mel Gibson ,11 from Denzel Washington ,10 from Eddie Murphy . We create a separate column with lead actors.

# %%
train['lead_act_1']=train['cast'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['cast_id']==1])) if x != {} else '')
train['lead_act_2']=train['cast'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['cast_id']==2])) if x != {} else '')
# top_actors=[m[0] for m in Counter([i for j in list_actors for i in j]).most_common(10)]
# for g in top_actors:
#     train['act_' + g] = train['keywords'].apply(lambda x: 1 if g in x else 0)
test['lead_act_1']=test['cast'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['cast_id']==1])) if x != {} else '')
test['lead_act_2']=test['cast'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['cast_id']==2])) if x != {} else '')

train=train.drop('cast',axis=1)
test=test.drop('cast',axis=1)

# %% [markdown]
# ### Crew

# %% [markdown]
# Lets check the crew column.

# %%
for i,e in enumerate(train['crew'].head()):
    print(i,e)
# Out:
# 0 [{'credit_id': '59ac067c92514107af02c8c8', 'department': 'Directing', 'gender': 0, 'id': 1449071, 'job': 'First Assistant Director', 'name': 'Kelly Cantley', 'profile_path': None}, {'credit_id': '52fe4ee7c3a36847f82afad7', 'department': 'Directing', 'gender': 2, 'id': 3227, 'job': 'Director', 'name': 'Steve Pink', 'profile_path': '/myHOgo8mQSCiCAZNGMRdHVr03jr.jpg'}, {'credit_id': '5524ed25c3a3687ded000d88', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Writer', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed2d925141720c001128', 'department': 'Writing', 'gender': 2, 'id': 347335, 'job': 'Characters', 'name': 'Josh Heald', 'profile_path': '/pwXJIenrDMrG7t3zNfLvr8w1RGU.jpg'}, {'credit_id': '5524ed3d92514166c1004a5d', 'department': 'Production', 'gender': 2, 'id': 57822, 'job': 'Producer', 'name': 'Andrew Panay', 'profile_path': None}, {'credit_id': '5524ed4bc3a3687df3000dd2', 'department': 'Production', 'gender': 0, 'id': 1451395, 'job': 'Associate Producer', 'name': 'Adam Blum', 'profile_path': None}, {'credit_id': '5524ed5a925141720c00112c', 'department': 'Production', 'gender': 2, 'id': 52997, 'job': 'Executive Producer', 'name': 'Rob Corddry', 'profile_path': '/k2zJL0V1nEZuFT08xUdOd3ucfXz.jpg'}, {'credit_id': '5524ed85c3a3687e0e000f56', 'department': 'Production', 'gender': 0, 'id': 62807, 'job': 'Executive Producer', 'name': 'Ben Ormand', 'profile_path': None}, {'credit_id': '5524ed9fc3a3687e0e000f59', 'department': 'Sound', 'gender': 2, 'id': 23486, 'job': 'Original Music Composer', 'name': 'Christophe Beck', 'profile_path': '/2fnJUmCk6IEpVIptpYaUk31epHx.jpg'}, {'credit_id': '5524eda6c3a3687e03000d28', 'department': 'Camera', 'gender': 2, 'id': 6117, 'job': 'Director of Photography', 'name': 'Declan Quinn', 'profile_path': None}, {'credit_id': '5524edb4925141720c00113d', 'department': 'Editing', 'gender': 0, 'id': 1451396, 'job': 'Editor', 'name': 'Jamie Gross', 'profile_path': None}, {'credit_id': '5524edc1925141727600102e', 'department': 'Production', 'gender': 0, 'id': 22219, 'job': 'Casting', 'name': 'Susie Farris', 'profile_path': None}, {'credit_id': '5524edd192514171cb008257', 'department': 'Art', 'gender': 0, 'id': 1002643, 'job': 'Production Design', 'name': 'Ryan Berg', 'profile_path': None}, {'credit_id': '555ad9be9251411e5b00d485', 'department': 'Production', 'gender': 2, 'id': 57431, 'job': 'Executive Producer', 'name': 'Matt Moore', 'profile_path': None}, {'credit_id': '5677e93bc3a36816890087dc', 'department': 'Directing', 'gender': 0, 'id': 1551818, 'job': 'Script Supervisor', 'name': 'Nicole Garcea', 'profile_path': None}, {'credit_id': '5677e96a92514179e10093d0', 'department': 'Production', 'gender': 0, 'id': 1551819, 'job': 'Production Coordinator', 'name': 'Jason Salzman', 'profile_path': None}, {'credit_id': '5677e98492514179d2008cd9', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 1422996, 'job': 'Costume Design', 'name': 'Carol Cutshall', 'profile_path': None}, {'credit_id': '5677e9d5c3a368168e009414', 'department': 'Art', 'gender': 2, 'id': 500199, 'job': 'Set Decoration', 'name': 'Tim Cohn', 'profile_path': None}, {'credit_id': '5677f89d9251417845001a61', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 1527917, 'job': 'Hair Department Head', 'name': 'Voni Hinkle', 'profile_path': None}, {'credit_id': '5677f8b392514179dd0089fb', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 1431554, 'job': 'Makeup Department Head', 'name': 'Remi Savva', 'profile_path': None}, {'credit_id': '5677f8d1c3a3681689008a4b', 'department': 'Art', 'gender': 0, 'id': 66495, 'job': 'Art Direction', 'name': 'Jason Baldwin Stewart', 'profile_path': None}, {'credit_id': '5677f8eec3a3681685008dd5', 'department': 'Production', 'gender': 0, 'id': 1412466, 'job': 'Production Supervisor', 'name': 'Korey Budd', 'profile_path': None}, {'credit_id': '5677f90a9251417845001a7d', 'department': 'Sound', 'gender': 0, 'id': 1401562, 'job': 'Sound Re-Recording Mi ...
# 1 [{'credit_id': '52fe43fe9251416c7502563d', 'department': 'Directing', 'gender': 2, 'id': 1201, 'job': 'Director', 'name': 'Garry Marshall', 'profile_path': '/kx77E8p5rnEmKxIhFT0qWCEMEik.jpg'}, {'credit_id': '52fe43fe9251416c75025667', 'department': 'Camera', 'gender': 2, 'id': 1214, 'job': 'Director of Photography', 'name': 'Charles Minsky', 'profile_path': None}, {'credit_id': '52fe43fe9251416c75025661', 'department': 'Sound', 'gender': 2, 'id': 4500, 'job': 'Original Music Composer', 'name': 'John Debney', 'profile_path': '/hTrlvZlDXQk49nfc2BM9sjKfJv.jpg'}, {'credit_id': '52fe43fe9251416c7502564f', 'department': 'Production', 'gender': 1, 'id': 8851, 'job': 'Producer', 'name': 'Whitney Houston', 'profile_path': '/69ouDnXnmklYPr4sMJXWKYz81AL.jpg'}, {'credit_id': '52fe43fe9251416c7502566d', 'department': 'Editing', 'gender': 0, 'id': 12970, 'job': 'Editor', 'name': 'Bruce Green', 'profile_path': '/yplxWPVgwK1b33AjvbhM9mWX2Aw.jpg'}, {'credit_id': '52fe43fe9251416c75025655', 'department': 'Production', 'gender': 2, 'id': 38415, 'job': 'Producer', 'name': 'Mario Iscovich', 'profile_path': None}, {'credit_id': '52fe43fe9251416c7502565b', 'department': 'Production', 'gender': 1, 'id': 38416, 'job': 'Executive Producer', 'name': 'Ellen H. Schwartz', 'profile_path': '/6WInjABr1sAYGXaa5qOvSrsHIqP.jpg'}, {'credit_id': '52fe43fe9251416c75025649', 'department': 'Production', 'gender': 1, 'id': 59973, 'job': 'Producer', 'name': 'Debra Martin Chase', 'profile_path': None}, {'credit_id': '52fe43fe9251416c75025643', 'department': 'Writing', 'gender': 1, 'id': 25539, 'job': 'Screenplay', 'name': 'Shonda Rhimes', 'profile_path': '/4c77e347InbTAlw9lGvORpZBHV6.jpg'}]
# 2 [{'credit_id': '54d5356ec3a3683ba0000039', 'department': 'Production', 'gender': 1, 'id': 494, 'job': 'Casting', 'name': 'Terri Taylor', 'profile_path': None}, {'credit_id': '56407fa89251417055000b58', 'department': 'Sound', 'gender': 0, 'id': 6745, 'job': 'Music Editor', 'name': 'Richard Henderson', 'profile_path': None}, {'credit_id': '5789212392514135d60025fd', 'department': 'Production', 'gender': 2, 'id': 9250, 'job': 'Executive In Charge Of Production', 'name': 'Jeffrey Stott', 'profile_path': None}, {'credit_id': '57892074c3a36835fa002886', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 23783, 'job': 'Makeup Artist', 'name': 'Heather Plott', 'profile_path': None}, {'credit_id': '56408055925141705c000bee', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 23786, 'job': 'Makeup Department Head', 'name': 'Nacoma Whobrey', 'profile_path': None}, {'credit_id': '52fe4ef7c3a36847f82b3fb9', 'department': 'Camera', 'gender': 2, 'id': 53181, 'job': 'Director of Photography', 'name': 'Sharone Meir', 'profile_path': None}, {'credit_id': '56407e4ac3a3685059000c7c', 'department': 'Production', 'gender': 2, 'id': 52443, 'job': 'Executive Producer', 'name': 'Jason Reitman', 'profile_path': '/bW44MnIOve5kqqtcmmbzBre0N7D.jpg'}, {'credit_id': '52fe4ef7c3a36847f82b3fd9', 'department': 'Production', 'gender': 2, 'id': 60864, 'job': 'Producer', 'name': 'David Lancaster', 'profile_path': None}, {'credit_id': '52fe4ef7c3a36847f82b3fdf', 'department': 'Production', 'gender': 0, 'id': 66726, 'job': 'Producer', 'name': 'Michel Litvak', 'profile_path': None}, {'credit_id': '56407e8b9251417052000c80', 'department': 'Production', 'gender': 2, 'id': 66727, 'job': 'Executive Producer', 'name': 'Gary Michael Walters', 'profile_path': None}, {'credit_id': '52fe4ef7c3a36847f82b3fcd', 'department': 'Production', 'gender': 2, 'id': 84348, 'job': 'Producer', 'name': 'Jason Blum', 'profile_path': None}, {'credit_id': '52fe4ef7c3a36847f82b3fb3', 'department': 'Writing', 'gender': 2, 'id': 136495, 'job': 'Screenplay', 'name': 'Damien Chazelle', 'profile_path': '/x5bpTU8b2mwgPpPDGJGWsJ1Qt3t.jpg'}, {'credit_id': '52fe4ef7c3a36847f82b3fad', 'department': 'Directing', 'gender': 2, 'id': 136495, 'job': 'Director', 'name': 'Damien Chazelle', 'profile_path': '/x5bpTU8b2mwgPpPDGJGWsJ1Qt3t.jpg'}, {'credit_id': '56407f1cc3a368506d000bfb', 'department': 'Crew', 'gender': 0, 'id': 198799, 'job': 'Stunt Coordinator', 'name': 'Mark Riccardi', 'profile_path': None}, {'credit_id': '57898004c3a36851a8000a45', 'department': 'Production', 'gender': 0, 'id': 230436, 'job': 'Casting', 'name': 'Barbara Harris', 'profile_path': None}, {'credit_id': '566aac9b92514169e2004626', 'department': 'Camera', 'gender': 0, 'id': 1017376, 'job': 'Steadicam Operator', 'name': 'Chris Squires', 'profile_path': None}, {'credit_id': '5789815c9251410db8000ab6', 'department': 'Crew', 'gender': 1, 'id': 1018788, 'job': 'Thanks', 'name': 'Jasmine McGlade', 'profile_path': '/bmHzn0YY2mUoe9qbZKWb9nfDaDw.jpg'}, {'credit_id': '56407e7f9251417052000c7c', 'department': 'Production', 'gender': 1, 'id': 1030966, 'job': 'Executive Producer', 'name': 'Jeanette Brill', 'profile_path': None}, {'credit_id': '566aabcc92514173830040fb', 'department': 'Sound', 'gender': 0, 'id': 1049456, 'job': 'Supervising Sound Editor', 'name': 'Ben Wilkins', 'profile_path': None}, {'credit_id': '566aabbe92514173fc008d77', 'department': 'Sound', 'gender': 0, 'id': 1049456, 'job': 'Sound Re-Recording Mixer', 'name': 'Ben Wilkins', 'profile_path': None}, {'credit_id': '578922e4c3a36836c0002c11', 'department': 'Crew', 'gender': 0, 'id': 1099700, 'job': 'Stunts', 'name': 'Chester E. Tripp III', 'profile_path': None}, {'credit_id': '5789153b9251411e29002aca', 'department': 'Production', 'gender': 0, 'id': 1125189, 'job': 'Co-Producer', 'name': 'Garrick Dion', 'profile_path': None}, {'credit_id': '52fe4ef7c3a36847f82b3fbf', 'department': 'Editing', 'gender': 2, 'id': 1156888, 'job': 'Editor', 'name': 'Tom Cross', 'profile_path ...
# 3 [{'credit_id': '52fe48779251416c9108d6eb', 'department': 'Directing', 'gender': 0, 'id': 95510, 'job': 'Director', 'name': 'Sujoy Ghosh', 'profile_path': None}, {'credit_id': '52fe48779251416c9108d6e5', 'department': 'Production', 'gender': 0, 'id': 95510, 'job': 'Producer', 'name': 'Sujoy Ghosh', 'profile_path': None}, {'credit_id': '52fe48779251416c9108d6df', 'department': 'Writing', 'gender': 0, 'id': 95510, 'job': 'Writer', 'name': 'Sujoy Ghosh', 'profile_path': None}]
# 4 [{'credit_id': '52fe464b9251416c75073b43', 'department': 'Directing', 'gender': 0, 'id': 84749, 'job': 'Director', 'name': 'Jong-seok Yoon', 'profile_path': None}, {'credit_id': '52fe464b9251416c75073b55', 'department': 'Writing', 'gender': 0, 'id': 84749, 'job': 'Writer', 'name': 'Jong-seok Yoon', 'profile_path': None}]

# %% [markdown]
# Lets check the various job types and departments represented in the crew.

# %%
list_jobs = list(train['crew'].apply(lambda x:[i['job'] for i in x] if x!={} else []).values)

# %% [markdown]
# Once we have extracted the list of jobs lets create a separate crew name column who are from  the jobs that are most represented.

# %%
Counter(i for j in list_jobs for i in j).most_common(10)
# Out:
# [('Producer', 6011),
#  ('Executive Producer', 3459),
#  ('Director', 3225),
#  ('Screenplay', 2996),
#  ('Editor', 2824),
#  ('Casting', 2483),
#  ('Director of Photography', 2288),
#  ('Original Music Composer', 1947),
#  ('Art Direction', 1821),
#  ('Production Design', 1650)]

# %% [markdown]
# Thus we have the most important crew being represented the most in the list .We create separate columns to represent each of the jobs.

# %%
train['producer']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Producer"])) if x!={} else '')
train['exec_producer']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Executive Producer"])) if x!={} else '')
train['director']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Director"])) if x!={} else '')
train['screenplay']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Screenplay"])) if x!={} else '')
train['editor']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Editor"])) if x!={} else '')
train['music']=train['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Original Music Composer"])) if x!={} else '')


test['producer']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Producer"])) if x!={} else '')
test['exec_producer']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Executive Producer"])) if x!={} else '')
test['director']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Director"])) if x!={} else '')
test['screenplay']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Screenplay"])) if x!={} else '')
test['editor']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Editor"])) if x!={} else '')
test['music']=test['crew'].apply(lambda x:' '.join(sorted([i['name'] for i in x if i['job']=="Original Music Composer"])) if x!={} else '')

train=train.drop('crew',axis=1)
test=test.drop('crew',axis=1)

# %% [markdown]
# Now that we have extracted features from json type columns , lets check the data structure and proceed for building our model.

# %%
train.head()
# Out:
#    id    budget                           homepage    imdb_id  \
# 0   1  14000000                                NaN  tt2637294
# 1   2  40000000                                NaN  tt0368933
# 2   3   3300000  http://sonyclassics.com/whiplash/  tt2582802
# 3   4   1200000         http://kahaanithefilm.com/  tt1821480
# 4   5         0                                NaN  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path release_date       ...         \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg      2/20/15       ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg       8/6/04       ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg     10/10/14       ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg       3/9/12       ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg       2/5/09       ...
#
#    kwds_murder kwds_based on novel     lead_act_1     lead_act_2  \
# 0            0                   0
# 1            0                   0  Anne Hathaway  Julie Andrews
# 2            0                   0
# 3            0                   0    Vidya Balan
# 4            0                   0
#
#                                             producer  \
# 0                                       Andrew Panay
# 1  Debra Martin Chase Mario Iscovich Whitney Houston
# 2  David Lancaster Helen Estabrook Jason Blum Mic...
# 3                                        Sujoy Ghosh
# 4
#
#                                        exec_producer         director  \
# 0                  Ben Ormand Matt Moore Rob Corddry       Steve Pink
# 1                                  Ellen H. Schwartz   Garry Marshall
# 2  Couper Samuelson Gary Michael Walters Jason Re...  Damien Chazelle
# 3                                                         Sujoy Ghosh
# 4                                                      Jong-seok Yoon
#
#         screenplay       editor            music
# 0                   Jamie Gross  Christophe Beck
# 1    Shonda Rhimes  Bruce Green      John Debney
# 2  Damien Chazelle    Tom Cross   Justin Hurwitz
# 3
# 4
#
# [5 rows x 89 columns]

# %% [markdown]
# Lets try to remove unwanted columns.For simplicity purpose , lets remove the text columns overview ,tagline

# %%
train.columns
# Out:
# Index(['id', 'budget', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'release_date', 'runtime', 'status', 'tagline', 'title', 'revenue',
#        'collection_name', 'num_genres', 'all_genres', 'genre_Drama',
#        'genre_Comedy', 'genre_Thriller', 'genre_Action', 'genre_Romance',
#        'genre_Crime', 'genre_Adventure', 'genre_Horror',
#        'genre_Science Fiction', 'genre_Family', 'genre_Fantasy',
#        'genre_Mystery', 'genre_Animation', 'genre_History', 'genre_Music',
#        'prod_comp', 'num_prod', 'prod_Warner Bros.', 'prod_Universal Pictures',
#        'prod_Paramount Pictures',
#        'prod_Twentieth Century Fox Film Corporation', 'prod_Columbia Pictures',
#        'prod_Metro-Goldwyn-Mayer (MGM)', 'prod_New Line Cinema',
#        'prod_Touchstone Pictures', 'prod_Walt Disney Pictures',
#        'prod_Columbia Pictures Corporation', 'prod_TriStar Pictures',
#        'prod_Relativity Media', 'prod_Canal+', 'prod_United Artists',
#        'prod_Miramax Films', 'prod_country', 'num_country',
#        'count_Warner Bros.', 'count_Universal Pictures',
#        'count_Paramount Pictures',
#        'count_Twentieth Century Fox Film Corporation',
#        'count_Columbia Pictures', 'count_Metro-Goldwyn-Mayer (MGM)',
#        'count_New Line Cinema', 'count_Touchstone Pictures',
#        'count_Walt Disney Pictures', 'count_Columbia Pictures Corporation',
#        'count_TriStar Pictures', 'count_Relativity Media', 'count_Canal+',
#        'count_United Artists', 'count_Miramax Films', 'lang', 'num_lang',
#        'lang_Warner Bros.', 'lang_Universal Pictures',
#        'lang_Paramount Pictures',
#        'lang_Twentieth Century Fox Film Corporation', 'lang_Columbia Pictures',
#        'keywords', 'num_kwds', 'kwds_woman director', 'kwds_independent film',
#        'kwds_duringcreditsstinger', 'kwds_murder', 'kwds_based on novel',
#        'lead_act_1', 'lead_act_2', 'producer', 'exec_producer', 'director',
#        'screenplay', 'editor', 'music'],
#       dtype='object')

# %%
useful_cols=[f for f in train.drop('revenue',axis=1).columns if f not in ['title','id','overview','release_date','all_genres','keywords','homepage','imdb_id','poster_path','status','tagline','all_geners','prod_comp','prod_country','lang']]

# %% [markdown]
# Lets extract date features from release date.

# %%
train['release_date'].head()
# Out:
# 0     2/20/15
# 1      8/6/04
# 2    10/10/14
# 3      3/9/12
# 4      2/5/09
# Name: release_date, dtype: object

# %%
test['release_date'].isnull().sum()
# Out:
# 1

# %% [markdown]
# There is only 1 null value in the test data . Lets check which movie is it and impute the value.

# %%
test[test['release_date'].isnull()==True]
# Out:
#        id  budget homepage    imdb_id original_language  \
# 828  3829       0      NaN  tt0210130                en
#
#                  original_title  \
# 828  Jails, Hospitals & Hip-Hop
#
#                                               overview  popularity  \
# 828  Jails, Hospitals &amp; Hip-Hop is a cinematic ...    0.009057
#
#     poster_path release_date  ...    kwds_murder kwds_based on novel  \
# 828         NaN          NaN  ...              0                   0
#
#     lead_act_1 lead_act_2 producer  exec_producer director  screenplay  \
# 828
#
#      editor  music
# 828
#
# [1 rows x 88 columns]

# %% [markdown]
# A quick check in [IMBD](https://www.imdb.com/title/tt0210130/) puts the release date for this movie at May 2000 . Lets take 1st may as the date and impute it.

# %%
test.loc[test['release_date'].isnull()==True,'release_date']='5/1/00'

# %%
# temp_train=train.copy()
# temp_test=test.copy()

# %%
def fix_date(x):
    """
    Fixes dates which are in 20xx
    """
    year = x.split('/')[2]
    if int(year) <= 19:
        return x[:-2] + '20' + year
    else:
        return x[:-2] + '19' + year

# %%
train['release_date'] = train['release_date'].apply(lambda x: fix_date(x))
test['release_date'] = test['release_date'].apply(lambda x: fix_date(x))

train['release_date']=pd.to_datetime(train['release_date'])
test['release_date']=pd.to_datetime(test['release_date'])

# %%
### Using the function from Andrews kernel ,

def process_date(df):
    date_parts = ["year", "weekday", "month", 'weekofyear', 'day', 'quarter']
    for part in date_parts:
        part_col = 'release_date' + "_" + part
        df[part_col] = getattr(df['release_date'].dt, part).astype(int)
    
    return df

# %%
train = process_date(train)
test = process_date(test)

# %%
train.head()
# Out:
#    id    budget                           homepage    imdb_id  \
# 0   1  14000000                                NaN  tt2637294
# 1   2  40000000                                NaN  tt0368933
# 2   3   3300000  http://sonyclassics.com/whiplash/  tt2582802
# 3   4   1200000         http://kahaanithefilm.com/  tt1821480
# 4   5         0                                NaN  tt1380152
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
# 2                en                                  Whiplash
# 3                hi                                   Kahaani
# 4                ko                                      마린보이
#
#                                             overview  popularity  \
# 0  When Lou, who has become the "father of the In...    6.575393
# 1  Mia Thermopolis is now a college graduate and ...    8.248895
# 2  Under the direction of a ruthless instructor, ...   64.299990
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936
# 4  Marine Boy is the story of a former national s...    1.148070
#
#                         poster_path release_date          ...           \
# 0  /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg   2015-02-20          ...
# 1  /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg   2004-08-06          ...
# 2  /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg   2014-10-10          ...
# 3  /aTXRaPrWSinhcmCrcfJK17urp3F.jpg   2012-03-09          ...
# 4  /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg   2009-02-05          ...
#
#           director       screenplay       editor            music  \
# 0       Steve Pink                   Jamie Gross  Christophe Beck
# 1   Garry Marshall    Shonda Rhimes  Bruce Green      John Debney
# 2  Damien Chazelle  Damien Chazelle    Tom Cross   Justin Hurwitz
# 3      Sujoy Ghosh
# 4   Jong-seok Yoon
#
#    release_date_year release_date_weekday  release_date_month  \
# 0               2015                    4                   2
# 1               2004                    4                   8
# 2               2014                    4                  10
# 3               2012                    4                   3
# 4               2009                    3                   2
#
#   release_date_weekofyear  release_date_day  release_date_quarter
# 0                       8                20                     1
# 1                      32                 6                     3
# 2                      41                10                     4
# 3                      10                 9                     1
# 4                       6                 5                     1
#
# [5 rows x 95 columns]

# %% [markdown]
# Lets check the na values in the dataset.

# %%
train.isna().sum()
# Out:
# id                                                0
# budget                                            0
# homepage                                       2054
# imdb_id                                           0
# original_language                                 0
# original_title                                    0
# overview                                          8
# popularity                                        0
# poster_path                                       1
# release_date                                      0
# runtime                                           2
# status                                            0
# tagline                                         597
# title                                             0
# revenue                                           0
# collection_name                                   0
# num_genres                                        0
# all_genres                                        0
# genre_Drama                                       0
# genre_Comedy                                      0
# genre_Thriller                                    0
# genre_Action                                      0
# genre_Romance                                     0
# genre_Crime                                       0
# genre_Adventure                                   0
# genre_Horror                                      0
# genre_Science Fiction                             0
# genre_Family                                      0
# genre_Fantasy                                     0
# genre_Mystery                                     0
#                                                ...
# count_United Artists                              0
# count_Miramax Films                               0
# lang                                              0
# num_lang                                          0
# lang_Warner Bros.                                 0
# lang_Universal Pictures                           0
# lang_Paramount Pictures                           0
# lang_Twentieth Century Fox Film Corporation       0
# lang_Columbia Pictures                            0
# keywords                                          0
# num_kwds                                          0
# kwds_woman director                               0
# kwds_independent film                             0
# kwds_duringcreditsstinger                         0
# kwds_murder                                       0
# kwds_based on novel                               0
# lead_act_1                                        0
# lead_act_2                                        0
# producer                                          0
# exec_producer                                     0
# director                                          0
# screenplay                                        0
# editor                                            0
# music                                             0
# release_date_year                                 0
# release_date_weekday                              0
# release_date_month                                0
# release_date_weekofyear                           0
# release_date_day                                  0
# release_date_quarter                              0
# Length: 95, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# Before we train a model , we see that there are lot of categorical variables.Lets first encode them.

# %%
from category_encoders import *

# %% [markdown]
# We try to do mean encoding keeping popularity as a target variable . Since the popularity of a movie depends on the cast,language,production company ,crew  etc of the movie , I intuitively take this column for mean encoding.

# %%
## Inspired from https://www.kaggle.com/fabiendaniel/detecting-malwares-with-lgbm

def target_encode(df,column,target='popularity'):
    mean_list =df.groupby(by=column)[target].mean()
    return df[column].map(mean_list)

# %%
temp_train=train.copy()
temp_test=test.copy()

# %%
# train=temp_train.copy()
# test=temp_test.copy()

# %%
test[['collection_name','lead_act_1','popularity']].head()
# Out:
#       collection_name     lead_act_1  popularity
# 0  Pokémon Collection                   3.851534
# 1                   0                   3.559789
# 2                   0                   8.085194
# 3                   0                   8.596012
# 4                   0  Dennis Hopper    3.217680

# %%
null_columns=test[useful_cols].isna().sum()
null_columns[null_columns>0]
# Out:
# runtime    4
# dtype: int64

# %%
null_columns=train[useful_cols].isna().sum()
null_columns[null_columns>0]
# Out:
# runtime    2
# dtype: int64

# %%
test['runtime']=test['runtime'].fillna(test['runtime'].mean())

# %%
train['len_' + 'title'] = train['title'].fillna('').apply(lambda x: len(str(x)))
train['words_' + 'title'] = train['title'].fillna('').apply(lambda x: len(str(x.split(' '))))
train=train.drop('title',axis=1)

test['len_' + 'title'] = test['title'].fillna('').apply(lambda x: len(str(x)))
test['words_' + 'title'] = test['title'].fillna('').apply(lambda x: len(str(x.split(' '))))
test=test.drop('title',axis=1)

# %%
train['runtime']=train['runtime'].fillna(train['runtime'].mean())

# %%
for cols in ['collection_name','producer', 'exec_producer', 'director','screenplay', 'editor', 'music','lead_act_1', 'lead_act_2']:
    print(f'Target Encoding {cols} \n')
    train[cols]=target_encode(df=train,column=cols)
    #test[cols]=target_encode(df=test,column=cols)
    print('Encoding Completed')
# Out:
# Target Encoding collection_name
#
# Encoding Completed
# Target Encoding producer
#
# Encoding Completed
# Target Encoding exec_producer
#
# Encoding Completed
# Target Encoding director
#
# Encoding Completed
# Target Encoding screenplay
#
# Encoding Completed
# Target Encoding editor
#
# Encoding Completed
# Target Encoding music
#
# Encoding Completed
# Target Encoding lead_act_1
#
# Encoding Completed
# Target Encoding lead_act_2
#
# Encoding Completed

# %%
for cols in ['collection_name','producer', 'exec_producer', 'director','screenplay', 'editor', 'music','lead_act_1', 'lead_act_2']:
    print(f'Target Encoding {cols} \n')
    #train[cols]=target_encode(df=train,column=cols)
    test[cols]=target_encode(df=test,column=cols)
    #print(test[cols].head())
    print('Encoding Completed')
# Out:
# Target Encoding collection_name
#
# Encoding Completed
# Target Encoding producer
#
# Encoding Completed
# Target Encoding exec_producer
#
# Encoding Completed
# Target Encoding director
#
# Encoding Completed
# Target Encoding screenplay
#
# Encoding Completed
# Target Encoding editor
#
# Encoding Completed
# Target Encoding music
#
# Encoding Completed
# Target Encoding lead_act_1
#
# Encoding Completed
# Target Encoding lead_act_2
#
# Encoding Completed

# %%
train[useful_cols].select_dtypes('object').columns
# Out:
# Index(['original_language', 'original_title'], dtype='object')

# %% [markdown]
# We do a label encoding for these columns,

# %%
cat_cols=['original_language', 'original_title']

# %%
# %%time
indexer = {}
for col in cat_cols:
    # print(col)
    _, indexer[col] = pd.factorize(train[col].astype(str), sort=True)
    
for col in tqdm_notebook(cat_cols):
    print(f'Encoding {col}\n')
    train[col] = indexer[col].get_indexer(train[col].astype(str))
    test[col] = indexer[col].get_indexer(test[col].astype(str))
# Out:
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# Encoding original_language
#
# Encoding original_title
#
#
# Wall time: 373 ms

# %%
X=train.drop(['id','revenue'],axis=1)
Y=np.log1p(train['revenue'])
X_test=test.drop('id',axis=1)

# %% [markdown]
# Now , lets train our model .

# %%
from sklearn.model_selection import train_test_split,KFold
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb

# %%
x_train,x_valid,y_train,y_valid=train_test_split(X,Y,test_size=0.2,random_state=1000)

# %%
print(f'Shape of x_train is {x_train.shape},Shape of x_valid is {x_valid.shape},shape of y_valid is {y_valid.shape},shape of y_train is {y_train.shape}')
# Out:
# Shape of x_train is (2400, 94),Shape of x_valid is (600, 94),shape of y_valid is (600,),shape of y_train is (2400,)

# %%
m = RandomForestRegressor(n_estimators=100, min_samples_leaf=10, max_features=0.8, n_jobs=-1, oob_score=True)
m.fit(x_train[useful_cols], y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=0.8, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=10, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=True, random_state=None, verbose=0, warm_start=False)

# %%
print(f'Score :{m.score(x_train[useful_cols],y_train)} Squared Error:{mean_squared_error(y_valid,m.predict(x_valid[useful_cols]))}')
# Out:
# Score :0.6644618233365843 Squared Error:5.245653824310716

# %% [markdown]
# The error rate is very high.Lets tune the parameters.

# %%
n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=True, random_state=100)

# %%
oof = np.zeros(len(x_train))
predictions = np.zeros(len(x_valid))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train)):
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train.iloc[trn_idx][useful_cols],y_train.iloc[trn_idx]
    val_x,val_y = x_train.iloc[val_idx][useful_cols],y_train.iloc[val_idx]

    num_round = 15000
    clf = RandomForestRegressor(n_estimators=1000, min_samples_leaf=2, max_features=0.8, n_jobs=-1, oob_score=True)
    clf.fit(trn_x,trn_y)
    oof[val_idx] = clf.predict(val_x)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = useful_cols
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(x_valid[useful_cols]) / folds.n_splits
    print('Fold {} most important features are: '.format(n_fold + 1))
    for i in np.argsort(fold_importance_df["importance"])[-10:]:
            print('{}  -> {}'.format(fold_importance_df.iloc[i, 0], fold_importance_df.iloc[i, 1]))
    
        
    print('Fold %2d RMSE : %.6f' % (fold_ + 1, mean_squared_error(val_y, oof[val_idx])))

print("CV score: {:<8.5f}".format(mean_squared_error(y_train, oof)))

# %% [markdown]
# From the 5 fold feature importance , it is seen that original title , runtime , director , popularity,budget,editor,number of keywords ,editor are playing a key role in deciding the revenue of the movie . Lets use these features and lightgbm to train the final model.

# %%
final_features=['screenplay','budget','popularity','director','runtime','original_title','num_kwds','num_prod']

# %%
param={'metric':'rmse'}
clf = lgb.LGBMRegressor(learning_rate=0.05,n_estimators=5000,num_leaves=100,min_split_gain=0.5,max_depth=5,random_state=100,min_child_samples=5,**param)

# %%
oof = np.zeros(len(x_train))
predictions = np.zeros(len(X_test))
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(x_train)):
    print("Fold {}".format(fold_))
    trn_x,trn_y = x_train.iloc[trn_idx][final_features],y_train.iloc[trn_idx]
    val_x,val_y = x_train.iloc[val_idx][final_features],y_train.iloc[val_idx]

    num_round = 15000
    
    clf.fit(trn_x,trn_y,eval_set=[(val_x,val_y)],eval_metric='rmse',early_stopping_rounds=50,verbose=False)
    oof[val_idx] = clf.predict(val_x)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["Feature"] = final_features
    fold_importance_df["importance"] = clf.feature_importances_
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(X_test[final_features]) / folds.n_splits
    print('Fold {} most important features are: '.format(n_fold + 1))
    for i in np.argsort(fold_importance_df["importance"])[-10:]:
            print('{}  -> {}'.format(fold_importance_df.iloc[i, 0], fold_importance_df.iloc[i, 1]))
    
        
    print('Fold %2d RMSE : %.6f' % (fold_ + 1, mean_squared_error(val_y, oof[val_idx])))

print("CV score: {:<8.5f}".format(mean_squared_error(y_train, oof)))
# Out:
# Fold 0
# Fold 6 most important features are:
# screenplay  -> 97
# num_kwds  -> 126
# num_prod  -> 126
# original_title  -> 155
# director  -> 219
# runtime  -> 234
# popularity  -> 250
# budget  -> 277
# Fold  1 RMSE : 4.857602
# Fold 1
# Fold 6 most important features are:
# screenplay  -> 160
# num_prod  -> 165
# num_kwds  -> 198
# director  -> 307
# original_title  -> 323
# runtime  -> 327
# popularity  -> 328
# budget  -> 403
# Fold  2 RMSE : 4.914707
# Fold 2
# Fold 6 most important features are:
# num_prod  -> 120
# num_kwds  -> 140
# screenplay  -> 143
# original_title  -> 191
# runtime  -> 212
# popularity  -> 237
# director  -> 243
# budget  -> 318
# Fold  3 RMSE : 5.024892
# Fold 3
# Fold 6 most important features are:
# screenplay  -> 201
# num_prod  -> 217
# num_kwds  -> 265
# director  -> 365
# popularity  -> 395
# budget  -> 427
# runtime  -> 438
# original_title  -> 451
# Fold  4 RMSE : 4.941461
# Fold 4
# Fold 6 most important features are:
# num_prod  -> 125
# screenplay  -> 155
# num_kwds  -> 195
# original_title  -> 208
# popularity  -> 231
# director  -> 276
# runtime  -> 313
# budget  -> 361
# Fold  5 RMSE : 5.078812
# CV score: 4.96350

# %% [markdown]
# # Submission

# %%
sub['revenue']=np.expm1(predictions)
sub.to_csv('sample_submission_0.csv')
